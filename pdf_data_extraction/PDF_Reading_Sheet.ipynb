# %%
import re
import os
import numpy as np
import pandas as pd
import pdfplumber
import time
from nltk.tokenize import word_tokenize

from IPython.display import display, HTML
from notebook.services.config import ConfigManager

display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Get all words on page in a list of lists. Each word is represented by:
# [x0, y0, x1, y1, word, bno, lno, wno]
# The first 4 entries are the word's rectangle coordinates, the last 3 are just
# technical info (block number, line number, word number).
# The term 'word' here stands for any string without space.
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def find_insurer_by_site(page):
    INSURERS = {
                "ACKO": "acko.com", "BAJAJ": "bajajallianz.com", "BHARTI": "bhartiaxa.com", "CHOLA": "cholainsurance.com",
                "EDELWEISS": "edelweissinsurance.com", "GODIGIT": "godigit.com", "HDFC": "hdfcergo.com", "ICICI": "icicilombard.com",
                "IFFICO-TOKIO": "iffcotokio.co.in", "KOTAK": "kotakgeneralinsurance.com", "LIBERTY": "libertyinsurance.in",
                "MAGMA": "magmahdi.com" , "NAVI": "navi.com", "NEW INDIA": "newindia.co.in", "NATIONAL": "nationalinsuranceindia.nic.co.in",
                "ORIENTAL": "orientalinsurance.org.in", "RELIANCE": "reliancegeneral.co.in", "ROYAL": "royalsundaram.in", "SBI": "sbigeneral.in",
                "SHRIRAM": "shriramgi.com", "TATA": "tataaig.com", "UNITED": "uiic.co.in"
               }
    
    for insurer in INSURERS:
        page_data = page.search( INSURERS[insurer], regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def get_insurer_by_name(page):
    INSURERS = [
        "ACKO", "BAJAJ", "BHARTI", "CHOLA", "EDELWEISS", "GODIGIT", "HDFC", "ICICI", "IFFICO-TOKIO", "KOTAK", "LIBERTY",
        "MAGMA", "NAVI", "NEW INDIA", "NATIONAL", "ORIENTAL", "RELIANCE", "ROYAL", "SBI", "SHRIRAM", "TATA", "UNITED"
    ]
  
    for insurer in INSURERS:
        page_data = page.search( insurer, regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def find_mobile( page ):
    page_data = page.search( r'\s(\+91\-|0)?[6-9X][0-9X]{9}(,|\s)', regex=True, case=False )
    if len( page_data ) and "mobile" not in data:
        data["mobile"] = page_data[0]["text"].strip()
        data["mobile"] = data["mobile"][0:-1] if data["mobile"][-1] == "," else data["mobile"]

# %%
def find_email(page):
    page_data = page.search( r'[a-z0-9\.\-]+@+(gmail|yahoo|outlook|hotmail)+(\.com|\.co\.in)+', regex=True, case=False )
    if len( page_data ) and "email" not in data:
        data["email"] = page_data[0]["text"].strip() if len( data ) else None

# %%
def find_vehicle_type( page ):
    type_regex = [ r'(two|2)\s?\-?\s?wheeler\s?', r'(four|4)\s?\-?\s?wheeler\s?', r'(MOTORCYCLE|SCOOTER|BIKE)', r'(private)?\s?\-?\s?(car\s|car$)' ]
    for i in range(4):
        if len( page.search( type_regex[i], regex=True, case=False ) ) > 0:
            data["type"] = "4W" if i%2 else "2W" 
            break
    
#     (policy|package|hybrid|comprehensive|certificate|secure)

# %%
def find_policy_type( page ):
    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Policy)?\s?\-?\s?Stand\s?\-?\s?alone\s?\-?\s?O(wn)?\s?D(amage)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Stand Alone Own Damage"
        return

    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?Package\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Package Policy"
        return
    
    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?Comprehensive\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Comprehensive Policy"
        return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Liability\s?\-?\s?(Only)?\s?\-?\s?(Policy)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Liability Policy"
        return
    
    page_data = page.search( r'Liability\s?\-?\s?(Only)?\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?\s?\-?\s?Private\s?\-?\s?Car', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Liability Policy"
        return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Package\s?\-?\s?(Policy)?\s?\-?\s?(Insurance)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Package Policy"
        return

    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Comprehensive\s?\-?\s?(Policy)?\s?\-?\s?(Insurance)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Comprehensive Policy"
        return
 
    page_data = page.search( r'Comprehensive\s?\-?\s?(Bike|Car)?\s?\-?\s?(Insurance)?\s?\-?\s?Policy', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Comprehensive Policy"
        return
    
    page_data = page.search( r'Package\s?\-?\s?(Bike|Car)?\s?\-?\s?(Insurance)?\s?\-?\s?Policy', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Package Policy"
        return

# %%
def find_reg_no( page ):
    page_data = page.search( r'Registration\s(No\s?\.?|Number|Mark)\s*:?\s*[A-Z]{2}\s?\-?\s?[0-9]{1,2}\s?\-?\s?[A-Z]{1,3}\s?\-?\s?[0-9]{2,5}', regex=True, case=False )
    if len( page_data ) > 0:
        reg_number = re.split('\s|\:', page_data[0]["text"] )[-1]
        data["reg_no"] = reg_number.replace( '-', "" )

# %%
def find_chassis_no( page ):
    page_data = page.search( r'Chass?is\s(No\s?\.?|Number)\s*:?\s*M[A-EZ][A-HJ-NPR-Z0-9]{14,19}', regex=True, case=False )
    if len( page_data ) > 0:
        chassis_number = re.split('\s|:', page_data[0]["text"] )[-1]
        data["chassis_no"] = chassis_number.replace( '-', "" )

# %%
def find_chassis_no_with_slash( page ):
    key = page.search( r'Chass?is\s(No\s?\.?|Number)\s?/', regex=True, case=False )
    if len( key ):
        chassis_number = page.search( r'M[A-EZ][A-HJ-NPR-Z0-9]{15,19}\s?/', regex=True, case=False )
        if len( chassis_number ) > 0:
            data["chassis_no"] = chassis_number[0]["text"].replace( r'\/', "" )
            return
    
    key = page.search( r'/\s?Chass?is\s(No\s?\.?|Number)', regex=True, case=False )
    if len( key ):
        chassis_number = page.search( r'/\s?M[A-EZ][A-HJ-NPR-Z0-9]{15,19}', regex=True, case=False )
        if len( chassis_number ) > 0:
            data["chassis_no"] = chassis_number[0]["text"].replace( r'\/', "" )
            return

# %%
def find_insured_name( page ):
    page_data = page.search( r'(Mr|Mrs?|M\/s)(\.\s?|\s)[A-Z]{1,20}\s[A-Z]{0,20}\s[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
        data["insurers_name"] = page_data[0]["text"]
        return
    
    page_data = page.search( r'insured(\'s)?\s*name(\s|\s?:\s?)(Mr|Mrs?|M\/s|Ms\.)?(\.\s?|\s)?s*[A-Z]{1,20}\s[A-Z]{0,20}\s[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
        insurer_name = re.sub( "Insured(\'s)?\s*Name\s*:?\s*", "", page_data[0]["text"] )
        data["insurers_name"] = insurer_name

# %%
def find_policy_duration( page ):
    #date_time dd/mm/yyyy hh:mm:ss
    start_date = page.search( r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?([0-9]{4})(\s*|T)(\[|\()?\s*' + 
                              r'(00|12):(00|01)(\]|\))?\s?(:00|:01)?(\]|\))?\s?(hrs|hours|AM)?',
                             regex=True, case=False 
                            )    
    end_date  =  page.search( r'[0-9]{1,2}[\-\/\]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?([0-9]{4})(\s*|T)(\[|\()?s?' +
                              r'(\(?Mid\s?night\)?|11:59|11:59:59|23:59:59)\s?(\]|\))?\s?(hrs|hours|PM)?(\(?Mid\s?night\))?',
                             regex=True, case=False
                            )
    if len( start_date ) > 0 and "start" not in data :
        data["start"] = start_date[0]['text']
    if len( end_date ) > 0 and "end" not in data :
        data["end"] = end_date[0]['text']
        
    
    #time_data  hh:mm:ss dd/mm/yyyy
    start_date = page.search( r'(\[|\()?\s?(00|12):(00|01)(\]|\))?\s?(:00|:01)?\s?(hrs|hours|AM)?\s?(\]|\))?\s*(T|on|of)\s*' +
                              r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?[0-9]{4}',
                             regex=True, case=False 
                            )
    end_date = page.search( r'(\[|\()?s?(\(?Mid\s?night\)?|11:59|11:59:59|23:59:59)s?(\]|\))?\s?(hrs|hours|PM)?\s*(T|on|of)\s*' +
                            r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?[0-9]{4}(\(?Mid\s?night\))?',
                           regex=True, case=False
                          )
    if len( start_date ) > 0 and "start" not in data :
        data["start"] = start_date[0]['text']
    if len( end_date ) > 0 and "end" not in data :
        data["end"] = end_date[0]['text']

# %%
df = pd.DataFrame( columns=[ "file", "pages", "insurers name", "type", "reg_no", "insurer", "phone", "email", "policy_type", "chassis_no", "start", "end", "time" ] )
files = os.listdir("./all_policy/Motor/misc")

count = 0

for file in files:
# for file in [ "hdfc10.pdf" ]:
    count += 1
    print( count, file )
    
    start_time = time.time()
    
    policy = pdfplumber.open( f'all_policy/Motor/misc/{file}' )
    
    insurer_count = {}
    data = {}

    for page in policy.pages:
        find_insured_name( page )
        find_insurer_by_site( page ) if "insurer" not in data else None
        find_mobile( page ) if "mobile" not in data else None
        find_email( page ) if "email" not in data else None
        find_policy_type( page ) if "policy_type" not in data else None
        find_reg_no( page ) if "reg_no" not in data else None
        find_chassis_no( page ) if "chassis_no" not in data else None
        find_vehicle_type( page ) if "type" not in data else None
        find_policy_duration( page ) if "duration" not in data else None
        
    for page in policy.pages:
        if "insurer" not in data:
            get_insurer_by_name( page )
            
        if "chassis_no" not in data:
            find_chassis_no_with_slash( page )


    print( "data", data, "\n" )
    end_time = time.time()

    df.loc[ len( df.index ) ] = [ 
        file,
        len( policy.pages ),
        data["insurers_name"] if "insurers_name" in data else None,
        data["type"] if "type" in data else None,
        data["reg_no"] if "reg_no" in data else None,
        data["insurer"] if "insurer" in data else None,
        data["mobile"] if "mobile" in data else None,        
        data["email"] if "email" in data else None,
        data["policy_type"] if "policy_type" in data else None,
        data["chassis_no"] if "chassis_no" in data else None,
        data["start"] if "start" in data else None,
        data["end"] if "end" in data else None,
        ( end_time - start_time )
    ]
#     break
    
#     https://github.com/jsvine/pdfplumber
# Out:
# 1 hdfc13_4w.pdf
# data {'insurers_name': 'MR MAYUR MADHUKAR PATIL', 'mobile': '9096749797', 'email': 'mayur.m.patil9@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'MH11AW9594', 'chassis_no': 'MCA11835E07029773EMZ', 'start': '03 Nov, 2021 00:01 hrs', 'insurer': 'HDFC'}
#
# 2 reliance11_4w.pdf
# data {'insurers_name': 'MS.PRIYA AWASTHI ', 'mobile': '8433707105', 'email': 'dhirajawasthi@yahoo.com', 'reg_no': 'GJ15CK8239', 'type': '4W', 'start': ' 00:00 Hrs on 21-Jan-2022', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy', 'end': 'Mid Night of 20/01/2023'}
#
# 3 iffco1_4w.pdf
# data {'mobile': 'XXXXXXX741', 'start': '07/02/2022 00:00:00\n', 'end': '06/02/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'type': '4W'}
#
# 4 icici1_2w.pdf
# data {'insurer': 'ICICI', 'mobile': '9356278702', 'reg_no': 'TS09EE9725', 'chassis_no': 'ME4JF502LET601661', 'type': '2W', 'email': '2000@YAHOO.COM', 'policy_type': 'Package Policy', 'start': '02, 2022 12:00:00 '}
#
# 5 reliance2_2w.pdf
# data {'insurers_name': 'MR.B SENTHIL KUMAR', 'mobile': '8433707105', 'email': 'senthilkumar@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'TN12AH5335', 'start': ' 00:00 Hrs on 10-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MD2A55F5KCJ07279', 'end': 'Mid Night of 09/01/2023'}
#
# 6 newindia-4w-tp.pdf
# data {'insurer': 'NEW INDIA', 'type': '4W', 'policy_type': 'Liability Policy', 'start': '14/04/2022 12:00:01 AM', 'end': '13/04/2023 11:59', 'insurers_name': 'BIKRAM HAZARIKA ', 'mobile': 'XXXXXX0262', 'email': 'akashchetry799@gmail.com', 'reg_no': 'AS12M6347', 'chassis_no': 'MA3ERLF1S00399960/'}
#
# 7 national-4w-comp.pdf
# data {'insurers_name': 'Mr. Edward I ', 'insurer': 'NATIONAL', 'mobile': '9916098981', 'email': 'edwardlawson87@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'start': '21-Apr-2022(00:00:00) '}
#
# 8 iffco9_2w.pdf
# data {'insurers_name': 'RAMNARESH GODARA ', 'mobile': 'XXXXXXX100', 'type': '2W', 'start': '05/01/2022 00:00:00\n', 'end': '04/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 9 hdfc8_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '9900466863', 'email': 'dhanukumar110@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'KA42EB9744', 'chassis_no': 'ME4JF50AALA134302', 'start': '20 Jan, 2022 00:01 hrs'}
#
# 10 sbi-4w-comp.pdf
# data {'insurers_name': 'Mr. CHINTHALA PREETHI\n', 'insurer': 'SBI', 'mobile': '+91-9052928520', 'type': '4W', 'start': '15/05/2022T00:00:00\n', 'reg_no': 'TS08GN1666', 'chassis_no': 'MA3NYFB1SKC520556', 'end': '14/05/2023 Midnight\n '}
#
# 11 reliance15_2w.pdf
# data {'insurers_name': 'MR.HIMANSHU KUMAR ', 'mobile': '8433707105', 'email': 'Himanshukum@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'DL13SU5840', 'start': ' 00:00 Hrs on 05-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JF507KH7361902', 'end': 'Mid Night of 04/01/2023'}
#
# 12 magma-4w-comp.pdf
# data {'insurers_name': 'Mrs. Mrsjayshreeben Kamleshkumar Prajapati', 'insurer': 'MAGMA', 'mobile': '9725056102', 'email': 'primekamlesh@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'start': ' 00:00 Hrs of 14/04/2022', 'end': 'Midnight of 13/04/2023'}
#
# 13 reliance8_car.pdf
# data {'insurers_name': 'MR.PRABHAKAR PANDEY ', 'mobile': '8433707105', 'email': 'pankaj.singh.garud@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'UP60AA1991', 'start': ' 00:00 Hrs on 07-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MALBM51BLFM193559M'}
#
# 14 kotak9_2w.pdf
# data {'insurer': 'KOTAK', 'mobile': '8409305280', 'type': '2W', 'insurers_name': 'Mr. Vikash Andani ', 'email': 'RAMKUMARITBP1988@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'end': '01/02/2023Midnight\n '}
#
# 15 reliance16_4w.pdf
# data {'insurers_name': 'MR.MOHAMMAD RUSTUM BHAT', 'mobile': '8433707105', 'email': 'hilaljmi12@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'JK13C7701', 'start': ' 00:00 Hrs on 29-Oct-2021', 'insurer': 'RELIANCE', 'chassis_no': 'MA3EWDE1S00894649'}
#
# 16 chola-2w-comp.pdf
# data {'insurer': 'CHOLA', 'mobile': '9841198260', 'reg_no': 'TN10BC4732', 'chassis_no': 'MD626AG78J2D14142', 'type': '2W', 'start': '17/04/2022 00:01 hours', 'end': 'midnight on 16/04/2023'}
#
# 17 iffco3_2w.pdf
# data {'insurers_name': 'N VARADARAJAN ', 'mobile': 'XXXXXXX101', 'type': '2W', 'start': '27/02/2022 00:00:00\n', 'end': '26/02/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 18 acko-4w-tp.pdf
# data {'insurers_name': 'TEISOVINUO LOTHA ', 'insurer': 'ACKO', 'mobile': 'XXXXXX8324', 'email': 'sXXXXXXXXXXXXXXXXXXXX6@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'NL07T0267'}
#
# 19 reliance12_2w.pdf
# data {'insurers_name': 'MR.MR RAVEENDRAN ', 'mobile': '8433707105', 'email': 'anugrahameppayur@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'KL77A9698', 'start': ' 00:00 Hrs on 08-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP12DML8474223', 'end': 'Mid Night of 07/01/2023'}
#
# 20 kotak2_2w.pdf
# data {'insurers_name': 'Mr. Netaji Shivaji Jadhav', 'insurer': 'KOTAK', 'mobile': '8149445455', 'type': '2W', 'email': 'GANESHDZIRE@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '03/01/2022 00:00 ', 'end': '02/01/2023Midnight\n '}
#
# 21 navi-4w-tp.pdf
# data {'insurer': 'NAVI', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'KA03ML1507', 'chassis_no': 'MALAM51CR9M333424', 'start': ' 00:00 Hrs on 04-03-2022', 'end': 'Midnight on 03-03-2023'}
#
# 22 national-2w-comp.pdf
# data {'insurers_name': 'Mr. Amit Ratnakar Pagare', 'insurer': 'NATIONAL', 'mobile': '9890085085', 'email': 'contactpagare@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'start': '13-Apr-2022(00:00:00) '}
#
# 23 reliance4_2w.pdf
# data {'insurers_name': 'MR.SITA RAM BAIRWA', 'mobile': '8433707105', 'email': 'jp9433344@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'RJ14AJ7933', 'start': ' 00:00 Hrs on 04-Feb-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JC67DBK8003293', 'end': 'Mid Night of 03/02/2023'}
#
# 24 acko-4w-comp.pdf
# data {'insurer': 'ACKO', 'email': 'iXXXXXXXXXXXXXXXXXXXa@yahoo.co.in', 'type': '4W', 'policy_type': 'Package Policy', 'insurers_name': 'MANJU ISHWERI NARAYAN', 'reg_no': 'MH03BS0277', 'chassis_no': 'MAT612354EKD08300', 'mobile': 'XXXXXX2426'}
#
# 25 iffco5_2w.pdf
# data {'insurers_name': 'ALAGAPPAN AL ', 'mobile': 'XXXXXXX195', 'type': '2W', 'start': '02/01/2022 00:00:00\n', 'end': '01/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 26 reliance10_2w.pdf
# data {'insurers_name': 'MR.AKASH KUMAR SINGH', 'mobile': '8433707105', 'email': 'akashikka@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'KA51Y5671', 'start': ' 00:00 Hrs on 21-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JC448BB8090424', 'end': 'Mid Night of 20/01/2023'}
#
# 27 newindia-2w-comp.pdf
# data {'insurers_name': 'RUPAM DAS ', 'insurer': 'NEW INDIA', 'mobile': 'XXXXXX6455', 'email': 'noonmati020@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'AS01DB1446', 'start': '15/04/2022 12:00:01 AM', 'end': '14/04/2023 11:59', 'chassis_no': 'MB8NG4BAHG8239880/'}
#
# 28 united-2w-comp.pdf
# data {'insurer': 'UNITED', 'mobile': '9671732414', 'policy_type': 'Package Policy', 'type': '2W', 'start': ' 00:00 Hrs on 14-Apr-2022', 'end': 'Midnight on 13-Apr-2023', 'email': 'gurmeet3093@gmail.com'}
#
# 29 reliance3_2w.pdf
# data {'insurers_name': 'MS.SHANTHI S ', 'mobile': '8433707105', 'email': 'rajthanga0123@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'PY01CW1342', 'start': ' 00:00 Hrs on 09-Feb-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP12DAL8138573', 'end': 'Mid Night of 08/02/2023'}
#
# 30 kotak7_2w.pdf
# data {'insurers_name': 'Mr. Prabhuraj K Hosamani', 'insurer': 'KOTAK', 'mobile': '8951618891', 'type': '2W', 'email': 'BAJARANGIPKH@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'end': '10/01/2023Midnight\n '}
#
# 31 kotak10_2w.pdf
# data {'insurer': 'KOTAK', 'mobile': '8533990227', 'type': '2W', 'insurers_name': 'Mrs. Reetu Kumari ', 'email': 'REETUREETU141@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '08/01/2022 00:00 ', 'end': '07/01/2023Midnight\n '}
#
# 32 kotak11_2w.pdf
# data {'insurers_name': 'Mr. Bharat Yashwant Bangar', 'insurer': 'KOTAK', 'mobile': '9594880123', 'type': '2W', 'email': 'DOSTITOUR@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '11/10/2021 00:00 ', 'end': '10/10/2022Midnight\n '}
#
# 33 hdfc9_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '7979971843', 'email': 'navneetbhg2020@gmail.com', 'type': '2W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'JH01BC4249', 'chassis_no': 'ME4JC36KKD7311586', 'start': '16 Jan, 2022 00:01 hrs'}
#
# 34 kotak5_2w.pdf
# data {'insurers_name': 'Mr. Sudesh R Morajkar', 'insurer': 'KOTAK', 'mobile': '9822122510', 'type': '2W', 'email': 'SUDESH.ARTIS@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '07/01/2022 00:00 ', 'end': '06/01/2023Midnight\n '}
#
# 35 united-4w-tp.pdf
# data {'insurer': 'UNITED', 'mobile': '7904149939', 'type': '4W', 'start': ' 00:00 Hrs on 03-Mar-2022', 'end': 'Midnight on 02-Mar-2023', 'email': 'veludivxece2018@gmail.com', 'policy_type': 'Liability Policy'}
#
# 36 newindia-4w-comp.pdf
# data {'insurer': 'NEW INDIA', 'type': '4W', 'policy_type': 'Package Policy', 'start': '20/04/2022 12:00:01 AM', 'end': '19/04/2023 11:59', 'insurers_name': 'GAURAV GOEL ', 'mobile': 'XXXXXX8030', 'email': 'goel209@yahoo.co.in', 'reg_no': 'HR26CD8127'}
#
# 37 reliance1_4w.pdf
# data {'insurers_name': 'MR.RAMAKANTA SAMAL ', 'mobile': '8433707105', 'email': 'niraj.samal@hotmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'OD02AA4963', 'start': ' 00:00 Hrs on 16-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MALA841CLFM151684'}
#
# 38 edel-4w-comp.pdf
# data {'insurers_name': 'Mr. Pronojit Sen ', 'type': '4W', 'policy_type': 'Package Policy', 'start': '[00:00] of 12-Apr-2022', 'insurer': 'EDELWEISS'}
#
# 39 iffco6_2w.pdf
# data {'insurers_name': 'BRAJESH KUMAR ', 'mobile': 'XXXXXXX810', 'type': '2W', 'start': '04/01/2022 00:00:00\n', 'end': '03/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 40 kotak6_2w.pdf
# data {'insurer': 'KOTAK', 'mobile': '9741111668', 'type': '2W', 'insurers_name': 'Mr. Suman Bn ', 'email': 'SUMANBN668@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'end': '27/01/2023Midnight\n '}
#
# 41 iffco11_2w.pdf
# data {'insurers_name': 'SUDHIR JAIN ', 'mobile': 'XXXXXXX830', 'type': '2W', 'start': '18/11/2021 00:00:00\n', 'end': '17/11/2022 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 42 hdfc2_4w.pdf
# data {'insurers_name': 'M/S RAJ KUMAR KAIN', 'mobile': '7982382088', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL08CNB8249', 'start': '24 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 43 iffco10_2w.pdf
# data {'insurers_name': 'RAJASEKHAR CH ', 'mobile': 'XXXXXXX689', 'type': '2W', 'start': '03/11/2021 00:00:00\n', 'end': '02/11/2022 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 44 iffco4_2w.pdf
# data {'insurers_name': 'RAKESH KUMAR MAURYA', 'mobile': 'XXXXXXX540', 'type': '2W', 'start': '10/01/2022 00:00:00\n', 'end': '09/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'policy_type': 'Package Policy'}
#
# 45 royalsundaram-4w-comp.pdf
# data {'insurers_name': 'Mr. LAVJIBHAI MOHANBHAI HAPALIYA', 'insurer': 'ROYAL', 'mobile': 'xxxxxx5540', 'start': ' 00:00:00 hours on 07/04/2022', 'end': '23:59:59 hours on 06/04/2023', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'GJ5JP5327'}
#
# 46 hdfc12_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '9902059738', 'email': 'jagadeeshae7272@gmail.com', 'type': '2W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'KA53EM8787', 'start': '16 Jan, 2022 00:01 hrs'}
#
# 47 hdfc11_4w.pdf
# data {'insurers_name': 'MR BEERAIAH B ', 'mobile': '9731138386', 'email': 'prakashmbangalore@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA53C7581', 'chassis_no': 'MAT600185GPJ34888', 'start': '03 Feb, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 48 iffco8_2w.pdf
# data {'insurers_name': 'MADHAV RADHEYSHYAM KATIYAR', 'mobile': 'XXXXXXX720', 'type': '2W', 'start': '27/01/2022 00:00:00\n', 'end': '26/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'policy_type': 'Package Policy'}
#
# 49 hdfc5_4w.pdf
# data {'insurers_name': 'MR KRISHNAMURTHY KIKKISETTI RTO', 'mobile': '9742723000', 'email': 'kkmurty93@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA03MX4830', 'chassis_no': 'MEEBBA002G1325553', 'start': '30 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 50 kotak8_4w.pdf
# data {'insurer': 'KOTAK', 'mobile': '9700643243', 'type': '4W', 'insurers_name': 'Mrs. Leelavathi B ', 'email': 'RAMYABHARGAVI.BUJJE@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '19/01/2022 00:00 ', 'end': '18/01/2023Midnight\n '}
#
# 51 iffco7_4w.pdf
# data {'mobile': 'XXXXXXX674', 'start': '03/02/2022 00:00:00\n', 'end': '02/02/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'type': '4W', 'policy_type': 'Package Policy'}
#
# 52 reliance9_car.pdf
# data {'insurers_name': 'MR.PRAMOD SINGH RANA', 'mobile': '8433707105', 'email': 'atienter2010@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL02CAZ7876', 'start': ' 00:00 Hrs on 09-Jan-2022', 'insurer': 'RELIANCE'}
#
# 53 acko-2w-comp.pdf
# data {'insurers_name': 'Geetinder Singh ', 'insurer': 'ACKO', 'mobile': 'XXXXXX9111', 'email': 'gXXXXXXXXXXXXi@yahoo.com', 'policy_type': 'Comprehensive Policy', 'reg_no': 'PB10FS2630', 'chassis_no': 'ME3U3K5C0GD042682', 'type': '2W'}
#
# 54 hdfc7_4w.pdf
# data {'insurers_name': 'MR SANDEEP KUMAR ', 'mobile': '9646689689', 'email': 'harpreetsharma097@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'CH01AE2802', 'chassis_no': 'MA3EWDE1S00176139', 'start': '31 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 55 sbi-4w-tp.pdf
# data {'insurers_name': 'Mr. MANISH SHARMA\n', 'insurer': 'SBI', 'mobile': '+91-9818077949', 'start': '10/03/2022T00:00:00\n', 'reg_no': 'DL2CAN2618', 'chassis_no': 'MA3EDKD1S00290267', 'end': '09/03/2023 Midnight\n ', 'type': '4W'}
#
# 56 kotak3_2w.pdf
# data {'insurers_name': 'Mr. Amol Jugalkishor Heda', 'insurer': 'KOTAK', 'mobile': '9845316882', 'type': '2W', 'email': 'MOHITSR76@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '09/01/2022 00:00 ', 'end': '08/01/2023Midnight\n '}
#
# 57 reliance14_2w.pdf
# data {'insurers_name': 'MR.SUNDARABABU R ', 'mobile': '8433707105', 'email': 'rajthanga0123@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'PY05F2934', 'start': ' 00:00 Hrs on 31-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP11ALJ8A62610', 'end': 'Mid Night of 30/01/2023'}
#
# 58 iffco2_4w.pdf
# data {'mobile': 'XXXXXXX114', 'start': '09/03/2022 00:00:00\n', 'end': '08/03/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'type': '4W'}
#
# 59 reliance7_4w.pdf
# data {'insurers_name': 'MR.MR SANKHA NARAYAN', 'mobile': '8433707105', 'email': 'surzeett@gmail.com', 'reg_no': 'AS06AA5025', 'type': '4W', 'start': ' 00:00 Hrs on 10-Jan-2022', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy', 'chassis_no': 'MBHEWB22SKM407883', 'end': 'Mid Night of 09/01/2023'}
#
# 60 hdfc1_4w.pdf
# data {'insurers_name': 'MR PARIKSHIT MALHOTRA ', 'insurer': 'HDFC', 'mobile': '9418450772', 'email': 'drpm1972@gmail.com', 'type': '4W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'HP33F5772', 'start': '18 Jan, 2022 00:01 hrs', 'end': '17/01/2023 Midnight '}
#
# 61 united-4w-comp.pdf
# data {'insurer': 'UNITED', 'mobile': '9873621425', 'policy_type': 'Package Policy', 'type': '4W', 'start': ' 00:00 Hrs on 09-Apr-2022', 'end': 'Midnight on 08-Apr-2023'}
#
# 62 hdfc6_2W.pdf
# data {'insurer': 'HDFC', 'mobile': '8882746998', 'email': 'pankajali786@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'DL08SCR0181', 'chassis_no': 'MD626AG74K2E23103', 'start': '02 Feb, 2022 00:01 hrs'}
#
# 63 hdfc10_4w.pdf
# data {'insurers_name': 'MR MANJU DEVI ', 'mobile': '9816086889', 'email': 'chandan.ranote@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'HP12D2172', 'chassis_no': 'MALAA51HR9M486097L', 'start': '16 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 64 hdfc3_4w.pdf
# data {'insurers_name': 'MR HARI OM ', 'mobile': '7983119833', 'email': 'sksmtr.sk@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL03CCN5760', 'chassis_no': 'MA3EWDE1S00D50948', 'start': '01 Feb, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 65 reliance13_4w.pdf
# data {'insurers_name': 'MR.ASHWATHANARAYAN M ', 'mobile': '8433707105', 'email': 'bmvishnu.vs@yahoo.co.in', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA43M8588', 'start': ' 00:00 Hrs on 06-Jan-2022', 'insurer': 'RELIANCE'}
#
# 66 reliance5_2w.pdf
# data {'insurers_name': 'MS.ASTALAKSHMI R ', 'mobile': '8433707105', 'email': 'SKFINANCE01@GMAIL.COM', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'TN11AK9898', 'start': ' 00:00 Hrs on 18-Feb-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME1SED14AJ0042881', 'end': 'Mid Night of 17/02/2023'}
#
# 67 reliance6_4w.pdf
# data {'insurers_name': 'MR.RAKESH BALDEVBHAI PATEL', 'mobile': '8433707105', 'email': 'rakesh11566@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'GJ06DG2771', 'start': ' 00:00 Hrs on 21-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MALBB51BR9M122064M'}

# %%
df = df.sort_values("file")
# df.filter( ["file", "start", "end"] )
df
# Out:
#                          file  pages  \
# 52           acko-2w-comp.pdf      2
# 23           acko-4w-comp.pdf      6
# 17             acko-4w-tp.pdf      2
# 15          chola-2w-comp.pdf      2
# 37           edel-4w-comp.pdf      3
# 62              hdfc10_4w.pdf      2
# 46              hdfc11_4w.pdf      3
# 45              hdfc12_2w.pdf      3
# 0               hdfc13_4w.pdf      3
# 59               hdfc1_4w.pdf      3
# 41               hdfc2_4w.pdf      3
# 63               hdfc3_4w.pdf      3
# 48               hdfc5_4w.pdf      3
# 61               hdfc6_2W.pdf      3
# 53               hdfc7_4w.pdf      3
# 8                hdfc8_2w.pdf      3
# 32               hdfc9_2w.pdf      3
# 3               icici1_2w.pdf      2
# 42             iffco10_2w.pdf      3
# 40             iffco11_2w.pdf      4
# 2               iffco1_4w.pdf      3
# 57              iffco2_4w.pdf      4
# 16              iffco3_2w.pdf      4
# 43              iffco4_2w.pdf      4
# 24              iffco5_2w.pdf      4
# 38              iffco6_2w.pdf      4
# 50              iffco7_4w.pdf      5
# 47              iffco8_2w.pdf      4
# 7               iffco9_2w.pdf      4
# 30             kotak10_2w.pdf     10
# 31             kotak11_2w.pdf     10
# 19              kotak2_2w.pdf     10
# 55              kotak3_2w.pdf     10
# 33              kotak5_2w.pdf     10
# 39              kotak6_2w.pdf     11
# 29              kotak7_2w.pdf     11
# 49              kotak8_4w.pdf      9
# 13              kotak9_2w.pdf     11
# 11          magma-4w-comp.pdf      2
# 21       national-2w-comp.pdf      2
# 6        national-4w-comp.pdf      2
# 20             navi-4w-tp.pdf      8
# 26       newindia-2w-comp.pdf      3
# 35       newindia-4w-comp.pdf      7
# 5          newindia-4w-tp.pdf      7
# 25          reliance10_2w.pdf      6
# 1           reliance11_4w.pdf     11
# 18          reliance12_2w.pdf      6
# 64          reliance13_4w.pdf     11
# 56          reliance14_2w.pdf      6
# 10          reliance15_2w.pdf      6
# 14          reliance16_4w.pdf     11
# 36           reliance1_4w.pdf     11
# 4            reliance2_2w.pdf      6
# 28           reliance3_2w.pdf      6
# 22           reliance4_2w.pdf      6
# 65           reliance5_2w.pdf      6
# 66           reliance6_4w.pdf     11
# 58           reliance7_4w.pdf     11
# 12          reliance8_car.pdf     11
# 51          reliance9_car.pdf     11
# 44  royalsundaram-4w-comp.pdf      4
# 9             sbi-4w-comp.pdf     17
# 54              sbi-4w-tp.pdf     13
# 27         united-2w-comp.pdf      9
# 60         united-4w-comp.pdf     10
# 34           united-4w-tp.pdf      8
#
#                                  insurers name type       reg_no  \
# 52                            Geetinder Singh    2W   PB10FS2630
# 23                       MANJU ISHWERI NARAYAN   4W   MH03BS0277
# 17                           TEISOVINUO LOTHA    4W    NL07T0267
# 15                                        None   2W   TN10BC4732
# 37                           Mr. Pronojit Sen    4W         None
# 62                              MR MANJU DEVI    4W    HP12D2172
# 46                              MR BEERAIAH B    4W    KA53C7581
# 45                                        None   2W   KA53EM8787
# 0                      MR MAYUR MADHUKAR PATIL   4W   MH11AW9594
# 59                      MR PARIKSHIT MALHOTRA    4W    HP33F5772
# 41                          M/S RAJ KUMAR KAIN   4W  DL08CNB8249
# 63                                 MR HARI OM    4W  DL03CCN5760
# 48             MR KRISHNAMURTHY KIKKISETTI RTO   4W   KA03MX4830
# 61                                        None   2W  DL08SCR0181
# 53                           MR SANDEEP KUMAR    4W   CH01AE2802
# 8                                         None   2W   KA42EB9744
# 32                                        None   2W   JH01BC4249
# 3                                         None   2W   TS09EE9725
# 42                              RAJASEKHAR CH    2W         None
# 40                                SUDHIR JAIN    2W         None
# 2                                         None   4W         None
# 57                                        None   4W         None
# 16                              N VARADARAJAN    2W         None
# 43                         RAKESH KUMAR MAURYA   2W         None
# 24                               ALAGAPPAN AL    2W         None
# 38                              BRAJESH KUMAR    2W         None
# 50                                        None   4W         None
# 47                  MADHAV RADHEYSHYAM KATIYAR   2W         None
# 7                            RAMNARESH GODARA    2W         None
# 30                          Mrs. Reetu Kumari    2W         None
# 31                  Mr. Bharat Yashwant Bangar   2W         None
# 19                   Mr. Netaji Shivaji Jadhav   2W         None
# 55                   Mr. Amol Jugalkishor Heda   2W         None
# 33                       Mr. Sudesh R Morajkar   2W         None
# 39                               Mr. Suman Bn    2W         None
# 29                    Mr. Prabhuraj K Hosamani   2W         None
# 49                          Mrs. Leelavathi B    4W         None
# 13                          Mr. Vikash Andani    2W         None
# 11  Mrs. Mrsjayshreeben Kamleshkumar Prajapati   4W         None
# 21                    Mr. Amit Ratnakar Pagare   2W         None
# 6                                Mr. Edward I    4W         None
# 20                                        None   4W   KA03ML1507
# 26                                  RUPAM DAS    2W   AS01DB1446
# 35                                GAURAV GOEL    4W   HR26CD8127
# 5                             BIKRAM HAZARIKA    4W    AS12M6347
# 25                        MR.AKASH KUMAR SINGH   2W    KA51Y5671
# 1                            MS.PRIYA AWASTHI    4W   GJ15CK8239
# 18                           MR.MR RAVEENDRAN    2W    KL77A9698
# 64                       MR.ASHWATHANARAYAN M    4W    KA43M8588
# 56                           MR.SUNDARABABU R    2W    PY05F2934
# 10                          MR.HIMANSHU KUMAR    2W   DL13SU5840
# 14                     MR.MOHAMMAD RUSTUM BHAT   4W    JK13C7701
# 36                         MR.RAMAKANTA SAMAL    4W   OD02AA4963
# 4                           MR.B SENTHIL KUMAR   2W   TN12AH5335
# 28                               MS.SHANTHI S    2W   PY01CW1342
# 22                          MR.SITA RAM BAIRWA   2W   RJ14AJ7933
# 65                           MS.ASTALAKSHMI R    2W   TN11AK9898
# 66                  MR.RAKESH BALDEVBHAI PATEL   4W   GJ06DG2771
# 58                        MR.MR SANKHA NARAYAN   4W   AS06AA5025
# 12                        MR.PRABHAKAR PANDEY    4W   UP60AA1991
# 51                        MR.PRAMOD SINGH RANA   4W  DL02CAZ7876
# 44            Mr. LAVJIBHAI MOHANBHAI HAPALIYA   4W    GJ5JP5327
# 9                      Mr. CHINTHALA PREETHI\n   4W   TS08GN1666
# 54                         Mr. MANISH SHARMA\n   4W   DL2CAN2618
# 27                                        None   2W         None
# 60                                        None   4W         None
# 34                                        None   4W         None
#
#          insurer           phone                              email  \
# 52          ACKO      XXXXXX9111           gXXXXXXXXXXXXi@yahoo.com
# 23          ACKO      XXXXXX2426  iXXXXXXXXXXXXXXXXXXXa@yahoo.co.in
# 17          ACKO      XXXXXX8324   sXXXXXXXXXXXXXXXXXXXX6@gmail.com
# 15         CHOLA      9841198260                               None
# 37     EDELWEISS            None                               None
# 62          HDFC      9816086889           chandan.ranote@gmail.com
# 46          HDFC      9731138386        prakashmbangalore@gmail.com
# 45          HDFC      9902059738          jagadeeshae7272@gmail.com
# 0           HDFC      9096749797           mayur.m.patil9@gmail.com
# 59          HDFC      9418450772                 drpm1972@gmail.com
# 41          HDFC      7982382088                               None
# 63          HDFC      7983119833                sksmtr.sk@gmail.com
# 48          HDFC      9742723000                kkmurty93@gmail.com
# 61          HDFC      8882746998             pankajali786@gmail.com
# 53          HDFC      9646689689        harpreetsharma097@gmail.com
# 8           HDFC      9900466863            dhanukumar110@gmail.com
# 32          HDFC      7979971843           navneetbhg2020@gmail.com
# 3          ICICI      9356278702                     2000@YAHOO.COM
# 42  IFFICO-TOKIO      XXXXXXX689                               None
# 40  IFFICO-TOKIO      XXXXXXX830                               None
# 2   IFFICO-TOKIO      XXXXXXX741                               None
# 57  IFFICO-TOKIO      XXXXXXX114                               None
# 16  IFFICO-TOKIO      XXXXXXX101                               None
# 43  IFFICO-TOKIO      XXXXXXX540                               None
# 24  IFFICO-TOKIO      XXXXXXX195                               None
# 38  IFFICO-TOKIO      XXXXXXX810                               None
# 50  IFFICO-TOKIO      XXXXXXX674                               None
# 47  IFFICO-TOKIO      XXXXXXX720                               None
# 7   IFFICO-TOKIO      XXXXXXX100                               None
# 30         KOTAK      8533990227            REETUREETU141@GMAIL.COM
# 31         KOTAK      9594880123                DOSTITOUR@GMAIL.COM
# 19         KOTAK      8149445455              GANESHDZIRE@GMAIL.COM
# 55         KOTAK      9845316882                MOHITSR76@GMAIL.COM
# 33         KOTAK      9822122510             SUDESH.ARTIS@GMAIL.COM
# 39         KOTAK      9741111668               SUMANBN668@GMAIL.COM
# 29         KOTAK      8951618891             BAJARANGIPKH@GMAIL.COM
# 49         KOTAK      9700643243      RAMYABHARGAVI.BUJJE@GMAIL.COM
# 13         KOTAK      8409305280         RAMKUMARITBP1988@GMAIL.COM
# 11         MAGMA      9725056102             primekamlesh@gmail.com
# 21      NATIONAL      9890085085            contactpagare@gmail.com
# 6       NATIONAL      9916098981           edwardlawson87@gmail.com
# 20          NAVI            None                               None
# 26     NEW INDIA      XXXXXX6455              noonmati020@gmail.com
# 35     NEW INDIA      XXXXXX8030                goel209@yahoo.co.in
# 5      NEW INDIA      XXXXXX0262           akashchetry799@gmail.com
# 25      RELIANCE      8433707105                akashikka@gmail.com
# 1       RELIANCE      8433707105            dhirajawasthi@yahoo.com
# 18      RELIANCE      8433707105         anugrahameppayur@gmail.com
# 64      RELIANCE      8433707105            bmvishnu.vs@yahoo.co.in
# 56      RELIANCE      8433707105            rajthanga0123@gmail.com
# 10      RELIANCE      8433707105              Himanshukum@gmail.com
# 14      RELIANCE      8433707105               hilaljmi12@gmail.com
# 36      RELIANCE      8433707105            niraj.samal@hotmail.com
# 4       RELIANCE      8433707105             senthilkumar@gmail.com
# 28      RELIANCE      8433707105            rajthanga0123@gmail.com
# 22      RELIANCE      8433707105                jp9433344@gmail.com
# 65      RELIANCE      8433707105              SKFINANCE01@GMAIL.COM
# 66      RELIANCE      8433707105              rakesh11566@gmail.com
# 58      RELIANCE      8433707105                 surzeett@gmail.com
# 12      RELIANCE      8433707105       pankaj.singh.garud@gmail.com
# 51      RELIANCE      8433707105             atienter2010@gmail.com
# 44         ROYAL      xxxxxx5540                               None
# 9            SBI  +91-9052928520                               None
# 54           SBI  +91-9818077949                               None
# 27        UNITED      9671732414              gurmeet3093@gmail.com
# 60        UNITED      9873621425                               None
# 34        UNITED      7904149939          veludivxece2018@gmail.com
#
#                policy_type            chassis_no  \
# 52    Comprehensive Policy     ME3U3K5C0GD042682
# 23          Package Policy     MAT612354EKD08300
# 17        Liability Policy                  None
# 15                    None     MD626AG78J2D14142
# 37          Package Policy                  None
# 62        Liability Policy    MALAA51HR9M486097L
# 46          Package Policy     MAT600185GPJ34888
# 45    Comprehensive Policy                  None
# 0           Package Policy  MCA11835E07029773EMZ
# 59    Comprehensive Policy                  None
# 41          Package Policy                  None
# 63          Package Policy     MA3EWDE1S00D50948
# 48          Package Policy     MEEBBA002G1325553
# 61  Stand Alone Own Damage     MD626AG74K2E23103
# 53          Package Policy     MA3EWDE1S00176139
# 8   Stand Alone Own Damage     ME4JF50AALA134302
# 32    Comprehensive Policy     ME4JC36KKD7311586
# 3           Package Policy     ME4JF502LET601661
# 42                    None                  None
# 40                    None                  None
# 2                     None                  None
# 57                    None                  None
# 16                    None                  None
# 43          Package Policy                  None
# 24                    None                  None
# 38                    None                  None
# 50          Package Policy                  None
# 47          Package Policy                  None
# 7                     None                  None
# 30    Comprehensive Policy                  None
# 31    Comprehensive Policy                  None
# 19    Comprehensive Policy                  None
# 55    Comprehensive Policy                  None
# 33    Comprehensive Policy                  None
# 39    Comprehensive Policy                  None
# 29    Comprehensive Policy                  None
# 49    Comprehensive Policy                  None
# 13    Comprehensive Policy                  None
# 11          Package Policy                  None
# 21          Package Policy                  None
# 6           Package Policy                  None
# 20        Liability Policy     MALAM51CR9M333424
# 26          Package Policy    MB8NG4BAHG8239880/
# 35          Package Policy                  None
# 5         Liability Policy    MA3ERLF1S00399960/
# 25          Package Policy     ME4JC448BB8090424
# 1           Package Policy                  None
# 18  Stand Alone Own Damage     MB8DP12DML8474223
# 64          Package Policy                  None
# 56  Stand Alone Own Damage     MB8DP11ALJ8A62610
# 10          Package Policy     ME4JF507KH7361902
# 14          Package Policy     MA3EWDE1S00894649
# 36          Package Policy     MALA841CLFM151684
# 4   Stand Alone Own Damage      MD2A55F5KCJ07279
# 28  Stand Alone Own Damage     MB8DP12DAL8138573
# 22  Stand Alone Own Damage     ME4JC67DBK8003293
# 65  Stand Alone Own Damage     ME1SED14AJ0042881
# 66          Package Policy    MALBB51BR9M122064M
# 58          Package Policy     MBHEWB22SKM407883
# 12          Package Policy    MALBM51BLFM193559M
# 51          Package Policy                  None
# 44          Package Policy                  None
# 9                     None     MA3NYFB1SKC520556
# 54                    None     MA3EDKD1S00290267
# 27          Package Policy                  None
# 60          Package Policy                  None
# 34        Liability Policy                  None
#
#                             start                           end      time
# 52                           None                          None  0.635562
# 23                           None                          None  3.486937
# 17                           None                          None  0.584177
# 15         17/04/2022 00:01 hours        midnight on 16/04/2023  0.470728
# 37         [00:00] of 12-Apr-2022                          None  1.364286
# 62         16 Jan, 2022 00:01 hrs                          None  0.708900
# 46         03 Feb, 2022 00:01 hrs                          None  1.364823
# 45         16 Jan, 2022 00:01 hrs                          None  2.697360
# 0          03 Nov, 2021 00:01 hrs                          None  2.554466
# 59         18 Jan, 2022 00:01 hrs          17/01/2023 Midnight   1.230346
# 41         24 Jan, 2022 00:01 hrs                          None  1.982419
# 63         01 Feb, 2022 00:01 hrs                          None  1.201335
# 48         30 Jan, 2022 00:01 hrs                          None  1.274642
# 61         02 Feb, 2022 00:01 hrs                          None  1.172944
# 53         31 Jan, 2022 00:01 hrs                          None  1.223492
# 8          20 Jan, 2022 00:01 hrs                          None  1.097651
# 32         16 Jan, 2022 00:01 hrs                          None  1.199855
# 3              02, 2022 12:00:00                           None  0.662312
# 42          03/11/2021 00:00:00\n        02/11/2022 23:59:59\n   1.967931
# 40          18/11/2021 00:00:00\n        17/11/2022 23:59:59\n   3.026156
# 2           07/02/2022 00:00:00\n        06/02/2023 23:59:59\n   0.906482
# 57          09/03/2022 00:00:00\n        08/03/2023 23:59:59\n   1.385370
# 16          27/02/2022 00:00:00\n        26/02/2023 23:59:59\n   1.283686
# 43          10/01/2022 00:00:00\n        09/01/2023 23:59:59\n   2.294039
# 24          02/01/2022 00:00:00\n        01/01/2023 23:59:59\n   2.725446
# 38          04/01/2022 00:00:00\n        03/01/2023 23:59:59\n   1.965521
# 50          03/02/2022 00:00:00\n        02/02/2023 23:59:59\n   3.317103
# 47          27/01/2022 00:00:00\n        26/01/2023 23:59:59\n   1.523913
# 7           05/01/2022 00:00:00\n        04/01/2023 23:59:59\n   2.654233
# 30              08/01/2022 00:00          07/01/2023Midnight\n   1.151772
# 31              11/10/2021 00:00          10/10/2022Midnight\n   1.121417
# 19              03/01/2022 00:00          02/01/2023Midnight\n   1.147491
# 55              09/01/2022 00:00          08/01/2023Midnight\n   1.589300
# 33              07/01/2022 00:00          06/01/2023Midnight\n   1.184362
# 39                           None         27/01/2023Midnight\n   1.151756
# 29                           None         10/01/2023Midnight\n   2.301914
# 49              19/01/2022 00:00          18/01/2023Midnight\n   1.436047
# 13                           None         01/02/2023Midnight\n   1.183410
# 11        00:00 Hrs of 14/04/2022        Midnight of 13/04/2023  0.716402
# 21         13-Apr-2022(00:00:00)                           None  0.749193
# 6          21-Apr-2022(00:00:00)                           None  0.778265
# 20        00:00 Hrs on 04-03-2022        Midnight on 03-03-2023  0.789042
# 26         15/04/2022 12:00:01 AM              14/04/2023 11:59  0.249340
# 35         20/04/2022 12:00:01 AM              19/04/2023 11:59  0.576754
# 5          14/04/2022 12:00:01 AM              13/04/2023 11:59  0.581620
# 25       00:00 Hrs on 21-Jan-2022       Mid Night of 20/01/2023  1.175577
# 1        00:00 Hrs on 21-Jan-2022       Mid Night of 20/01/2023  1.646710
# 18       00:00 Hrs on 08-Jan-2022       Mid Night of 07/01/2023  2.509951
# 64       00:00 Hrs on 06-Jan-2022                          None  1.594101
# 56       00:00 Hrs on 31-Jan-2022       Mid Night of 30/01/2023  2.462163
# 10       00:00 Hrs on 05-Jan-2022       Mid Night of 04/01/2023  1.146987
# 14       00:00 Hrs on 29-Oct-2021                          None  1.547550
# 36       00:00 Hrs on 16-Jan-2022                          None  1.568057
# 4        00:00 Hrs on 10-Jan-2022       Mid Night of 09/01/2023  1.146672
# 28       00:00 Hrs on 09-Feb-2022       Mid Night of 08/02/2023  1.124986
# 22       00:00 Hrs on 04-Feb-2022       Mid Night of 03/02/2023  1.124157
# 65       00:00 Hrs on 18-Feb-2022       Mid Night of 17/02/2023  1.078618
# 66       00:00 Hrs on 21-Jan-2022                          None  3.070352
# 58       00:00 Hrs on 10-Jan-2022       Mid Night of 09/01/2023  1.751265
# 12       00:00 Hrs on 07-Jan-2022                          None  2.691378
# 51       00:00 Hrs on 09-Jan-2022                          None  1.645686
# 44   00:00:00 hours on 07/04/2022  23:59:59 hours on 06/04/2023  0.832335
# 9           15/05/2022T00:00:00\n        14/05/2023 Midnight\n   1.807477
# 54          10/03/2022T00:00:00\n        09/03/2023 Midnight\n   1.390867
# 27       00:00 Hrs on 14-Apr-2022       Midnight on 13-Apr-2023  3.663383
# 60       00:00 Hrs on 09-Apr-2022       Midnight on 08-Apr-2023  5.401888
# 34       00:00 Hrs on 03-Mar-2022       Midnight on 02-Mar-2023  4.058838

# %%
len( "17/04/2022" )
# Out:
# 10

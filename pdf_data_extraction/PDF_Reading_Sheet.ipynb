# %%
import re
import os
import numpy as np
import pandas as pd
import pdfplumber
import time
from nltk.tokenize import word_tokenize

from IPython.display import display, HTML
from notebook.services.config import ConfigManager

display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Get all words on page in a list of lists. Each word is represented by:
# [x0, y0, x1, y1, word, bno, lno, wno]
# The first 4 entries are the word's rectangle coordinates, the last 3 are just
# technical info (block number, line number, word number).
# The term 'word' here stands for any string without space.
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def get_insurer_by_site(page):
    INSURERS = {
                "ACKO": "acko.com", "BAJAJ": "bajajallianz.com", "BHARTI": "bhartiaxa.com", "CHOLA": "cholainsurance.com",
                "EDELWEISS": "edelweissinsurance.com", "GODIGIT": "godigit.com", "HDFC": "hdfcergo.com", "ICICI": "icicilombard.com",
                "IFFICO-TOKIO": "iffcotokio.co.in", "KOTAK": "kotakgeneralinsurance.com", "LIBERTY": "libertyinsurance.in",
                "MAGMA": "magmahdi.com" , "NAVI": "navi.com", "NEW INDIA": "newindia.co.in", "NATIONAL": "nationalinsuranceindia.nic.co.in",
                "ORIENTAL": "orientalinsurance.org.in", "RELIANCE": "reliancegeneral.co.in", "ROYAL": "royalsundaram.in", "SBI": "sbigeneral.in",
                "SHRIRAM": "shriramgi.com", "TATA": "tataaig.com", "UNITED": "uiic.co.in"
               }
    
    for insurer in INSURERS:
        page_data = page.search( INSURERS[insurer], regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def get_insurer_by_name(page):
    INSURERS = [
        "ACKO", "BAJAJ", "BHARTI", "CHOLA", "EDELWEISS", "GODIGIT", "HDFC", "ICICI", "IFFICO-TOKIO", "KOTAK", "LIBERTY",
        "MAGMA", "NAVI", "NEW INDIA", "NATIONAL", "ORIENTAL", "RELIANCE", "ROYAL", "SBI", "SHRIRAM", "TATA", "UNITED"
    ]
  
    for insurer in INSURERS:
        page_data = page.search( insurer, regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def find_mobile( page ):
    page_data = page.search( r'\s(\+91\-|0)?[6-9X][0-9X]{9}(,|\s)', regex=True, case=False )
    if len( page_data ) and "mobile" not in data:
        data["mobile"] = page_data[0]["text"].strip()
        data["mobile"] = data["mobile"][0:-1] if data["mobile"][-1] == "," else data["mobile"]

# %%
def find_email(page):
    page_data = page.search( r'[a-z0-9\.\-]+@+(gmail|yahoo|outlook|hotmail)+(\.com|\.co\.in)+', regex=True, case=False )
    if len( page_data ) and "email" not in data:
        data["email"] = page_data[0]["text"].strip() if len( data ) else None

# %%
def find_vehicle_type( page ):
    type_regex = [ r'(two|2)\s?\-?\s?wheeler\s?', r'(four|4)\s?\-?\s?wheeler\s?', r'(MOTORCYCLE|SCOOTER|BIKE)', r'(private)?\s?\-?\s?(car\s|car$)' ]
    for i in range(4):
        if len( page.search( type_regex[i], regex=True, case=False ) ) > 0:
            data["type"] = "4W" if i%2 else "2W" 
            break
    
#     (policy|package|hybrid|comprehensive|certificate|secure)

# %%
def find_policy_type( page ):
    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Policy)?\s?\-?\s?Stand\s?\-?\s?alone\s?\-?\s?O(wn)?\s?D(amage)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Stand Alone Own Damage"
        return

#     page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?Package\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?', regex=True, case=False )
    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?(Package|Comprehensive)\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
#         data["policy_type"] = "Package Policy"
        data["policy_type"] = "Comprehensive Policy" if "comprehensive" in str(page_data[0]["text"]).lower else "Package Policy"
        return
    
#     page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?', regex=True, case=False )
#     if len( page_data ) and "insurance_type" not in data:
#         data["policy_type"] = "Comprehensive Policy"
#         return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Liability\s?\-?\s?(Only)?\s?\-?\s?(Policy)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Liability Policy"
        return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?(Package|Comprehensive)\s?\-?\s?(Policy)?\s?\-?\s?(Insurance)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Comprehensive Policy" if "comprehensive" in str(page_data[0]["text"]).lower else "Package Policy"
        return

#     page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Comprehensive\s?\-?\s?(Policy)?\s?\-?\s?(Insurance)?', regex=True, case=False )
#     if len( page_data ) and "insurance_type" not in data:
#         data["policy_type"] = "Comprehensive Policy"
#         return
    
    page_data = page.search( r'Liability\s?\-?\s?(Only)?\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?\s?\-?\s?Private\s?\-?\s?Car', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Liability Policy"
        return
    
    page_data = page.search( r'Comprehensive\s?\-?\s?Policy\s?\-?\s?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Comprehensive Policy"
        return

# %%
def find_reg_no( page ):
    page_data = page.search( r'Registration\s(No\s?\.?|Number|Mark)\s*:?\s*[A-Z]{2}\s?\-?\s?[0-9]{1,2}\s?\-?\s?[A-Z]{1,3}\s?\-?\s?[0-9]{2,5}', regex=True, case=False )
    if len( page_data ) > 0:
        reg_number = re.split('\s|\:', page_data[0]["text"] )[-1]
        data["reg_no"] = reg_number.replace( '-', "" )

# %%
def find_chassis_no( page ):
    page_data = page.search( r'Chass?is\s(No\s?\.?|Number)\s*:?\s*M[A-EZ][A-HJ-NPR-Z0-9]{14,19}', regex=True, case=False )
    if len( page_data ) > 0:
#         data["chassis_no"] = page_data[0]["text"]
#         print( "chassis", page_data[0]["text"] )
        chassis_number = re.split('\s|:', page_data[0]["text"] )[-1]
        data["chassis_no"] = chassis_number.replace( '-', "" )

# %%
def find_chassis_no_with_slash( page ):
    key = page.search( r'Chass?is\s(No\s?\.?|Number)\s?/', regex=True, case=False )
    if len( key ):
        chassis_number = page.search( r'M[A-EZ][A-HJ-NPR-Z0-9]{15,19}\s?/', regex=True, case=False )
        if len( chassis_number ) > 0:
            data["chassis_no"] = chassis_number[0]["text"].replace( r'\/', "" )
            return
    
    key = page.search( r'/\s?Chass?is\s(No\s?\.?|Number)', regex=True, case=False )
    if len( key ):
        chassis_number = page.search( r'/\s?M[A-EZ][A-HJ-NPR-Z0-9]{15,19}', regex=True, case=False )
        if len( chassis_number ) > 0:
            data["chassis_no"] = chassis_number[0]["text"].replace( r'\/', "" )
            return

# %%
def find_insured_name( page ):
    page_data = page.search( r'(Mr|Mrs?|M\/s)(\.\s?|\s)[A-Z]{1,20}\s[A-Z]{0,20}\s[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
#         print( page_data[0]["text"] )
        data["insurers_name"] = page_data[0]["text"]
        return
    
    page_data = page.search( r'insured(\'s)?\s*name(\s|\s?:\s?)(Mr|Mrs?|M\/s|Ms\.)?(\.\s?|\s)?s*[A-Z]{1,20}\s[A-Z]{0,20}\s[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
        insurer_name = re.sub( "Insured(\'s)?\s*Name\s*:?\s*", "", page_data[0]["text"] )
#         str(page_data[0]["text"]).replace( "", "", regex=True )
        data["insurers_name"] = insurer_name
#         print( "insurer name :  ", insurer_name )

# %%
def find_period(page):
#     date_time_regex = /([0-9]{2}[\-|\/|\s][[0-9]{2}|[a-z]{3}]+[\-|\/|\s|\,]+[20]?[1,2]+[0-9]+)[\s|\-|t]+([0-9]{2}\:[0-9]{2}\:?[0-9]{2}?)?\s?[hrs|hours]*/
#     time_date_regex = /([0-9]{2}\:[0-9]{2}\:?[0-9]{2}?)?\s?[hrs|hours]*\s?[of|on]*\s([0-9]{2}[\-|\/|\s][[0-9]{2}|[a-z]{3}]+[\-|\/|\s|\,]+[20]?[1,2]+[0-9]+)[\s|\-|\n]+/
    
    x = page.search( 'from', regex=True, case=False )
    print( page, [x[0]["text"], x[0]["x0"], x[0]["top"],  x[0]["x1"],  x[0]["bottom"] ] if len( x ) else "" )
    
    x = page.search( 'to', regex=True, case=False )
    print( page, [x[0]["text"], x[0]["x0"], x[0]["top"],  x[0]["x1"],  x[0]["bottom"] ] if len( x ) else "" )

# %%
df = pd.DataFrame( columns=[ "file", "pages", "insurers name", "type", "reg_no", "insurer", "phone", "email", "policy_type", "chassis_no", "time" ] )
files = os.listdir("./all_policy/Motor/misc")

count = 0

for file in files:
# for file in [ "hdfc10.pdf" ]:
    count += 1
    print( count, file )
    
    start_time = time.time()
    
    policy = pdfplumber.open( f'all_policy/Motor/misc/{file}' )
    
    insurer_count = {}
    data = {}

    for page in policy.pages:
        find_insured_name( page )
        get_insurer_by_site( page ) if "insurer" not in data else None
        find_mobile( page ) if "mobile" not in data else None
        find_email( page ) if "email" not in data else None
        find_vehicle_type( page ) if "type" not in data else None
        find_policy_type( page ) if "policy_type" not in data else None
        find_reg_no( page ) if "reg_no" not in data else None
        find_chassis_no( page ) if "chassis_no" not in data else None

        
    for page in policy.pages:
        if "insurer" not in data:
            get_insurer_by_name( page )
            
        if "chassis_no" not in data:
            find_chassis_no_with_slash( page )


    print( "data", data, "\n" )
    end_time = time.time()

    df.loc[ len( df.index ) ] = [ 
        file,
        len( policy.pages ),
        data["insurers_name"] if "insurers_name" in data else None,
        data["type"] if "type" in data else None,
        data["reg_no"] if "reg_no" in data else None,
        data["insurer"] if "insurer" in data else None,
        data["mobile"] if "mobile" in data else None,        
        data["email"] if "email" in data else None,
        data["policy_type"] if "policy_type" in data else None,
        data["chassis_no"] if "chassis_no" in data else None,
        ( end_time - start_time )
    ]
#     break
    
#     https://github.com/jsvine/pdfplumber
# Out:
# 1 hdfc13_4w.pdf
# data {'insurers_name': 'MR MAYUR MADHUKAR PATIL', 'mobile': '9096749797', 'email': 'mayur.m.patil9@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'MH11AW9594', 'chassis_no': 'MCA11835E07029773EMZ', 'insurer': 'HDFC'}
#
# 2 reliance11_4w.pdf
# data {'insurers_name': 'MS.PRIYA AWASTHI ', 'mobile': '8433707105', 'email': 'dhirajawasthi@yahoo.com', 'type': '4W', 'reg_no': 'GJ15CK8239', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy'}
#
# 3 iffco1_4w.pdf
# data {'mobile': 'XXXXXXX741', 'insurer': 'IFFICO-TOKIO', 'type': '4W'}
#
# 4 icici1_2w.pdf
# data {'insurer': 'ICICI', 'mobile': '9356278702', 'type': '2W', 'reg_no': 'TS09EE9725', 'chassis_no': 'ME4JF502LET601661', 'email': '2000@YAHOO.COM', 'policy_type': 'Package Policy'}
#
# 5 reliance2_2w.pdf
# data {'insurers_name': 'MR.B SENTHIL KUMAR', 'mobile': '8433707105', 'email': 'senthilkumar@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'TN12AH5335', 'insurer': 'RELIANCE', 'chassis_no': 'MD2A55F5KCJ07279'}
#
# 6 newindia-4w-tp.pdf
# data {'insurer': 'NEW INDIA', 'type': '4W', 'policy_type': 'Liability Policy', 'insurers_name': 'BIKRAM HAZARIKA ', 'mobile': 'XXXXXX0262', 'email': 'akashchetry799@gmail.com', 'reg_no': 'AS12M6347', 'chassis_no': 'MA3ERLF1S00399960/'}
#
# 7 national-4w-comp.pdf
# data {'insurers_name': 'Mr. Edward I ', 'insurer': 'NATIONAL', 'mobile': '9916098981', 'email': 'edwardlawson87@gmail.com', 'type': '4W', 'policy_type': 'Package Policy'}
#
# 8 iffco9_2w.pdf
# data {'insurers_name': 'RAMNARESH GODARA ', 'mobile': 'XXXXXXX100', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 9 hdfc8_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '9900466863', 'email': 'dhanukumar110@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'KA42EB9744', 'chassis_no': 'ME4JF50AALA134302'}
#
# 10 sbi-4w-comp.pdf
# data {'insurers_name': 'Mr. CHINTHALA PREETHI\n', 'insurer': 'SBI', 'mobile': '+91-9052928520', 'type': '4W', 'reg_no': 'TS08GN1666', 'chassis_no': 'MA3NYFB1SKC520556'}
#
# 11 reliance15_2w.pdf
# data {'insurers_name': 'MR.HIMANSHU KUMAR ', 'mobile': '8433707105', 'email': 'Himanshukum@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'DL13SU5840', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JF507KH7361902'}
#
# 12 magma-4w-comp.pdf
# data {'insurers_name': 'Mrs. Mrsjayshreeben Kamleshkumar Prajapati', 'insurer': 'MAGMA', 'mobile': '9725056102', 'email': 'primekamlesh@gmail.com', 'type': '4W', 'policy_type': 'Package Policy'}
#
# 13 reliance8_car.pdf
# data {'insurers_name': 'MR.PRABHAKAR PANDEY ', 'mobile': '8433707105', 'email': 'pankaj.singh.garud@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'UP60AA1991', 'insurer': 'RELIANCE', 'chassis_no': 'MALBM51BLFM193559M'}
#
# 14 kotak9_2w.pdf
# data {'insurer': 'KOTAK', 'mobile': '8409305280', 'type': '2W', 'insurers_name': 'Mr. Vikash Andani ', 'email': 'RAMKUMARITBP1988@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 15 reliance16_4w.pdf
# data {'insurers_name': 'MR.MOHAMMAD RUSTUM BHAT', 'mobile': '8433707105', 'email': 'hilaljmi12@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'JK13C7701', 'insurer': 'RELIANCE', 'chassis_no': 'MA3EWDE1S00894649'}
#
# 16 chola-2w-comp.pdf
# data {'insurer': 'CHOLA', 'mobile': '9841198260', 'type': '2W', 'reg_no': 'TN10BC4732', 'chassis_no': 'MD626AG78J2D14142'}
#
# 17 iffco3_2w.pdf
# data {'insurers_name': 'N VARADARAJAN ', 'mobile': 'XXXXXXX101', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 18 acko-4w-tp.pdf
# data {'insurers_name': 'TEISOVINUO LOTHA ', 'insurer': 'ACKO', 'mobile': 'XXXXXX8324', 'email': 'sXXXXXXXXXXXXXXXXXXXX6@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'NL07T0267'}
#
# 19 reliance12_2w.pdf
# data {'insurers_name': 'MR.MR RAVEENDRAN ', 'mobile': '8433707105', 'email': 'anugrahameppayur@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'KL77A9698', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP12DML8474223'}
#
# 20 kotak2_2w.pdf
# data {'insurers_name': 'Mr. Netaji Shivaji Jadhav', 'insurer': 'KOTAK', 'mobile': '8149445455', 'type': '2W', 'email': 'GANESHDZIRE@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 21 navi-4w-tp.pdf
# data {'insurer': 'NAVI', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'KA03ML1507', 'chassis_no': 'MALAM51CR9M333424'}
#
# 22 national-2w-comp.pdf
# data {'insurers_name': 'Mr. Amit Ratnakar Pagare', 'insurer': 'NATIONAL', 'mobile': '9890085085', 'email': 'contactpagare@gmail.com', 'type': '2W', 'policy_type': 'Package Policy'}
#
# 23 reliance4_2w.pdf
# data {'insurers_name': 'MR.SITA RAM BAIRWA', 'mobile': '8433707105', 'email': 'jp9433344@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'RJ14AJ7933', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JC67DBK8003293'}
#
# 24 acko-4w-comp.pdf
# data {'insurer': 'ACKO', 'email': 'iXXXXXXXXXXXXXXXXXXXa@yahoo.co.in', 'type': '4W', 'policy_type': 'Package Policy', 'insurers_name': 'MANJU ISHWERI NARAYAN', 'reg_no': 'MH03BS0277', 'chassis_no': 'MAT612354EKD08300', 'mobile': 'XXXXXX2426'}
#
# 25 iffco5_2w.pdf
# data {'insurers_name': 'ALAGAPPAN AL ', 'mobile': 'XXXXXXX195', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 26 reliance10_2w.pdf
# data {'insurers_name': 'MR.AKASH KUMAR SINGH', 'mobile': '8433707105', 'email': 'akashikka@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'KA51Y5671', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JC448BB8090424'}
#
# 27 newindia-2w-comp.pdf
# data {'insurers_name': 'RUPAM DAS ', 'insurer': 'NEW INDIA', 'mobile': 'XXXXXX6455', 'email': 'noonmati020@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'AS01DB1446', 'chassis_no': 'MB8NG4BAHG8239880/'}
#
# 28 united-2w-comp.pdf
# data {'insurer': 'UNITED', 'mobile': '9671732414', 'type': '2W', 'email': 'gurmeet3093@gmail.com'}
#
# 29 reliance3_2w.pdf
# data {'insurers_name': 'MS.SHANTHI S ', 'mobile': '8433707105', 'email': 'rajthanga0123@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'PY01CW1342', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP12DAL8138573'}
#
# 30 kotak7_2w.pdf
# data {'insurers_name': 'Mr. Prabhuraj K Hosamani', 'insurer': 'KOTAK', 'mobile': '8951618891', 'type': '2W', 'email': 'BAJARANGIPKH@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 31 kotak10_2w.pdf
# data {'insurer': 'KOTAK', 'mobile': '8533990227', 'type': '2W', 'insurers_name': 'Mrs. Reetu Kumari ', 'email': 'REETUREETU141@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 32 kotak11_2w.pdf
# data {'insurers_name': 'Mr. Bharat Yashwant Bangar', 'insurer': 'KOTAK', 'mobile': '9594880123', 'type': '2W', 'email': 'DOSTITOUR@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 33 hdfc9_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '7979971843', 'email': 'navneetbhg2020@gmail.com', 'type': '2W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'JH01BC4249', 'chassis_no': 'ME4JC36KKD7311586'}
#
# 34 kotak5_2w.pdf
# data {'insurers_name': 'Mr. Sudesh R Morajkar', 'insurer': 'KOTAK', 'mobile': '9822122510', 'type': '2W', 'email': 'SUDESH.ARTIS@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 35 united-4w-tp.pdf
# data {'insurer': 'UNITED', 'mobile': '7904149939', 'type': '4W', 'email': 'veludivxece2018@gmail.com', 'policy_type': 'Liability Policy'}
#
# 36 newindia-4w-comp.pdf
# data {'insurer': 'NEW INDIA', 'type': '4W', 'policy_type': 'Package Policy', 'insurers_name': 'GAURAV GOEL ', 'mobile': 'XXXXXX8030', 'email': 'goel209@yahoo.co.in', 'reg_no': 'HR26CD8127'}
#
# 37 reliance1_4w.pdf
# data {'insurers_name': 'MR.RAMAKANTA SAMAL ', 'mobile': '8433707105', 'email': 'niraj.samal@hotmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'OD02AA4963', 'insurer': 'RELIANCE', 'chassis_no': 'MALA841CLFM151684'}
#
# 38 edel-4w-comp.pdf
# data {'insurers_name': 'Mr. Pronojit Sen ', 'type': '4W', 'policy_type': 'Package Policy', 'insurer': 'EDELWEISS'}
#
# 39 iffco6_2w.pdf
# data {'insurers_name': 'BRAJESH KUMAR ', 'mobile': 'XXXXXXX810', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 40 kotak6_2w.pdf
# data {'insurer': 'KOTAK', 'mobile': '9741111668', 'type': '2W', 'insurers_name': 'Mr. Suman Bn ', 'email': 'SUMANBN668@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 41 iffco11_2w.pdf
# data {'insurers_name': 'SUDHIR JAIN ', 'mobile': 'XXXXXXX830', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 42 hdfc2_4w.pdf
# data {'insurers_name': 'M/S RAJ KUMAR KAIN', 'mobile': '7982382088', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL08CNB8249', 'insurer': 'HDFC'}
#
# 43 iffco10_2w.pdf
# data {'insurers_name': 'RAJASEKHAR CH ', 'mobile': 'XXXXXXX689', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 44 iffco4_2w.pdf
# data {'insurers_name': 'RAKESH KUMAR MAURYA', 'mobile': 'XXXXXXX540', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 45 royalsundaram-4w-comp.pdf
# data {'insurers_name': 'Mr. LAVJIBHAI MOHANBHAI HAPALIYA', 'insurer': 'ROYAL', 'mobile': 'xxxxxx5540', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'GJ5JP5327'}
#
# 46 hdfc12_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '9902059738', 'email': 'jagadeeshae7272@gmail.com', 'type': '2W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'KA53EM8787'}
#
# 47 hdfc11_4w.pdf
# data {'insurers_name': 'MR BEERAIAH B ', 'mobile': '9731138386', 'email': 'prakashmbangalore@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA53C7581', 'chassis_no': 'MAT600185GPJ34888', 'insurer': 'HDFC'}
#
# 48 iffco8_2w.pdf
# data {'insurers_name': 'MADHAV RADHEYSHYAM KATIYAR', 'mobile': 'XXXXXXX720', 'type': '2W', 'insurer': 'IFFICO-TOKIO'}
#
# 49 hdfc5_4w.pdf
# data {'insurers_name': 'MR KRISHNAMURTHY KIKKISETTI RTO', 'mobile': '9742723000', 'email': 'kkmurty93@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA03MX4830', 'chassis_no': 'MEEBBA002G1325553', 'insurer': 'HDFC'}
#
# 50 kotak8_4w.pdf
# data {'insurer': 'KOTAK', 'mobile': '9700643243', 'type': '4W', 'insurers_name': 'Mrs. Leelavathi B ', 'email': 'RAMYABHARGAVI.BUJJE@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 51 iffco7_4w.pdf
# data {'mobile': 'XXXXXXX674', 'insurer': 'IFFICO-TOKIO', 'type': '4W'}
#
# 52 reliance9_car.pdf
# data {'insurers_name': 'MR.PRAMOD SINGH RANA', 'mobile': '8433707105', 'email': 'atienter2010@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL02CAZ7876', 'insurer': 'RELIANCE'}
#
# 53 acko-2w-comp.pdf
# data {'insurers_name': 'Geetinder Singh ', 'insurer': 'ACKO', 'mobile': 'XXXXXX9111', 'email': 'gXXXXXXXXXXXXi@yahoo.com', 'type': '2W', 'reg_no': 'PB10FS2630', 'chassis_no': 'ME3U3K5C0GD042682'}
#
# 54 hdfc7_4w.pdf
# data {'insurers_name': 'MR SANDEEP KUMAR ', 'mobile': '9646689689', 'email': 'harpreetsharma097@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'CH01AE2802', 'chassis_no': 'MA3EWDE1S00176139', 'insurer': 'HDFC'}
#
# 55 sbi-4w-tp.pdf
# data {'insurers_name': 'Mr. MANISH SHARMA\n', 'insurer': 'SBI', 'mobile': '+91-9818077949', 'reg_no': 'DL2CAN2618', 'chassis_no': 'MA3EDKD1S00290267', 'type': '4W'}
#
# 56 kotak3_2w.pdf
# data {'insurers_name': 'Mr. Amol Jugalkishor Heda', 'insurer': 'KOTAK', 'mobile': '9845316882', 'type': '2W', 'email': 'MOHITSR76@GMAIL.COM', 'policy_type': 'Comprehensive Policy'}
#
# 57 reliance14_2w.pdf
# data {'insurers_name': 'MR.SUNDARABABU R ', 'mobile': '8433707105', 'email': 'rajthanga0123@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'PY05F2934', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP11ALJ8A62610'}
#
# 58 iffco2_4w.pdf
# data {'mobile': 'XXXXXXX114', 'insurer': 'IFFICO-TOKIO', 'type': '4W'}
#
# 59 reliance7_4w.pdf
# data {'insurers_name': 'MR.MR SANKHA NARAYAN', 'mobile': '8433707105', 'email': 'surzeett@gmail.com', 'type': '4W', 'reg_no': 'AS06AA5025', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy', 'chassis_no': 'MBHEWB22SKM407883'}
#
# 60 hdfc1_4w.pdf
# data {'insurers_name': 'MR PARIKSHIT MALHOTRA ', 'insurer': 'HDFC', 'mobile': '9418450772', 'email': 'drpm1972@gmail.com', 'type': '4W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'HP33F5772'}
#
# 61 united-4w-comp.pdf
# data {'insurer': 'UNITED', 'mobile': '9873621425', 'type': '4W', 'policy_type': 'Package Policy'}
#
# 62 hdfc6_2W.pdf
# data {'insurer': 'HDFC', 'mobile': '8882746998', 'email': 'pankajali786@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'DL08SCR0181', 'chassis_no': 'MD626AG74K2E23103'}
#
# 63 hdfc10_4w.pdf
# data {'insurers_name': 'MR MANJU DEVI ', 'mobile': '9816086889', 'email': 'chandan.ranote@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'HP12D2172', 'chassis_no': 'MALAA51HR9M486097L', 'insurer': 'HDFC'}
#
# 64 hdfc3_4w.pdf
# data {'insurers_name': 'MR HARI OM ', 'mobile': '7983119833', 'email': 'sksmtr.sk@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL03CCN5760', 'chassis_no': 'MA3EWDE1S00D50948', 'insurer': 'HDFC'}
#
# 65 reliance13_4w.pdf
# data {'insurers_name': 'MR.ASHWATHANARAYAN M ', 'mobile': '8433707105', 'email': 'bmvishnu.vs@yahoo.co.in', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA43M8588', 'insurer': 'RELIANCE'}
#
# 66 reliance5_2w.pdf
# data {'insurers_name': 'MS.ASTALAKSHMI R ', 'mobile': '8433707105', 'email': 'SKFINANCE01@GMAIL.COM', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'TN11AK9898', 'insurer': 'RELIANCE', 'chassis_no': 'ME1SED14AJ0042881'}
#
# 67 reliance6_4w.pdf
# data {'insurers_name': 'MR.RAKESH BALDEVBHAI PATEL', 'mobile': '8433707105', 'email': 'rakesh11566@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'GJ06DG2771', 'insurer': 'RELIANCE', 'chassis_no': 'MALBB51BR9M122064M'}

# %%
re.split('(Insured|Name|:\s)', "Insured's Name: MADHAV RADHEYSHYAM KATIYAR" )[-1]
# Out:
# 'MADHAV RADHEYSHYAM KATIYAR'

# %%
df = df.sort_values("time")
# df.filter( ["file", "chassis_no"] )
df
# Out:
#                          file  pages  \
# 26       newindia-2w-comp.pdf      3
# 15          chola-2w-comp.pdf      2
# 17             acko-4w-tp.pdf      2
# 35       newindia-4w-comp.pdf      7
# 11          magma-4w-comp.pdf      2
# 5          newindia-4w-tp.pdf      7
# 52           acko-2w-comp.pdf      2
# 3               icici1_2w.pdf      2
# 20             navi-4w-tp.pdf      8
# 6        national-4w-comp.pdf      2
# 62              hdfc10_4w.pdf      2
# 44  royalsundaram-4w-comp.pdf      4
# 21       national-2w-comp.pdf      2
# 22           reliance4_2w.pdf      6
# 49              kotak8_4w.pdf      9
# 56          reliance14_2w.pdf      6
# 13              kotak9_2w.pdf     11
# 48               hdfc5_4w.pdf      3
# 19              kotak2_2w.pdf     10
# 30             kotak10_2w.pdf     10
# 55              kotak3_2w.pdf     10
# 0               hdfc13_4w.pdf      3
# 42             iffco10_2w.pdf      3
# 61               hdfc6_2W.pdf      3
# 65           reliance5_2w.pdf      6
# 10          reliance15_2w.pdf      6
# 53               hdfc7_4w.pdf      3
# 31             kotak11_2w.pdf     10
# 4            reliance2_2w.pdf      6
# 39              kotak6_2w.pdf     11
# 63               hdfc3_4w.pdf      3
# 32               hdfc9_2w.pdf      3
# 25          reliance10_2w.pdf      6
# 57              iffco2_4w.pdf      4
# 46              hdfc11_4w.pdf      3
# 7               iffco9_2w.pdf      4
# 40             iffco11_2w.pdf      4
# 37           edel-4w-comp.pdf      3
# 29              kotak7_2w.pdf     11
# 16              iffco3_2w.pdf      4
# 47              iffco8_2w.pdf      4
# 38              iffco6_2w.pdf      4
# 51          reliance9_car.pdf     11
# 14          reliance16_4w.pdf     11
# 58           reliance7_4w.pdf     11
# 1           reliance11_4w.pdf     11
# 66           reliance6_4w.pdf     11
# 43              iffco4_2w.pdf      4
# 9             sbi-4w-comp.pdf     17
# 41               hdfc2_4w.pdf      3
# 28           reliance3_2w.pdf      6
# 8                hdfc8_2w.pdf      3
# 45              hdfc12_2w.pdf      3
# 2               iffco1_4w.pdf      3
# 33              kotak5_2w.pdf     10
# 18          reliance12_2w.pdf      6
# 59               hdfc1_4w.pdf      3
# 54              sbi-4w-tp.pdf     13
# 36           reliance1_4w.pdf     11
# 50              iffco7_4w.pdf      5
# 12          reliance8_car.pdf     11
# 24              iffco5_2w.pdf      4
# 34           united-4w-tp.pdf      8
# 64          reliance13_4w.pdf     11
# 23           acko-4w-comp.pdf      6
# 27         united-2w-comp.pdf      9
# 60         united-4w-comp.pdf     10
#
#                                  insurers name type       reg_no  \
# 26                                  RUPAM DAS    2W   AS01DB1446
# 15                                        None   2W   TN10BC4732
# 17                           TEISOVINUO LOTHA    4W    NL07T0267
# 35                                GAURAV GOEL    4W   HR26CD8127
# 11  Mrs. Mrsjayshreeben Kamleshkumar Prajapati   4W         None
# 5                             BIKRAM HAZARIKA    4W    AS12M6347
# 52                            Geetinder Singh    2W   PB10FS2630
# 3                                         None   2W   TS09EE9725
# 20                                        None   4W   KA03ML1507
# 6                                Mr. Edward I    4W         None
# 62                              MR MANJU DEVI    4W    HP12D2172
# 44            Mr. LAVJIBHAI MOHANBHAI HAPALIYA   4W    GJ5JP5327
# 21                    Mr. Amit Ratnakar Pagare   2W         None
# 22                          MR.SITA RAM BAIRWA   2W   RJ14AJ7933
# 49                          Mrs. Leelavathi B    4W         None
# 56                           MR.SUNDARABABU R    2W    PY05F2934
# 13                          Mr. Vikash Andani    2W         None
# 48             MR KRISHNAMURTHY KIKKISETTI RTO   4W   KA03MX4830
# 19                   Mr. Netaji Shivaji Jadhav   2W         None
# 30                          Mrs. Reetu Kumari    2W         None
# 55                   Mr. Amol Jugalkishor Heda   2W         None
# 0                      MR MAYUR MADHUKAR PATIL   4W   MH11AW9594
# 42                              RAJASEKHAR CH    2W         None
# 61                                        None   2W  DL08SCR0181
# 65                           MS.ASTALAKSHMI R    2W   TN11AK9898
# 10                          MR.HIMANSHU KUMAR    2W   DL13SU5840
# 53                           MR SANDEEP KUMAR    4W   CH01AE2802
# 31                  Mr. Bharat Yashwant Bangar   2W         None
# 4                           MR.B SENTHIL KUMAR   2W   TN12AH5335
# 39                               Mr. Suman Bn    2W         None
# 63                                 MR HARI OM    4W  DL03CCN5760
# 32                                        None   2W   JH01BC4249
# 25                        MR.AKASH KUMAR SINGH   2W    KA51Y5671
# 57                                        None   4W         None
# 46                              MR BEERAIAH B    4W    KA53C7581
# 7                            RAMNARESH GODARA    2W         None
# 40                                SUDHIR JAIN    2W         None
# 37                           Mr. Pronojit Sen    4W         None
# 29                    Mr. Prabhuraj K Hosamani   2W         None
# 16                              N VARADARAJAN    2W         None
# 47                  MADHAV RADHEYSHYAM KATIYAR   2W         None
# 38                              BRAJESH KUMAR    2W         None
# 51                        MR.PRAMOD SINGH RANA   4W  DL02CAZ7876
# 14                     MR.MOHAMMAD RUSTUM BHAT   4W    JK13C7701
# 58                        MR.MR SANKHA NARAYAN   4W   AS06AA5025
# 1                            MS.PRIYA AWASTHI    4W   GJ15CK8239
# 66                  MR.RAKESH BALDEVBHAI PATEL   4W   GJ06DG2771
# 43                         RAKESH KUMAR MAURYA   2W         None
# 9                      Mr. CHINTHALA PREETHI\n   4W   TS08GN1666
# 41                          M/S RAJ KUMAR KAIN   4W  DL08CNB8249
# 28                               MS.SHANTHI S    2W   PY01CW1342
# 8                                         None   2W   KA42EB9744
# 45                                        None   2W   KA53EM8787
# 2                                         None   4W         None
# 33                       Mr. Sudesh R Morajkar   2W         None
# 18                           MR.MR RAVEENDRAN    2W    KL77A9698
# 59                      MR PARIKSHIT MALHOTRA    4W    HP33F5772
# 54                         Mr. MANISH SHARMA\n   4W   DL2CAN2618
# 36                         MR.RAMAKANTA SAMAL    4W   OD02AA4963
# 50                                        None   4W         None
# 12                        MR.PRABHAKAR PANDEY    4W   UP60AA1991
# 24                               ALAGAPPAN AL    2W         None
# 34                                        None   4W         None
# 64                       MR.ASHWATHANARAYAN M    4W    KA43M8588
# 23                       MANJU ISHWERI NARAYAN   4W   MH03BS0277
# 27                                        None   2W         None
# 60                                        None   4W         None
#
#          insurer           phone                              email  \
# 26     NEW INDIA      XXXXXX6455              noonmati020@gmail.com
# 15         CHOLA      9841198260                               None
# 17          ACKO      XXXXXX8324   sXXXXXXXXXXXXXXXXXXXX6@gmail.com
# 35     NEW INDIA      XXXXXX8030                goel209@yahoo.co.in
# 11         MAGMA      9725056102             primekamlesh@gmail.com
# 5      NEW INDIA      XXXXXX0262           akashchetry799@gmail.com
# 52          ACKO      XXXXXX9111           gXXXXXXXXXXXXi@yahoo.com
# 3          ICICI      9356278702                     2000@YAHOO.COM
# 20          NAVI            None                               None
# 6       NATIONAL      9916098981           edwardlawson87@gmail.com
# 62          HDFC      9816086889           chandan.ranote@gmail.com
# 44         ROYAL      xxxxxx5540                               None
# 21      NATIONAL      9890085085            contactpagare@gmail.com
# 22      RELIANCE      8433707105                jp9433344@gmail.com
# 49         KOTAK      9700643243      RAMYABHARGAVI.BUJJE@GMAIL.COM
# 56      RELIANCE      8433707105            rajthanga0123@gmail.com
# 13         KOTAK      8409305280         RAMKUMARITBP1988@GMAIL.COM
# 48          HDFC      9742723000                kkmurty93@gmail.com
# 19         KOTAK      8149445455              GANESHDZIRE@GMAIL.COM
# 30         KOTAK      8533990227            REETUREETU141@GMAIL.COM
# 55         KOTAK      9845316882                MOHITSR76@GMAIL.COM
# 0           HDFC      9096749797           mayur.m.patil9@gmail.com
# 42  IFFICO-TOKIO      XXXXXXX689                               None
# 61          HDFC      8882746998             pankajali786@gmail.com
# 65      RELIANCE      8433707105              SKFINANCE01@GMAIL.COM
# 10      RELIANCE      8433707105              Himanshukum@gmail.com
# 53          HDFC      9646689689        harpreetsharma097@gmail.com
# 31         KOTAK      9594880123                DOSTITOUR@GMAIL.COM
# 4       RELIANCE      8433707105             senthilkumar@gmail.com
# 39         KOTAK      9741111668               SUMANBN668@GMAIL.COM
# 63          HDFC      7983119833                sksmtr.sk@gmail.com
# 32          HDFC      7979971843           navneetbhg2020@gmail.com
# 25      RELIANCE      8433707105                akashikka@gmail.com
# 57  IFFICO-TOKIO      XXXXXXX114                               None
# 46          HDFC      9731138386        prakashmbangalore@gmail.com
# 7   IFFICO-TOKIO      XXXXXXX100                               None
# 40  IFFICO-TOKIO      XXXXXXX830                               None
# 37     EDELWEISS            None                               None
# 29         KOTAK      8951618891             BAJARANGIPKH@GMAIL.COM
# 16  IFFICO-TOKIO      XXXXXXX101                               None
# 47  IFFICO-TOKIO      XXXXXXX720                               None
# 38  IFFICO-TOKIO      XXXXXXX810                               None
# 51      RELIANCE      8433707105             atienter2010@gmail.com
# 14      RELIANCE      8433707105               hilaljmi12@gmail.com
# 58      RELIANCE      8433707105                 surzeett@gmail.com
# 1       RELIANCE      8433707105            dhirajawasthi@yahoo.com
# 66      RELIANCE      8433707105              rakesh11566@gmail.com
# 43  IFFICO-TOKIO      XXXXXXX540                               None
# 9            SBI  +91-9052928520                               None
# 41          HDFC      7982382088                               None
# 28      RELIANCE      8433707105            rajthanga0123@gmail.com
# 8           HDFC      9900466863            dhanukumar110@gmail.com
# 45          HDFC      9902059738          jagadeeshae7272@gmail.com
# 2   IFFICO-TOKIO      XXXXXXX741                               None
# 33         KOTAK      9822122510             SUDESH.ARTIS@GMAIL.COM
# 18      RELIANCE      8433707105         anugrahameppayur@gmail.com
# 59          HDFC      9418450772                 drpm1972@gmail.com
# 54           SBI  +91-9818077949                               None
# 36      RELIANCE      8433707105            niraj.samal@hotmail.com
# 50  IFFICO-TOKIO      XXXXXXX674                               None
# 12      RELIANCE      8433707105       pankaj.singh.garud@gmail.com
# 24  IFFICO-TOKIO      XXXXXXX195                               None
# 34        UNITED      7904149939          veludivxece2018@gmail.com
# 64      RELIANCE      8433707105            bmvishnu.vs@yahoo.co.in
# 23          ACKO      XXXXXX2426  iXXXXXXXXXXXXXXXXXXXa@yahoo.co.in
# 27        UNITED      9671732414              gurmeet3093@gmail.com
# 60        UNITED      9873621425                               None
#
#                policy_type            chassis_no      time
# 26          Package Policy    MB8NG4BAHG8239880/  0.422167
# 15                    None     MD626AG78J2D14142  0.486808
# 17        Liability Policy                  None  0.579974
# 35          Package Policy                  None  0.616491
# 11          Package Policy                  None  0.631324
# 5         Liability Policy    MA3ERLF1S00399960/  0.633295
# 52                    None     ME3U3K5C0GD042682  0.650385
# 3           Package Policy     ME4JF502LET601661  0.679280
# 20        Liability Policy     MALAM51CR9M333424  0.760944
# 6           Package Policy                  None  0.788348
# 62        Liability Policy    MALAA51HR9M486097L  0.801672
# 44          Package Policy                  None  0.820941
# 21          Package Policy                  None  0.846969
# 22  Stand Alone Own Damage     ME4JC67DBK8003293  1.100024
# 49    Comprehensive Policy                  None  1.102801
# 56  Stand Alone Own Damage     MB8DP11ALJ8A62610  1.108500
# 13    Comprehensive Policy                  None  1.125400
# 48          Package Policy     MEEBBA002G1325553  1.140115
# 19    Comprehensive Policy                  None  1.143968
# 30    Comprehensive Policy                  None  1.148783
# 55    Comprehensive Policy                  None  1.150004
# 0           Package Policy  MCA11835E07029773EMZ  1.174805
# 42                    None                  None  1.176893
# 61  Stand Alone Own Damage     MD626AG74K2E23103  1.191339
# 65  Stand Alone Own Damage     ME1SED14AJ0042881  1.224342
# 10          Package Policy     ME4JF507KH7361902  1.225856
# 53          Package Policy     MA3EWDE1S00176139  1.231493
# 31    Comprehensive Policy                  None  1.236938
# 4   Stand Alone Own Damage      MD2A55F5KCJ07279  1.241388
# 39    Comprehensive Policy                  None  1.266602
# 63          Package Policy     MA3EWDE1S00D50948  1.284289
# 32    Comprehensive Policy     ME4JC36KKD7311586  1.303348
# 25          Package Policy     ME4JC448BB8090424  1.312670
# 57                    None                  None  1.337669
# 46          Package Policy     MAT600185GPJ34888  1.351901
# 7                     None                  None  1.363789
# 40                    None                  None  1.366081
# 37          Package Policy                  None  1.384159
# 29    Comprehensive Policy                  None  1.392113
# 16                    None                  None  1.401200
# 47                    None                  None  1.488651
# 38                    None                  None  1.610921
# 51          Package Policy                  None  1.616321
# 14          Package Policy     MA3EWDE1S00894649  1.632955
# 58          Package Policy     MBHEWB22SKM407883  1.653730
# 1           Package Policy                  None  1.709514
# 66          Package Policy    MALBB51BR9M122064M  1.759327
# 43                    None                  None  1.783460
# 9                     None     MA3NYFB1SKC520556  1.977999
# 41          Package Policy                  None  2.121598
# 28  Stand Alone Own Damage     MB8DP12DAL8138573  2.212539
# 8   Stand Alone Own Damage     ME4JF50AALA134302  2.254611
# 45    Comprehensive Policy                  None  2.279528
# 2                     None                  None  2.317247
# 33    Comprehensive Policy                  None  2.328461
# 18  Stand Alone Own Damage     MB8DP12DML8474223  2.425520
# 59    Comprehensive Policy                  None  2.468072
# 54                    None     MA3EDKD1S00290267  2.489295
# 36          Package Policy     MALA841CLFM151684  2.676087
# 50                    None                  None  2.700984
# 12          Package Policy    MALBM51BLFM193559M  2.777549
# 24                    None                  None  2.901787
# 34        Liability Policy                  None  2.915656
# 64          Package Policy                  None  2.924363
# 23          Package Policy     MAT612354EKD08300  4.101108
# 27                    None                  None  4.214212
# 60          Package Policy                  None  4.568778

# %%
len( "ASHWATHANARAYAN" )
# Out:
# 15

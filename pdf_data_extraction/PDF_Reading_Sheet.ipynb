# %%
import re
import os
import numpy as np
import pandas as pd
import pdfplumber
import time
from nltk.tokenize import word_tokenize

from IPython.display import display, HTML
from notebook.services.config import ConfigManager

display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Get all words on page in a list of lists. Each word is represented by:
# [x0, y0, x1, y1, word, bno, lno, wno]
# The first 4 entries are the word's rectangle coordinates, the last 3 are just
# technical info (block number, line number, word number).
# The term 'word' here stands for any string without space.
# Out:
# <style>.container { width:100% !important; }</style>

# %%
all_mmv_chassis_sheet = pd.read_csv('../pdf_data_extraction/all_policy/data/ChasisAll.csv')
ALL_MAKES = list( all_mmv_chassis_sheet["make"].unique() )
ALL_MAKE_MODEL = {}

for make in ALL_MAKES:
    ALL_MAKE_MODEL[ make ] = list( all_mmv_chassis_sheet[ all_mmv_chassis_sheet["make"] == "Mahindra" ]["model"].unique() )

# %%
def find_insurer_by_site(page):
    INSURERS = {
                "ACKO": "acko.com", "BAJAJ": "bajajallianz.com", "BHARTI": "bharti-axagi.co.in", "CHOLA": "cholainsurance.com",
                "EDELWEISS": "edelweissinsurance.com", "GODIGIT": "godigit.com", "HDFC": "hdfcergo.com", "HDFC": "hdfcgi.com", "ICICI": "icicilombard.com",
                "IFFICO": "iffcotokio.co.in", "KOTAK": "kotakgeneralinsurance.com", "LIBERTY": "libertyinsurance.in",
                "MAGMA": "magmahdi.com" , "NAVI": "navi.com", "NEW INDIA": "newindia.co.in", "NATIONAL": "nationalinsuranceindia.nic.co.in",
                "ORIENTAL": "orientalinsurance.org.in", "RELIANCE": "reliancegeneral.co.in", "ROYAL": "royalsundaram.in", "SBI": "sbigeneral.in",
                "SHRIRAM": "shriramgi.com", "TATA": "tataaig.com", "UNITED": "uiic.co.in"
               }
    
    for insurer in INSURERS:
        page_data = page.search( INSURERS[insurer], regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def get_insurer_by_name(page):
    INSURERS = [
        "ACKO", "BAJAJ", "BHARTI", "CHOLA", "EDELWEISS", "GODIGIT", "HDFC", "ICICI", "IFFICO", "KOTAK", "LIBERTY",
        "MAGMA", "NAVI", "NEW INDIA", "NATIONAL", "ORIENTAL", "RELIANCE", "ROYAL", "SBI", "SHRIRAM", "TATA", "UNITED"
    ]
  
    for insurer in INSURERS:
        page_data = page.search( r'for\s[A-Z0-9]*' + insurer, regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def find_mobile( page ):
    page_data = page.search( r'\s(\+91\-|0)?[6-9X][0-9X]{9}(,|\s)', regex=True, case=False )
    if len( page_data ) and "mobile" not in data:
        data["mobile"] = page_data[0]["text"].strip()
        data["mobile"] = data["mobile"][0:-1] if data["mobile"][-1] == "," else data["mobile"]

# %%
def find_email(page):
    page_data = page.search( r'[a-z0-9\.\-]+@(gmail|yahoo|outlook|hotmail)(\.com|\.co\.in)', regex=True, case=False )
    if len( page_data ) and "email" not in data:
        data["email"] = page_data[0]["text"].strip() if len( page_data ) else None

# %%
def find_vehicle_type( page ):
    type_regex = [ r'(two|2)\s?\-?\s?wheeler\s?', r'(four|4)\s?\-?\s?wheeler\s?', r'(MOTORCYCLE|SCOOTER|BIKE)', r'(private)?\s?\-?\s?(car\s|car$)' ]
    for i in range(4):
        if len( page.search( type_regex[i], regex=True, case=False ) ) > 0:
            data["type"] = "4W" if i%2 else "2W" 
            break

# %%
def find_policy_type( page ):
    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Policy)?\s?\-?\s?Stand\s?\-?\s?alone\s?\-?\s?O(wn)?\s?D(amage)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Stand Alone Own Damage"
        return

    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?(Package|Comprehensive)', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Package Policy"
        return
    
#     page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?Comprehensive', regex=True, case=False )
#     if len( page_data ) and "insurance_type" not in data:
#         data["type"] = "2W"
#         data["policy_type"] = "Package Policy"
#         return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Liability\s?\-?\s?(Only)?\s?\-?\s?(Policy)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Third Party"
        return
    
    page_data = page.search( r'Liability\s?\-?\s?(Only)?\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?\s?\-?\s?(for)?\s?Private\s?\-?\s?Car', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Third Party"
        return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Package|Comprehensive)', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Package Policy"
        return

#     page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?Comprehensive', regex=True, case=False )
#     if len( page_data ) and "insurance_type" not in data:
#         data["type"] = "4W"
#         data["policy_type"] = "Package Policy"
#         return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Bundled\s?\-?\s?(cover)', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Bundled Policy"
        return

    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Stand\s?\-?\s?alone\s?\-?\s?O(wn)?\s?D(amage)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Stand alone own damage"
        return
 
    page_data = page.search( r'(Package|Comprehensive)\s?\-?\s?(Bike|Car|Two\s?\-?\s?Wheeler)?\s?\-?\s?(Insurance)?\s?\-?\s?Policy', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Package Policy"
        return
    
#     page_data = page.search( r'Package\s?\-?\s?(Bike|Car|Two\s?\-?\s?Wheeler)?\s?\-?\s?(Insurance)?\s?\-?\s?Policy', regex=True, case=False )
#     if len( page_data ) and "insurance_type" not in data:
#         data["policy_type"] = "Package Policy"
#         return

    page_data = page.search( r'Liability\s?\-?\s?(Only)?\s?\-?\s?(Bike|Car|Two\s?\-?\s?Wheeler)?\s?\-?\s?Policy', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Third Party"
        return
    
    page_data = page.search( r'Bundled', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Bundled"
        return
    
    page_data = page.search( r'Act\s?\-?\s?(Only)?\s?\-?\s?(Bike|Car|Two\s?\-?\s?Wheeler)?\s?\-?\s?Policy', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Third Party"
        return

# %%
def find_package_v( page ):
    
    found_word = page.search( "Coverage", regex=True, case=False )
    
    if len( found_word ) > 0:
        next_bbox = [ found_word[0]["x0"] , found_word[0]["bottom"] + 1, found_word[0]["x1"], found_word[0]["bottom"] + 2 ]
    
        found_text, next_bbox = find_top_of_first_value_below( page, next_bbox )
    
        start_loc = { "x0": next_bbox[0], "top": next_bbox[1] }

        # find bottom of value 
        # |________________|__> top of value, start_loc_x0, start_loc_top 
        # |_____value______|__> end_loc_x1, end_loc_bottom
        # |----------------|--> bbox of h=2 from start_loc
        # |________________|__> top of first word below

        blank_space, next_bbox = find_bottom_of_value( page, next_bbox )
        end_loc = { "x1": next_bbox[2], "bottom": next_bbox[3] }

        # find left end of world
        next_bbox = [ start_loc["x0"] - 1, start_loc["top"], start_loc["x0"], end_loc["bottom"]  ]
        start_loc["x0"] = find_left_end_of_value( page, next_bbox )
    
        # find right end of world
        next_bbox = [ end_loc["x1"], start_loc["top"], end_loc["x1"] + 1, end_loc["bottom"]  ]
        end_loc["x1"] = find_right_end_of_value( page, next_bbox )
        
        data[ "policy_type" ] = page.crop( [ start_loc["x0"], start_loc["top"], end_loc["x1"], end_loc["bottom"] ] ).extract_text()

# %%
def find_reg_no( page ):
    page_data = page.search( r'(Vehicle|Reg(istration)?)(\s?\.?)\s?(No\s?\.?|Number|Mark)\s*:?\s*' + 
                             r'([A-Z]{2}\s?\-?\s?[0-9]{1,2}\s?\-?\s?[A-Z]{1,3}\s?\-?\s?[0-9]{2,5}|new)', 
                             regex=True, case=False
                           )

    if len( page_data ) > 0:
        reg_number = re.split('\s|\:', page_data[0]["text"] )[-1]
        data["reg_no"] = reg_number.replace( '-', "" )
        data["data_loc"] = "h" if page_data[0]['bottom'] - page_data[0]['top'] < 10 else "v"

# %%
def find_reg_no_using_bbox( page ):
    
    page_data = page.search( r'Registration\s?(No\s?\.?|Number|Mark)?', regex=True, case=False )
    
    if len( page_data ) > 0:
        for i in range( len( page_data ) ):
            for j in range(10):
                h_offset = ( page_data[i]["x1"] - page_data[i]["x0"] ) / len( page_data[i]["text"] ) * j
                v_offset = ( page_data[i]['bottom'] - page_data[i]['top'] ) * 5
        
                bbox_text = page.crop( [
                     max( page_data[i]["x0"] - h_offset, 0 ),
                     page_data[i]['top'],
                     min( page_data[i]["x1"] + h_offset, page.width ),
                     min( page_data[i]['bottom'] + v_offset, page.height )
                 ], strict=True )
            
                text = bbox_text.search( r"([A-Z]{2}\s?\-?\s?[0-9]{1,2}\s?\-?\s?[A-Z]{1,3}\s?\-?\s?[0-9]{2,5}|new)", regex=True, case=False )

                if len( text ):
                    word = text[0]["text"].replace("\n|\-", "")
                    if word.lower() == "new" or word[-4:].isnumeric():
                        data["reg_no"] = word
                        data["data_loc"] = "v"
                        return

# %%
def find_chassis_engine_h( page ):
    word_data = page.search( r'Engine\s(No\s?\.?|Number)?\s*\/\s*Chass?is\s?(No\s?\.?|Number)?\s?:?', regex=True, case=False )
    if len( word_data ) > 0:
        print( "1 ", word_data[0]["text"] )
        found_data = find_chassis_engine_no_h_bbox( page, word_data )
        data["engine_no"], data["chassis_no"] = re.split(r'\/', found_data)

    word_data = page.search( r'Chass?is\s(No\s?\.?|Number)?\s*\/\s*Engine\s?(No\s?\.?|Number)?\s?:?', regex=True, case=False )
    if len( word_data ) > 0:
        print( "2 ", word_data[0]["text"] )
        found_data = find_chassis_engine_no_h_bbox( page, word_data )
        data["chassis_no"], data["engine_no"] = re.split(r'\/', found_data)

    word_data = page.search( r'Engine\s(No\s?\.?|Number)\s*:?', regex=True, case=False )
    if "engine_no" not in data and len( word_data ) > 0:
        print( "3 ", word_data[0]["text"] )
        found_data = find_chassis_engine_no_h_bbox( page, word_data )
        found_data = re.sub( r'\s|\/|\n', "", found_data )
        if not found_data.isalpha():
            data["engine_no"] = found_data
            
    word_data = page.search( r'Chass?is\s(No\s?\.?|Number)\s*:?', regex=True, case=False )
    if "chassis_no" not in data and len( word_data ) > 0:
        print( "4 ", word_data[0]["text"] )
        found_data = find_chassis_engine_no_h_bbox( page, word_data )
        found_data = re.sub( r'\s|\/|\n', "", found_data )
        if not found_data.isalpha():
            data["chassis_no"] = found_data

# %%
def find_chassis_engine_no_h_bbox( page, word_data ):
    
    prev_right, prev_bottom = int(word_data[0]['x1']) ,int(word_data[0]['bottom']) 

    start_loc = { "x0": int(word_data[0]['x1']) + 2, "top": int(word_data[0]['top']) }
    end_loc = {}

    next_bbox = [ prev_right + 2, start_loc["top"], prev_right + 4, prev_bottom ]
    
    #find first word after space
    while True:
        found_text = page.crop(next_bbox, strict=True).extract_text()
        if len( found_text ) > 0 or next_bbox[0] == next_bbox[2]:
            break
        next_bbox[0], next_bbox[2] = next_bbox[2], min(next_bbox[2] + 2, page.width)

    #find last word
    consecutive_blank = 0
    while consecutive_blank < 2 and next_bbox[0] != next_bbox[2]:
        found_char = page.crop(next_bbox, strict=True).extract_text()
        if len( found_char ) == 0:
            consecutive_blank += 1
            end_loc = { "x1": min(next_bbox[2] + 2, page.width), "bottom": prev_bottom }
        next_bbox[0], next_bbox[2] = next_bbox[2], min(next_bbox[2] + 2, page.width)
    
    next_char = [ start_loc["x0"], end_loc["bottom"], next_bbox[2], end_loc["bottom"] + 1 ]
    
    #move down
    consecutive_blank = 0
    while consecutive_blank < 2 and next_bbox[1] != next_bbox[3]:
        found_char = page.crop(next_bbox, strict=True).extract_text()
        if len( found_char ) == 0:
            consecutive_blank += 1
        next_bbox[1], next_bbox[3] = next_bbox[3], min(next_bbox[3] + 1, page.height)
        
    end_loc = { "x1": next_bbox[2], "bottom": next_bbox[3] }
        
    bbox_text = page.crop([start_loc["x0"], start_loc["top"], end_loc["x1"], end_loc["bottom"]]).extract_text()
    return re.sub( r'\.|\s|\xa0|\n', "", bbox_text )

# %%
def find_chassis_engine_v( page ):
    
    if "engine_no" not in data:
        word_data = page.search( r'Engine\s*(No\s?\.?|Number)\s*:?', regex=True, case=False )
        if len( word_data ) > 0:
            found_data = find_chassis_engine_no_v_bbox( page, word_data )
            found_data = (re.sub( r'[^A-Za-z0-9]+', "", found_data )).strip()
            if found_data != "wrong_data":
                data["engine_no"] = found_data

    if "chassis_no" not in data:
        word_data = page.search( r'Chass?is\s*(No\s?\.?|Number)\s*:?', regex=True, case=False )
        if len( word_data ) > 0:
            found_data = find_chassis_engine_no_v_bbox( page, word_data )
            found_data = (re.sub( r'[^A-Za-z0-9]+', "", found_data )).strip()
            if found_data != "wrong_data":
                data["chassis_no"] = found_data
                
    if "engine_no" not in data:
        word_data = page.search( r'Engine', regex=True, case=False )
        if len( word_data ) > 0:
            found_data = find_chassis_engine_no_v_bbox( page, word_data )
            found_data = (re.sub( r'[^A-Za-z0-9]+', "", found_data )).strip()
            if found_data != "wrong_data":
                data["engine_no"] = found_data

    if "chassis_no" not in data:
        word_data = page.search( r'Chass?is', regex=True, case=False )
        if len( word_data ) > 0:
            found_data = find_chassis_engine_no_v_bbox( page, word_data )
            found_data = (re.sub( r'[^A-Za-z0-9]+', "", found_data )).strip()
            if found_data != "wrong_data":
                data["chassis_no"] = found_data

# %%
def find_top_of_first_value_below( page, next_bbox ):
    while next_bbox[1] != next_bbox[3]:
        found_word = page.crop( next_bbox, strict=True ).extract_text()
        if len( found_word ) > 0 or next_bbox[0] == next_bbox[2]:
            found_word = re.sub( r'[^A-Za-z0-9]+', "", found_word )
            return found_word, next_bbox
        next_bbox[1], next_bbox[3] = next_bbox[3], min(next_bbox[3] + 1, page.height)
    return "", next_bbox

def find_bottom_of_value( page, next_bbox ):
    while next_bbox[1] != next_bbox[3]:
        found_word = page.crop( next_bbox, strict=True ).extract_text()
        if len( found_word ) == 0:
            found_word = re.sub( r'[^A-Za-z0-9]+', "", found_word )
            return found_word, next_bbox
        next_bbox[1], next_bbox[3] = next_bbox[3], min(next_bbox[3] + 1, page.height)
    return "", next_bbox
    
def find_left_end_of_value( papge, next_bbox ):
    while next_bbox[0] != next_bbox[2]:
        found_word = page.crop( next_bbox, strict=True ).extract_text()
        if len( found_word ) == 0:
            return next_bbox[2]
        next_bbox[0], next_bbox[2] = max(next_bbox[0] - 1, 0), next_bbox[0]
    return next_bbox[0]
            
def find_right_end_of_value( papge, next_bbox ):
    while next_bbox[0] != next_bbox[2]:
        found_word = page.crop( next_bbox, strict=True ).extract_text()
        if len( found_word ) == 0:
            return next_bbox[2]
        next_bbox[0], next_bbox[2] = next_bbox[2], min(next_bbox[2] + 1, page.width)
    return next_bbox[2]

# %%
def find_chassis_engine_no_v_bbox( page, word_data ):
    
    next_bbox = [ word_data[0]['x0'], word_data[0]['bottom']+1, word_data[0]["x1"], word_data[0]["bottom"] + 2 ]
    # step 1: finding top of first key below
    # bbox of h=2 from bottom of key 
    #  ________________
    # |_______key______|__> start_loc_x0, start_loc_bottom
    # |----------------|--> bbox of h=2 from start_loc
    # |________________|__> top of first word below
        
    found_text, next_bbox = find_top_of_first_value_below( page, next_bbox )
    
    # step 2 checking if first below is wraped_key, if wrapped_key find next word below and mark as top for value
    # |_______key______|
    # |___wrapped_key__|__> bottom of wrapped_key (Number or no).
    # |----------------|--> bbox of h=2 from bottom of wrapped_key
    # |________________|__> top of first word below
    
    if found_text.isalpha():
        blank_, next_bbox = find_bottom_of_value( page, next_bbox )
        found_text, next_bbox = find_top_of_first_value_below( page, next_bbox )
    
    start_loc = { "x0": next_bbox[0], "top": next_bbox[1] }
    
    # step 3 find bottom of value 
    # |________________|__> top of value, start_loc_x0, start_loc_top 
    # |_____value______|__> end_loc_x1, end_loc_bottom
    # |----------------|--> bbox of h=2 from start_loc
    # |________________|__> top of first word below
    
    blank_space, next_bbox = find_bottom_of_value( page, next_bbox )
    end_loc = { "x1": next_bbox[2], "bottom": next_bbox[3] }

    # step 4 checking if value is wrapped, if wrapped_value find_bottom of text and update end_loc
    # |______value______|
    # |__wrapped_value__|__> bottom of wrapped_value, end_loc_x1, end_loc_bottom
    
    found_text, next_bbox = find_top_of_first_value_below( page, next_bbox )
    
    if not found_text.isalpha():
        found_text, next_bbox = find_bottom_of_value( page, next_bbox )
        end_loc = { "x1": next_bbox[2], "bottom": next_bbox[3] }
        
# step 5 find left end of world
    next_bbox = [ start_loc["x0"] - 1, start_loc["top"], start_loc["x0"], end_loc["bottom"]  ]
    start_loc["x0"] = find_left_end_of_value( page, next_bbox )
    
# step 6 find right end of world
    next_bbox = [ end_loc["x1"], start_loc["top"], end_loc["x1"] + 1, end_loc["bottom"]  ]
    end_loc["x1"] = find_right_end_of_value( page, next_bbox )
    
    return page.crop( [ start_loc["x0"], start_loc["top"], end_loc["x1"], end_loc["bottom"] ], strict=True ).extract_text()

# %%
def find_insured_name( page ):
    page_data = page.search( r'(Mr|Mrs?|M\/s|Ms\.)(\.\s?|\s)[A-Z]{1,20}\s?[A-Z]{0,20}\s?[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
        data["insurers_name"] = page_data[0]["text"].replace( "\n", "" )
        return
    
    page_data = page.search( r'(insured|Proposer)(\'s)?\s*name(\s|\s?:\s?)(Mr|Mrs?|M\/s|Ms\.)?(\.\s?|\s)?\s?[A-Z]{1,40}\s?[A-Z]{0,20}\s?[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
        insurer_name = re.sub( "Insured(\'s)?\s*Name\s*:?\s*", "", page_data[0]["text"] )
        data["insurers_name"] = insurer_name.replace( "\n", "" )

# %%
def find_policy_duration( page ):
    #date_time dd/mm/yyyy hh:mm:ss
    start_date = page.search( r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?([0-9]{4})(\s*|T)(\[|\()?\s*' + 
                              r'(00|12):(00|01)(\]|\))?\s?(:00|:01)?(\]|\))?\s?(hrs|hours|AM)?',
                             regex=True, case=False 
                            )    
    end_date  =  page.search( r'[0-9]{1,2}[\-\/\]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?([0-9]{4})(\s*|T)(\[|\()?s?' +
                              r'(\(?Mid\s?night\)?|11:59|11:59:59|23:59:59)\s?(\]|\))?\s?(hrs|hours|PM)?(\(?Mid\s?night\)?)?',
                             regex=True, case=False
                            )
    if len( start_date ) > 0 and "start" not in data :
        data["start"] = start_date[0]['text']
    if len( end_date ) > 0 and "end" not in data :
        data["end"] = end_date[0]['text']
        
    
    #time_data  hh:mm:ss dd/mm/yyyy
    start_date = page.search( r'(\[|\()?\s?(00|12):(00|01)(\]|\))?\s?(:00|:01)?\s?(hrs|hours|AM)?\s?(\]|\))?\s*(T|on|of)\s*' +
                              r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?[0-9]{4}',
                             regex=True, case=False 
                            )
    end_date = page.search( r'(\[|\()?s?(\(?Mid\s?night\)?|11:59|11:59:59|23:59:59)s?(\]|\))?\s?(hrs|hours|PM)?\s*(T|on|of)\s*' +
                            r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?[0-9]{4}(\(?Mid\s?night\)?)?',
                           regex=True, case=False
                          )
    if len( start_date ) > 0 and "start" not in data :
        data["start"] = start_date[0]['text']
    if len( end_date ) > 0 and "end" not in data :
        data["end"] = end_date[0]['text']

# %%
# def find_mmv_using_mmv_list( page ):
        
#     for make in MAKES:
#         found_data = page.search( make, regex=True, case=False )
#         if len( found_data ) > 0:
#             for model in

# %%
def find_mmv_using_chassis( page, chassis_no ):
    found_mmv = all_mmv_chassis_sheet[ all_mmv_chassis_sheet["chasis number"] == chassis_no ]
    for index, row in found_mmv.iterrows():
#         print( "mmv ", row["make"], row["model"], row["variant"], row["fuel type"] )
        data["mmv"] = f'{row["make"]} {row["model"]} {row["variant"]} {row["fuel type"]}'

# %%
def find_idv_h( page ):
    found_word = page.search( r'Total\s?(Value|IDV)' ?)

# %%
def find_premium_value( page ):
    found_word = page.search( r'(TOTAL\sPREMIUM\sPayable|FINAL\sAMOUNT)', case=False, regex=True )
    if len( found_word ) > 0:
        for i in range( len( found_word ) ):
            print( page,  found_word[i]["text"], re.sub( r'[^A-Za-z0-9\.]+', "", page.crop( [found_word[i]['x0'], found_word[i]['top'], page.width, found_word[i]['bottom'] ] ) ) )
            return
                
    found_word = page.search( r'((Net|Total)\s?Premium)', case=False, regex=True )
    if len( found_word ) > 0:
        for i in range( len( found_word ) ):
            print( page,  
                  found_word[i]["text"], 
                  re.sub( r'[^A-Za-z0-9\.]+', "", page.crop( [found_word[i]['x0'], found_word[i]['top'], page.width, found_word[i]['bottom'] ] ).extract_text() ) 
                 )
            return

# %%
df = pd.DataFrame( columns=[ "file", "pages", "data_loc", "policy_no", "insurers_name", "type", "reg_no", "insurer", "phone", "email",
                             "policy_type", "chassis_no", "engine_no", "mmv", "start", "end", "time" 
                           ] )
files = os.listdir("./all_policy/Motor/all_policy")

count = 0

for file in sorted(files):
# for file in [ "bajaj_3p_4w.pdf", "bajaj_4w_od.pdf", "bajaj_4w_pack.pdf", "bharti_hybrid_4w.pdf", "magma-4w-comp.pdf", "united-2w-comp.pdf", "united-4w-comp.pdf", "united-4w-tp.pdf" ]:
# for file in [ "acko-4w-comp.pdf" ]:
    count += 1
    print( count, file )

    start_time = time.time()
#     if count == 9:
#         break
    
    policy = pdfplumber.open( f'all_policy/Motor/all_policy/{file}' )
    
    insurer_count = {}
    data = {}

    for page in policy.pages:

#         find_insured_name( page ) if "insurers_name" not in data else None
#         find_email( page ) if "email" not in data else None
#         find_mobile( page ) if "mobile" not in data else None
#         find_reg_no( page ) if "reg_no" not in data else None
#         find_vehicle_type( page ) if "type" not in data else None
#         find_insurer_by_site( page ) if "insurer" not in data else None
#         find_policy_type( page ) if "policy_type" not in data else None
#         find_make( page ) if "make" not in data else None
        find_premium_value( page ) if "premium_value" not in data else None

        
#     if "reg_no" not in data:
#         for page in policy.pages:
#             find_reg_no_using_bbox( page )
        
#     for page in policy.pages:
#         if "insurer" not in data:
#             get_insurer_by_name( page )
        
#         if "policy_type" not in data:
#             find_package_v( page )
            
#         if "data_loc" not in data:
#             continue
            
#         if "chassis_no" not in data and data["data_loc"] == "h":
#             find_chassis_engine_h( page ) if "chassis_no" not in data else None
#             find_mmv_using_chassis( page, data["chassis_no"] ) if "chassis_no" in data else None
            
#         if "chassis_no" not in data and data["data_loc"] == "v":
#             find_chassis_engine_v( page ) if "chassis_no" not in data else None
#             find_mmv_using_chassis( page, data["chassis_no"] ) if "chassis_no" in data else None
        

#     for page in policy.pages:
#         if data["policy"] != "Third Party" or data["policy"] != "Liability Only":
#             find_idv_h( page ) if "idv" in data else None

            
#         find_policy_duration( page ) if "duration" not in data else None
            
        
    print( "data", data, "\n\n" )
    end_time = time.time()

    df.loc[ len( df.index ) ] = [ 
        file,
        len( policy.pages ),
        data["data_loc"] if "data_loc" in data else None,
        data["policy_no"] if "policy_no" in data else None,
        data["insurers_name"] if "insurers_name" in data else None,
        data["type"] if "type" in data else None,
        data["reg_no"] if "reg_no" in data else None,
        data["insurer"] if "insurer" in data else None,
        data["mobile"] if "mobile" in data else None,        
        data["email"] if "email" in data else None,
        data["policy_type"] if "policy_type" in data else None,
        data["chassis_no"] if "chassis_no" in data else None,
        data["engine_no"] if "engine_no" in data else None,
        data["mmv"] if "mmv" in data else None,
        data["start"] if "start" in data else None,
        data["end"] if "end" in data else None,
        ( end_time - start_time )
    ]
    
#     https://github.com/jsvine/pdfplumber
# Out:
# 1 acko-2w-comp.pdf
# <Page:1> Total Premium TotalPremium1538.00
# data {}
#
#
# 2 acko-4w-comp.pdf
# <Page:3> Total Premium TotalPremium3611.00
# <Page:4> Total Premium TotalPremium3611.00
# data {}
#
#
# 3 acko-4w-tp.pdf
# <Page:1> Total Premium TotalPremium2445.00
# data {}
#
#
# 4 bajaj_3p_4w.pdf
# <Page:3> Totalpremium Totalpremium3221.00
# data {}
#
#
# 5 bajaj_4w_hybrd.pdf
# <Page:3> NetPremium NetPremiumAB68330.00
# data {}
#
#
# 6 bajaj_4w_od.pdf
# <Page:3> TotalPremium TotalPremiumexcludingGSTforODcoveragesquotedandagreeduponis
# data {}
#
#
# 7 bajaj_4w_pack.pdf
# <Page:2> TotalPremium TotalPremiumexcludingGoodsandServiceTaxGSTforLiabilityandODcoveragesquotedandagreeduponis
# <Page:6> TotalPremium TotalPremiumNetPremiumAB5611.00LLtopersonforPaiddriverOpera50.00
# data {}
#
#
# 8 bharti_3p_4w.pdf
# <Page:1> Total Premium TotalPremium3800.78
# data {}
#
#
# 9 bharti_4w_comp.pdf
# <Page:1> Total Premium TotalPremium7033.68
# data {}
#
#
# 10 bharti_hybrid_4w.pdf
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [67], line 33
#      21     data = {}
#      23     for page in policy.pages:
#      24
#      25 #         find_insured_name( page ) if "insurers_name" not in data else None
#    (...)
#      31 #         find_policy_type( page ) if "policy_type" not in data else None
#      32 #         find_make( page ) if "make" not in data else None
# ---> 33         find_premium_value( page ) if "premium_value" not in data else None
#      36 #     if "reg_no" not in data:
#      37 #         for page in policy.pages:
#      38 #             find_reg_no_using_bbox( page )
#    (...)
#      63
#      64 #         find_policy_duration( page ) if "duration" not in data else None
#      67     print( "data", data, "\n\n" )
#
# Cell In [66], line 5, in find_premium_value(page)
#       3 if len( found_word ) > 0:
#       4     for i in range( len( found_word ) ):
# ----> 5         print( page,  found_word[i]["text"], re.sub( r'[^A-Za-z0-9\.]+', "", page.crop( [found_word[i]['x0'], found_word[i]['top'], page.width, found_word[i]['bottom'] ] ) ) )
#       6         return
#       8 found_word = page.search( r'((Net|Total)\s?Premium)', case=False, regex=True )
#
# File /usr/lib/python3.10/re.py:209, in sub(pattern, repl, string, count, flags)
#     202 def sub(pattern, repl, string, count=0, flags=0):
#     203     """Return the string obtained by replacing the leftmost
#     204     non-overlapping occurrences of the pattern in string by the
#     205     replacement repl.  repl can be either a string or a callable;
#     206     if a string, backslash escapes in it are processed.  If it is
#     207     a callable, it's passed the Match object and must return
#     208     a replacement string to be used."""
# --> 209     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object

# %%
# df.filter( ["file", "mmv", "pages", "data_loc", "insurers name", "type", "phone", "email", "reg_no", "chassis_no", "engine_no", "policy_type", "insurer" ] ).sort_values( "make" )
# df.filter( ["file", "pages", "reg_no", "mmv", "chassis_no", "engine_no" ] ).sort_values( "chassis_no" )
df.sort_values("policy_type")
# Out:
#                          file  pages data_loc policy_no  \
# 56        kotak_hybrid_4w.pdf      5        v      None
# 4          bajaj_4w_hybrd.pdf      7     None      None
# 83     reliance_hybrid_4w.pdf      9        h      None
# 9        bharti_hybrid_4w.pdf      2        v      None
# 41           iffico_3p_4w.pdf      3        v      None
# 32              iffco1_4w.pdf      3        v      None
# 30             iffco10_2w.pdf      3        v      None
# 31             iffco11_2w.pdf      4        v      None
# 33              iffco2_4w.pdf      4        v      None
# 34              iffco3_2w.pdf      4        v      None
# 43      iffico_4w_package.pdf      4     None      None
# 37              iffco6_2w.pdf      4        v      None
# 40              iffco9_2w.pdf      4        v      None
# 36              iffco5_2w.pdf      4        v      None
# 52              kotak8_4w.pdf      9        v      None
# 53              kotak9_2w.pdf     11        v      None
# 55          kotak_4w_comp.pdf      5        v      None
# 51              kotak7_2w.pdf     11        v      None
# 0            acko-2w-comp.pdf      2        h      None
# 48              kotak3_2w.pdf     10        v      None
# 47              kotak2_2w.pdf     10        v      None
# 46             kotak11_2w.pdf     10        v      None
# 50              kotak6_2w.pdf     11        v      None
# 49              kotak5_2w.pdf     10        v      None
# 58       national-2w-comp.pdf      2        v      None
# 59       national-4w-comp.pdf      2        v      None
# 87         united-2w-comp.pdf      9        h      None
# 85            sbi-4w-comp.pdf     17        h      None
# 84  royalsundaram-4w-comp.pdf      4        h      None
# 82         reliance_4w_od.pdf      9        h      None
# 81       reliance_4w_comp.pdf     11        h      None
# 79          reliance9_car.pdf     11        h      None
# 78          reliance8_car.pdf     11        h      None
# 77           reliance7_4w.pdf     11        h      None
# 76           reliance6_4w.pdf     11        h      None
# 71           reliance1_4w.pdf     11        h      None
# 70          reliance16_4w.pdf     11        h      None
# 69          reliance15_2w.pdf      6        h      None
# 67          reliance13_4w.pdf     11        h      None
# 65          reliance11_4w.pdf     11        h      None
# 64          reliance10_2w.pdf      6        h      None
# 62       newindia-4w-comp.pdf      7        h      None
# 61       newindia-2w-comp.pdf      3        h      None
# 57          magma-4w-comp.pdf      2        v      None
# 45             kotak10_2w.pdf     10        v      None
# 44     iffico_4w_package2.pdf      5        v      None
# 16              hdfc12_2w.pdf      3        h      None
# 18               hdfc1_4w.pdf      3        h      None
# 15              hdfc11_4w.pdf      3        h      None
# 19               hdfc2_4w.pdf      3        h      None
# 20               hdfc3_4w.pdf      3        h      None
# 13            hdf_4w_comp.pdf      3        h      None
# 21               hdfc5_4w.pdf      3        h      None
# 12           edel-4w-comp.pdf      3        v      None
# 23               hdfc7_4w.pdf      3        h      None
# 17              hdfc13_4w.pdf      3        h      None
# 11          chola-2w-comp.pdf      2        h      None
# 8          bharti_4w_comp.pdf      1        h      None
# 26         hdfc_4w_hybrid.pdf      3        h      None
# 6           bajaj_4w_pack.pdf     10        v      None
# 1            acko-4w-comp.pdf      6        h      None
# 29              icici1_2w.pdf      2        h      None
# 35              iffco4_2w.pdf      4        v      None
# 38              iffco7_4w.pdf      5        v      None
# 39              iffco8_2w.pdf      4        v      None
# 25               hdfc9_2w.pdf      3        h      None
# 88         united-4w-comp.pdf     10        h      None
# 42           iffico_4w_od.pdf      4        v      None
# 68          reliance14_2w.pdf      6        h      None
# 66          reliance12_2w.pdf      6        h      None
# 24               hdfc8_2w.pdf      3        h      None
# 72           reliance2_2w.pdf      6        h      None
# 73           reliance3_2w.pdf      6        h      None
# 74           reliance4_2w.pdf      6        h      None
# 75           reliance5_2w.pdf      6        h      None
# 22               hdfc6_2W.pdf      3        h      None
# 27             hdfc_4w_od.pdf      3        h      None
# 10           bharti_od_4w.pdf      3        v      None
# 14              hdfc10_4w.pdf      2        h      None
# 54            kotak_4w_3p.pdf      5        v      None
# 80         reliance_4w_3p.pdf      7        h      None
# 7            bharti_3p_4w.pdf      1        h      None
# 63         newindia-4w-tp.pdf      7        h      None
# 5             bajaj_4w_od.pdf     12        v      None
# 3             bajaj_3p_4w.pdf      5        v      None
# 2              acko-4w-tp.pdf      2        h      None
# 28             hdfc_4w_tp.pdf      2        h      None
# 60             navi-4w-tp.pdf      8        h      None
# 89           united-4w-tp.pdf      8        h      None
# 86              sbi-4w-tp.pdf     13        h      None
#
#                                  insurers_name  type         reg_no  \
# 56                           Mrs. Suniti Tyagi    4W            NEW
# 4               GIRISHKUMARTHANKAPPANNAIR Zone  None           None
# 83                          Mr. SHIVA KUMARA S    4W            NEW
# 9                      Mr. Subasish Mohapatra     4W            NEW
# 41                                        None    4W     MH27AC9244
# 32                                        None    4W      UP93U5817
# 30                              RAJASEKHAR CH     2W     AP05BK0106
# 31                                SUDHIR JAIN     2W     DL12SJ2108
# 33                                        None    4W      KL27A1810
# 34                              N VARADARAJAN     2W     TN09BV8596
# 43                                MR KULDEEP      4W           None
# 37                              BRAJESH KUMAR     2W     DL9SBG4545
# 40                           RAMNARESH GODARA     2W     RJ44SB9262
# 36                               ALAGAPPAN AL     2W     TN18AE7511
# 52                           Mrs. Leelavathi B    4W     AP03BP5836
# 53                           Mr. Vikash Andani    2W     UP42AA4005
# 55                      Mrs. Shradha Deshpande    4W     KA02MH8148
# 51                    Mr. Prabhuraj K Hosamani    2W      KA41Y8233
# 0                             Geetinder Singh     2W     PB10FS2630
# 48                   Mr. Amol Jugalkishor Heda    2W     MH41AN7522
# 47                   Mr. Netaji Shivaji Jadhav    2W     MH25AF4065
# 46                  Mr. Bharat Yashwant Bangar    2W     MH04JA5479
# 50                                Mr. Suman Bn    2W     KA05JQ0243
# 49                       Mr. Sudesh R Morajkar    2W      GA04M4387
# 58                    Mr. Amit Ratnakar Pagare    2W     MH05BW0835
# 59                               Mr. Edward I     4W     KA01MH6947
# 87                                        None    2W      HR19H1069
# 85                       Mr. CHINTHALA PREETHI    4W     TS08GN1666
# 84            Mr. LAVJIBHAI MOHANBHAI HAPALIYA    4W      GJ5JP5327
# 82                            Ms. ANJU TIWARI     4W     HR26EF2340
# 81                            MR.ANISH DHIMAN     4W      HP64A2836
# 79                        MR.PRAMOD SINGH RANA    4W    DL02CAZ7876
# 78                        MR.PRABHAKAR PANDEY     4W     UP60AA1991
# 77                        MR.MR SANKHA NARAYAN    4W     AS06AA5025
# 76                  MR.RAKESH BALDEVBHAI PATEL    4W     GJ06DG2771
# 71                         MR.RAMAKANTA SAMAL     4W     OD02AA4963
# 70                     MR.MOHAMMAD RUSTUM BHAT    4W      JK13C7701
# 69                          MR.HIMANSHU KUMAR     2W     DL13SU5840
# 67                       MR.ASHWATHANARAYAN M     4W      KA43M8588
# 65                           MS.PRIYA AWASTHI     4W     GJ15CK8239
# 64                        MR.AKASH KUMAR SINGH    2W      KA51Y5671
# 62                                GAURAV GOEL     4W     HR26CD8127
# 61                                  RUPAM DAS     2W     AS01DB1446
# 57  Mrs. Mrsjayshreeben Kamleshkumar Prajapati    4W     GJ05RA1617
# 45                           Mrs. Reetu Kumari    2W    DL05SAZ7925
# 44                                        None    4W            New
# 16                                        None    2W     KA53EM8787
# 18                      MR PARIKSHIT MALHOTRA     4W      HP33F5772
# 15                              MR BEERAIAH B     4W      KA53C7581
# 19                          M/S RAJ KUMAR KAIN    4W    DL08CNB8249
# 20                                 MR HARI OM     4W    DL03CCN5760
# 13                                        None    4W     KA04MS3235
# 21             MR KRISHNAMURTHY KIKKISETTI RTO    4W     KA03MX4830
# 12                           Mr. Pronojit Sen     4W     WB02AP3947
# 23                           MR SANDEEP KUMAR     4W     CH01AE2802
# 17                     MR MAYUR MADHUKAR PATIL    4W     MH11AW9594
# 11                                        None    2W     TN10BC4732
# 8                                         None    4W     MP09CU3117
# 26                     MR RAJESH MUROOR PRABHU    4W            NEW
# 6                        DEVENDRAKUMARSHARMA      4W     UP14AY7728
# 1                        MANJU ISHWERI NARAYAN    4W     MH03BS0277
# 29                                        None    2W     TS09EE9725
# 35                         RAKESH KUMAR MAURYA    2W     HR26DK2115
# 38                                        None    4W      GA03Y4235
# 39                  MADHAV RADHEYSHYAM KATIYAR    2W     MH05DV1898
# 25                                        None    2W     JH01BC4249
# 88                                        None    4W     DL9CAU4736
# 42                              Mr. Anil Singh    4W     UK07DN9838
# 68                           MR.SUNDARABABU R     2W      PY05F2934
# 66                           MR.MR RAVEENDRAN     2W      KL77A9698
# 24                                        None    2W     KA42EB9744
# 72                          MR.B SENTHIL KUMAR    2W     TN12AH5335
# 73                               MS.SHANTHI S     2W     PY01CW1342
# 74                          MR.SITA RAM BAIRWA    2W     RJ14AJ7933
# 75                           MS.ASTALAKSHMI R     2W     TN11AK9898
# 22                                        None    2W    DL08SCR0181
# 27                     MR MANU THOMAS CHIRAYIL    4W     KA03ND9582
# 10                         Mr. Devinder Kumar     4W  DL-2-CBA-2638
# 14                              MR MANJU DEVI     4W      HP12D2172
# 54                                 Mr. Basha S    4W     KA51MN8526
# 80                             Mr.SUMIT SUHAG     4W     HR26BM5573
# 7                                         None    4W     TN22CY7234
# 63                            BIKRAM HAZARIKA     4W      AS12M6347
# 5                                  MALATYAGI      4W     UP15CY6869
# 3                               DEEPAKMISHRA      4W    DL02CAK7454
# 2                            TEISOVINUO LOTHA     4W      NL07T0267
# 28                   MRS APARNA ARUN CHORMUNGE    4W      MH43L3303
# 60                                 and Address    4W     KA03ML1507
# 89                                        None    4W      TN24V4844
# 86                           Mr. MANISH SHARMA    4W     DL2CAN2618
#
#       insurer           phone                              email  \
# 56      KOTAK      7409548465              ayushtyagsa@gmail.com
# 4       BAJAJ            None                               None
# 83   RELIANCE      9426110267            shivakumar267@gmail.com
# 9      BHARTI      9008811448      mohapatrasubasish@yahoo.co.in
# 41     IFFICO      XXXXXXX569                               None
# 32     IFFICO      XXXXXXX741                               None
# 30     IFFICO      XXXXXXX689                               None
# 31     IFFICO      XXXXXXX830                               None
# 33     IFFICO      XXXXXXX114                               None
# 34     IFFICO      XXXXXXX101                               None
# 43     IFFICO      9911093500                               None
# 37     IFFICO      XXXXXXX810                               None
# 40     IFFICO      XXXXXXX100                               None
# 36     IFFICO      XXXXXXX195                               None
# 52      KOTAK      9700643243      RAMYABHARGAVI.BUJJE@GMAIL.COM
# 53      KOTAK      8409305280         RAMKUMARITBP1988@GMAIL.COM
# 55      KOTAK      9740575400        SANKETH.KANDLIKAR@GMAIL.COM
# 51      KOTAK      8951618891             BAJARANGIPKH@GMAIL.COM
# 0        ACKO      XXXXXX9111           gXXXXXXXXXXXXi@yahoo.com
# 48      KOTAK      9845316882                MOHITSR76@GMAIL.COM
# 47      KOTAK      8149445455              GANESHDZIRE@GMAIL.COM
# 46      KOTAK      9594880123                DOSTITOUR@GMAIL.COM
# 50      KOTAK      9741111668               SUMANBN668@GMAIL.COM
# 49      KOTAK      9822122510             SUDESH.ARTIS@GMAIL.COM
# 58   NATIONAL      9890085085            contactpagare@gmail.com
# 59   NATIONAL      9916098981           edwardlawson87@gmail.com
# 87     UNITED      9671732414              gurmeet3093@gmail.com
# 85        SBI  +91-9052928520                               None
# 84      ROYAL      xxxxxx5540                               None
# 82   RELIANCE      9871421097       shalendra.tripathi@gmail.com
# 81   RELIANCE      8433707105            anishdhiman99@gmail.com
# 79   RELIANCE      8433707105             atienter2010@gmail.com
# 78   RELIANCE      8433707105       pankaj.singh.garud@gmail.com
# 77   RELIANCE      8433707105                 surzeett@gmail.com
# 76   RELIANCE      8433707105              rakesh11566@gmail.com
# 71   RELIANCE      8433707105            niraj.samal@hotmail.com
# 70   RELIANCE      8433707105               hilaljmi12@gmail.com
# 69   RELIANCE      8433707105              Himanshukum@gmail.com
# 67   RELIANCE      8433707105            bmvishnu.vs@yahoo.co.in
# 65   RELIANCE      8433707105            dhirajawasthi@yahoo.com
# 64   RELIANCE      8433707105                akashikka@gmail.com
# 62  NEW INDIA      XXXXXX8030                goel209@yahoo.co.in
# 61  NEW INDIA      XXXXXX6455              noonmati020@gmail.com
# 57      MAGMA      9725056102             primekamlesh@gmail.com
# 45      KOTAK      8533990227            REETUREETU141@GMAIL.COM
# 44     IFFICO      8097762008                               None
# 16       HDFC      9902059738          jagadeeshae7272@gmail.com
# 18       HDFC      9418450772                 drpm1972@gmail.com
# 15       HDFC      9731138386        prakashmbangalore@gmail.com
# 19       HDFC      7982382088                               None
# 20       HDFC      7983119833                sksmtr.sk@gmail.com
# 13       HDFC      8861598378                               None
# 21       HDFC      9742723000                kkmurty93@gmail.com
# 12  EDELWEISS            None                               None
# 23       HDFC      9646689689        harpreetsharma097@gmail.com
# 17       HDFC      9096749797           mayur.m.patil9@gmail.com
# 11      CHOLA      9841198260                               None
# 8      BHARTI      9406826010       anshuljhansiwale@yahoo.co.in
# 26       HDFC      9448366661           rajeshprabhu14@gmail.com
# 6       BAJAJ      9899161954              dssharma761@gmail.com
# 1        ACKO      XXXXXX2426  iXXXXXXXXXXXXXXXXXXXa@yahoo.co.in
# 29      ICICI      9356278702                     2000@YAHOO.COM
# 35     IFFICO      XXXXXXX540                               None
# 38     IFFICO      XXXXXXX674                               None
# 39     IFFICO      XXXXXXX720                               None
# 25       HDFC      7979971843           navneetbhg2020@gmail.com
# 88     UNITED      9873621425                               None
# 42     IFFICO      8130533313                               None
# 68   RELIANCE      8433707105            rajthanga0123@gmail.com
# 66   RELIANCE      8433707105         anugrahameppayur@gmail.com
# 24       HDFC      9900466863            dhanukumar110@gmail.com
# 72   RELIANCE      8433707105             senthilkumar@gmail.com
# 73   RELIANCE      8433707105            rajthanga0123@gmail.com
# 74   RELIANCE      8433707105                jp9433344@gmail.com
# 75   RELIANCE      8433707105              SKFINANCE01@GMAIL.COM
# 22       HDFC      8882746998             pankajali786@gmail.com
# 27       HDFC      7760914134     manuthomaschirayil@outlook.com
# 10     BHARTI      9729078558                hr2800471@gmail.com
# 14       HDFC      9816086889           chandan.ranote@gmail.com
# 54      KOTAK      8178289201    harshverdhanpathak115@gmail.com
# 80   RELIANCE      8433707105              davesh.dits@gmail.com
# 7      BHARTI      7299997375                   sajuvk@gmail.com
# 63  NEW INDIA      XXXXXX0262           akashchetry799@gmail.com
# 5       BAJAJ      9808144591          navinshandilya1@gmail.com
# 3       BAJAJ            None            deepakafcme84@gmail.com
# 2        ACKO      XXXXXX8324   sXXXXXXXXXXXXXXXXXXXX6@gmail.com
# 28       HDF2      9870909211             spartans2277@gmail.com
# 60       NAVI            None                               None
# 89     UNITED      7904149939          veludivxece2018@gmail.com
# 86        SBI  +91-9818077949                               None
#
#                policy_type             chassis_no                 engine_no  \
# 56                 Bundled      MA3RFL41SLJ193564              K10BN2336503
# 4                  Bundled                   None                      None
# 83                 Bundled      REVTRN11FYXK52821         MAT627223MLF40268
# 9           Bundled Policy      MEERBC006M7103584            B4DA417E085205
# 41          Liability Only      MA3EAA61S01885909               F8DN4656405
# 32          Liability Only                1035744                   3972486
# 30          Liability Only      MBLHA10EG8GJ08102            HA10EB8GJ49879
# 31                 Package      ME3U3S5C1GL015515            U3S5C1GL343915
# 33                 Package      MA6TF694M9HB19867              F14D37255301
# 34                 Package      ME4KC09CBE8664023             KC09E86674245
# 43                 Package                   None                      None
# 37                 Package       MD2A1EZ9GCG47626               DKZCGG63495
# 40                 Package      MBLHA12ACG4B01238            HA12EMG4B01186
# 36                 Package      ME4KC201HF8122740             KC20E80135741
# 52          Package Policy               M345752K              G3HAEM305015
# 53          Package Policy      MD625SF43E1D76026              CF4DE1075225
# 55          Package Policy       A3EPDE1S00709577               10BN1674884
# 51          Package Policy      MD2A14AZ4DWD33291               JBZWDD11470
# 0           Package Policy      ME3U3K5C0GD042682            U3K5C0GD042682
# 48          Package Policy      ME4JF651JG7037973             JF65E70038014
# 47          Package Policy      MBLHA11ATG9D37306            HA11EJG9D02469
# 46          Package Policy      MD626BG46H3B20774              BG4AH2421207
# 50          Package Policy      ME4JF393JF7083337             JF39E71083386
# 49          Package Policy      ME4JF505KGU482180             JF50EU3481618
# 58          Package Policy      ME4JF481GD8007022             JF48E80006776
# 59          Package Policy     MALBB51BLBM382438M              G4LABM793892
# 87          Package Policy      MBLHA11EUD9E00520            HA11EGD9E02497
# 85          Package Policy      MA3NYFB1SKC520556               D13A5801360
# 84          Package Policy       156586icleHYUNDA                    016268
# 82          Package Policy      MAJAXXMRKAKM56507                   KM56507
# 81          Package Policy      MAKDG175JG4000911              L15Z13107839
# 79          Package Policy                0470310                   8142367
# 78          Package Policy     MALBM51BLFM193559M              G4LAFM879175
# 77          Package Policy      MBHEWB22SKM407883              K12MN7528598
# 76          Package Policy     MALBB51BR9M122064M              G4LA9M291454
# 71          Package Policy      MALA841CLFM151684              G4LAFM876857
# 70          Package Policy      MA3EWDE1S00894649              K10BN7542133
# 69          Package Policy      ME4JF507KH7361902             JF50E75361916
# 67          Package Policy                1693222                   4903386
# 65          Package Policy                  03324                     39782
# 64          Package Policy      ME4JC448BB8090424              JC44E1201259
# 62          Package Policy                M507437                   M743083
# 61          Package Policy      MB8NG4BAHG8239880                BGA1315966
# 57          Package Policy                 C38517                    868839
# 45          Package Policy      MBLJFW015HGC12557            JF33ABHGC11537
# 44          Package Policy      MAT626350LKH28864         REVTRN08HZXK54331
# 16          Package Policy      ME4JC652BGTO93696             JC65ET0289227
# 18          Package Policy                JL56466                   JL56466
# 15          Package Policy      MAT600185GPJ34888         475IDI03JTYP34516
# 19          Package Policy                 909623                    734624
# 20          Package Policy      MA3EWDE1S00D50948              K10BN8060462
# 13          Package Policy               GT090342                   S496599
# 21          Package Policy      MEEBBA002G1325553            B4AA400E021442
# 12          Package Policy      MA3EZDE1S00536116              K10BN8260195
# 23          Package Policy      MA3EWDE1S00176139              K10BN1308907
# 17          Package Policy   MCA11835E07029773EMZ                   0154603
# 11          Package Policy      MD626AG78J2D14142              AG7DJ2402787
# 8           Package Policy                 244464                    195460
# 26          Package Policy      MZBEU812TMN218550                    143129
# 6           Package Policy      MA3EED81SOO884095              F10DN4708969
# 1           Package Policy      MAT612354EKD08300  engineisnotcoveredunless
# 29          Package Policy      ME4JF502LET601661             JF50ET1601603
# 35          Package Policy      ME4JF507LH7411749             JF50E75411787
# 38          Package Policy      MA3EWB22SJD465408              K12MN7237270
# 39          Package Policy      ME4JF50BGJU086422             JF50EU8086454
# 25          Package Policy      ME4JC36KKD7311586             JC36E77950021
# 88          Package Policy  MBJ53REH2065099410316                2ZRY278842
# 42          Stand Alone OD                 335801                    074189
# 68  Stand Alone Own Damage      MB8DP11ALJ8A62610               AF215161361
# 66  Stand Alone Own Damage      MB8DP12DML8474223               AF212447702
# 24  Stand Alone Own Damage      ME4JF50AALA134302             JF50EA0133058
# 72  Stand Alone Own Damage       MD2A55F5KCJ07279               JLYCKJ36058
# 73  Stand Alone Own Damage      MB8DP12DAL8138573               AF212276139
# 74  Stand Alone Own Damage      ME4JC67DBK8003293             JC67E84268984
# 75  Stand Alone Own Damage      ME1SED14AJ0042881              E3Y3E0612903
# 22  Stand Alone Own Damage      MD626AG74K2E23103              AG7EK2622131
# 27  Stand alone own damage      MALA851CLJM952554              G4LAJM135335
# 10  Stand alone own damage      MAT626289KKB19889         REVTRN02BPYK22179
# 14             Third Party     MALAA51HR9M486097L              G4HG9M906721
# 54             Third Party      MA3JMT81SKE162279              K12MN4592385
# 80             Third Party      MAKGM252HBN211435              L15A72233599
# 7              Third Party      MAJ2XXMRJ2BT81073                  BT81073C
# 63             Third Party      MA3ERLF1S00399960               G12BN377383
# 5              Third Party                 407380                   1033775
# 3              Third Party      MA3EKE42S00199643                    514133
# 2              Third Party                 440411                    288648
# 28             Third Party                 018751                    370989
# 60             Third Party      MALAM51CR9M333424              G4LA9M143384
# 89             Third Party      MA3FKE31S00237428               D13A1017327
# 86                    None      MA3EDKD1S00290267              K12MN4074617
#
#                                                   mmv start   end      time
# 56                     Maruti S Presso VXI AMT PETROL  None  None  1.827969
# 4                                                None  None  None  1.319100
# 83                                               None  None  None  1.385721
# 9                        Renault Triber RXZ MT PETROL  None  None  2.252494
# 41                             Maruti Alto LXI PETROL  None  None  2.006417
# 32                                               None  None  None  1.699250
# 30                 Hero Honda Passion Plus STD PETROL  None  None  2.290863
# 31               Royal Enfield Classic 350 350 PETROL  None  None  3.694563
# 33                          Chevrolet Aveo 1.4 PETROL  None  None  2.327534
# 34              Honda Cb Unicorn DAZZLER BASIC PETROL  None  None  2.729211
# 43                                               None  None  None  2.719372
# 37                                               None  None  None  2.850018
# 40   Hero Motocorp Splendor I Smart Self Start PETROL  None  None  3.682447
# 36                    Honda Cb Unicorn 160 STD PETROL  None  None  3.066511
# 52                                               None  None  None  2.184132
# 53                             Tvs Phoenix STD PETROL  None  None  2.055454
# 55                                               None  None  None  1.571797
# 51                      Bajaj Discover 100 STD PETROL  None  None  2.688393
# 0                     Royal Enfield Bullet STD PETROL  None  None  1.110945
# 48                              Honda Navi Street nan  None  None  2.721051
# 47  Hero Motocorp Hf Deluxe Self Start Alloy Wheel...  None  None  2.065003
# 46                      Tvs Jupiter Self Start PETROL  None  None  2.012558
# 50                    Honda Dio Dlx Self Start PETROL  None  None  2.067373
# 49                             Honda Activa 3G PETROL  None  None  2.047969
# 58                          Honda Activa I STD PETROL  None  None  1.756887
# 59                                               None  None  None  1.823988
# 87                                               None  None  None  5.890732
# 85                                               None  None  None  2.904786
# 84                                               None  None  None  1.036232
# 82                             Ford Ecosport S PETROL  None  None  1.418903
# 81                     Honda BR-V i-VTEC VX MT PETROL  None  None  3.199211
# 79                                               None  None  None  1.733586
# 78                                               None  None  None  1.982081
# 77                     Maruti Baleno 1.2 Alpha PETROL  None  None  2.867342
# 76                                               None  None  None  2.089421
# 71                             Hyundai Xcent S PETROL  None  None  1.931700
# 70                           Maruti Wagon R VX PETROL  None  None  1.989582
# 69                             Honda Activa 4G PETROL  None  None  1.683055
# 67                                               None  None  None  1.817064
# 65                                               None  None  None  2.482951
# 64                            Honda Activa Dlx PETROL  None  None  1.662046
# 62                                               None  None  None  0.722062
# 61                         Suzuki Gixxer SF SP PETROL  None  None  0.486191
# 57                                               None  None  None  0.979990
# 45                   Hero Motocorp Maestro STD PETROL  None  None  2.738960
# 44                 Tata Tiago Revotron XZ Plus PETROL  None  None  2.949050
# 16                   Honda Cb Shine Kick Start PETROL  None  None  2.033834
# 18                                               None  None  None  1.917932
# 15                           Tata Indica V2 LS DIESEL  None  None  2.222006
# 19                                               None  None  None  1.782451
# 20                Maruti Wagon R LXI INTERNAL_LPG_CNG  None  None  2.159962
# 13                                               None  None  None  3.953856
# 21                            Renault Kwid RXT PETROL  None  None  2.963349
# 12                                               None  None  None  1.537148
# 23                          Maruti Wagon R LXI PETROL  None  None  2.176157
# 17                                               None  None  None  2.631248
# 11                                               None  None  None  1.273737
# 8                                                None  None  None  0.901373
# 26                        KIA Seltos HTX IVT G PETROL  None  None  2.045807
# 6                           Maruti Wagon R VXI PETROL  None  None  1.866051
# 1                                 Tata Nano LX PETROL  None  None  4.344582
# 29                                               None  None  None  1.411689
# 35                             Honda Activa 4G PETROL  None  None  4.088513
# 38                 Maruti Baleno 1.2 CVT Delta PETROL  None  None  3.708016
# 39                             Honda Activa 5G PETROL  None  None  2.451147
# 25                   Honda Cb Shine Kick Start PETROL  None  None  2.969883
# 88                                               None  None  None  5.119297
# 42                                               None  None  None  2.220146
# 68                           Suzuki Access 125 PETROL  None  None  2.272467
# 66      Suzuki Access 125 Special Edition Disc PETROL  None  None  1.563923
# 24                             Honda Activa 5G PETROL  None  None  2.117235
# 72                                               None  None  None  2.311091
# 73                   Suzuki Access Spl Edition PETROL  None  None  1.548298
# 74                      Honda Cd 110 Dream STD PETROL  None  None  1.623859
# 75                           Yamaha Alpha Disc PETROL  None  None  1.592229
# 22                           Tvs NTORQ 125 STD PETROL  None  None  2.157250
# 27                     Hyundai Grand i10 Magna PETROL  None  None  2.101643
# 10                              Tata Tiago NRG PETROL  None  None  1.549517
# 14                                               None  None  None  1.676953
# 54                      Maruti Wagon R ZXI 1.2 PETROL  None  None  2.367794
# 80                              Honda City EMT PETROL  None  None  1.569044
# 7                   Ford Fiesta 1.5 TDCI Trend DIESEL  None  None  1.043875
# 63                                               None  None  None  0.753551
# 5                                                None  None  None  2.891563
# 3                       Maruti Swift Dzire VXI PETROL  None  None  2.241177
# 2                                                None  None  None  0.797700
# 28                                               None  None  None  1.661194
# 60                           Hyundai i10 Magna PETROL  None  None  1.847111
# 89                            Maruti Swift LDI DIESEL  None  None  3.364909
# 86                             Maruti Ritz ZXI PETROL  None  None  2.753396

# %%
# x = df[ df["data_loc"] == 'h' ].filter( ["file"] )
# x = list( x["file"].unique() )
# print( x )

# %%
def test( page ):
    page_data = page.search( r'Coverage', regex=True, case=False )
    
    if len( page_data ) > 0:
        for i in range( len( page_data ) ):
            for j in range(14):
#                 print( page, page_data[i]['text'] )
                h_offset = ( page_data[i]["x1"] - page_data[i]["x0"] ) / len( page_data[i]["text"] ) * j
                v_offset = ( page_data[i]['bottom'] - page_data[i]['top'] ) * 5
        
                bbox_text = page.crop( [
                     max( page_data[i]["x0"] - h_offset, 0 ),
                     page_data[i]['top'],
                     min( page_data[i]["x1"] + h_offset, page.width ),
                     min( page_data[i]['bottom'] + v_offset, page.height )
                 ], strict=True ).extract_text()
            
                print( repr(bbox_text) )
#                 text = re.findall( r"\n?M[A-EZ][A-HJ-NPR-Z0-9]{14,19}\n?", bbox_text, re.IGNORECASE )

#                 if len( text ):
#                     word = text[0].replace("\n\-", "")
#                     if word.lower() == "new" or word[-4:].isnumeric():
#                         data["chassis_no"] = word
# #                         print( "\n", page, "\t\t\t\t\t\tfound chassis_no ", repr(word), "\n" )
#                         return

# %%
# files = list( df[ df["policy_type"].isnull() == True ]["file"] )
# i = 0
# for file in files:
# # for file in ["national-4w-comp.pdf"]:
#     i = i + 1
#     print( i, file )
#     policy = pdfplumber.open( f'all_policy/Motor/all_policy/{file}' )

# # repr(policy.pages[0].extract_text() )
# # policy.pages[0].search( r'chassis no.\sM[A-EZ][A-HJ-NPR-Z0-9]{9}', regex=True, case=False )[0]['text']
#     for page in policy.pages:
#         print(page)
#         test( page )

# %%
# !git add PDF_Reading_Sheet.ipynb
# !git commit -m "adding "
# !git push

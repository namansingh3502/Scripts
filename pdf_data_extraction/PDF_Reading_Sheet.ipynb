# %%
import re
import os
import numpy as np
import pandas as pd
import pdfplumber
import time
from nltk.tokenize import word_tokenize

from IPython.display import display, HTML
from notebook.services.config import ConfigManager

display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Get all words on page in a list of lists. Each word is represented by:
# [x0, y0, x1, y1, word, bno, lno, wno]
# The first 4 entries are the word's rectangle coordinates, the last 3 are just
# technical info (block number, line number, word number).
# The term 'word' here stands for any string without space.
# Out:
# <style>.container { width:100% !important; }</style>

# %%
def find_insurer_by_site(page):
    INSURERS = {
                "ACKO": "acko.com", "BAJAJ": "bajajallianz.com", "BHARTI": "bhartiaxa.com", "CHOLA": "cholainsurance.com",
                "EDELWEISS": "edelweissinsurance.com", "GODIGIT": "godigit.com", "HDFC": "hdfcergo.com", "ICICI": "icicilombard.com",
                "IFFICO-TOKIO": "iffcotokio.co.in", "KOTAK": "kotakgeneralinsurance.com", "LIBERTY": "libertyinsurance.in",
                "MAGMA": "magmahdi.com" , "NAVI": "navi.com", "NEW INDIA": "newindia.co.in", "NATIONAL": "nationalinsuranceindia.nic.co.in",
                "ORIENTAL": "orientalinsurance.org.in", "RELIANCE": "reliancegeneral.co.in", "ROYAL": "royalsundaram.in", "SBI": "sbigeneral.in",
                "SHRIRAM": "shriramgi.com", "TATA": "tataaig.com", "UNITED": "uiic.co.in"
               }
    
    for insurer in INSURERS:
        page_data = page.search( INSURERS[insurer], regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def get_insurer_by_name(page):
    INSURERS = [
        "ACKO", "BAJAJ", "BHARTI", "CHOLA", "EDELWEISS", "GODIGIT", "HDFC", "ICICI", "IFFICO-TOKIO", "KOTAK", "LIBERTY",
        "MAGMA", "NAVI", "NEW INDIA", "NATIONAL", "ORIENTAL", "RELIANCE", "ROYAL", "SBI", "SHRIRAM", "TATA", "UNITED"
    ]
  
    for insurer in INSURERS:
        page_data = page.search( insurer, regex=True, case=False )
        if len( page_data ) and "insurer" not in data:
            data["insurer"] = insurer

# %%
def find_mobile( page ):
    page_data = page.search( r'\s(\+91\-|0)?[6-9X][0-9X]{9}(,|\s)', regex=True, case=False )z
    if len( page_data ) and "mobile" not in data:
        data["mobile"] = page_data[0]["text"].strip()
        data["mobile"] = data["mobile"][0:-1] if data["mobile"][-1] == "," else data["mobile"]

# %%
def find_email(page):
    page_data = page.search( r'[a-z0-9\.\-]+@+(gmail|yahoo|outlook|hotmail)+(\.com|\.co\.in)+', regex=True, case=False )
    if len( page_data ) and "email" not in data:
        data["email"] = page_data[0]["text"].strip() if len( data ) else None

# %%
def find_vehicle_type( page ):
    type_regex = [ r'(two|2)\s?\-?\s?wheeler\s?', r'(four|4)\s?\-?\s?wheeler\s?', r'(MOTORCYCLE|SCOOTER|BIKE)', r'(private)?\s?\-?\s?(car\s|car$)' ]
    for i in range(4):
        if len( page.search( type_regex[i], regex=True, case=False ) ) > 0:
            data["type"] = "4W" if i%2 else "2W" 
            break
    
#     (policy|package|hybrid|comprehensive|certificate|secure)

# %%
def find_policy_type( page ):
    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Policy)?\s?\-?\s?Stand\s?\-?\s?alone\s?\-?\s?O(wn)?\s?D(amage)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Stand Alone Own Damage"
        return

    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?Package\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Package Policy"
        return
    
    page_data = page.search( r'Two\s?\-?\s?Wheeler\s?\-?\s?(Vehicles)?\s?\-?\s?Comprehensive\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "2W"
        data["policy_type"] = "Comprehensive Policy"
        return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Liability\s?\-?\s?(Only)?\s?\-?\s?(Policy)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Liability Policy"
        return
    
    page_data = page.search( r'Liability\s?\-?\s?(Only)?\s?\-?\s?(Insurance)?\s?\-?\s?(Policy)?\s?\-?\s?(Only)?\s?\-?\s?Private\s?\-?\s?Car', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Liability Policy"
        return
    
    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Package\s?\-?\s?(Policy)?\s?\-?\s?(Insurance)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Package Policy"
        return

    page_data = page.search( r'Private\s?\-?\s?Car\s?\-?\s?Comprehensive\s?\-?\s?(Policy)?\s?\-?\s?(Insurance)?', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["type"] = "4W"
        data["policy_type"] = "Comprehensive Policy"
        return
 
    page_data = page.search( r'Comprehensive\s?\-?\s?(Bike|Car)?\s?\-?\s?(Insurance)?\s?\-?\s?Policy', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Comprehensive Policy"
        return
    
    page_data = page.search( r'Package\s?\-?\s?(Bike|Car)?\s?\-?\s?(Insurance)?\s?\-?\s?Policy', regex=True, case=False )
    if len( page_data ) and "insurance_type" not in data:
        data["policy_type"] = "Package Policy"
        return

# %%
def find_reg_no( page ):
    page_data = page.search( r'(Vehicle|Reg(istration)?|\s?\.?)\s?(No\s?\.?|Number|Mark)\s*:?\s*' + 
                             r'([A-Z]{2}\s?\-?\s?[0-9]{1,2}\s?\-?\s?[A-Z]{1,3}\s?\-?\s?[0-9]{2,5}|new)', 
                             regex=True, case=False
                           )
    if len( page_data ) > 0:
        reg_number = re.split('\s|\:', page_data[0]["text"] )[-1]
        data["reg_no"] = reg_number.replace( '-', "" )

# %%
def find_chassis_no( page ):
    page_data = page.search( r'Chass?is\s(No\s?\.?|Number)\s*:?\s*M[A-EZ][A-HJ-NPR-Z0-9]{14,19}', regex=True, case=False )
    if len( page_data ) > 0:
        chassis_number = re.split('\s|:', page_data[0]["text"] )[-1]
        data["chassis_no"] = chassis_number.replace( '-', "" )

# %%
def find_chassis_no_with_slash( page ):
    key = page.search( r'Chass?is\s(No\s?\.?|Number)\s?\/', regex=True, case=False )
    if len( key ):
        chassis_number = page.search( r'M[A-EZ][A-HJ-NPR-Z0-9]{15,19}\s?\/', regex=True, case=False )
        if len( chassis_number ) > 0:
            data["chassis_no"] = chassis_number[0]["text"].replace( r'\/', "" )
            return
    
    key = page.search( r'/\s?Chass?is\s(No\s?\.?|Number)', regex=True, case=False )
    if len( key ):
        chassis_number = page.search( r'/\s?M[A-EZ][A-HJ-NPR-Z0-9]{15,19}', regex=True, case=False )
        if len( chassis_number ) > 0:
            data["chassis_no"] = chassis_number[0]["text"].replace( r'\/', "" )
            return

# %%
def find_insured_name( page ):
    page_data = page.search( r'(Mr|Mrs?|M\/s|Ms\.)(\.\s?|\s)[A-Z]{1,20}\s?[A-Z]{0,20}\s?[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
        data["insurers_name"] = page_data[0]["text"].replace( "\n", "" )
        return
    
    page_data = page.search( r'insured(\'s)?\s*name(\s|\s?:\s?)(Mr|Mrs?|M\/s|Ms\.)?(\.\s?|\s)?\s?[A-Z]{1,40}\s?[A-Z]{0,20}\s?[A-Z]{0,20}', regex=True, case=False )
    if len( page_data ) and "insurers_name" not in data:
        insurer_name = re.sub( "Insured(\'s)?\s*Name\s*:?\s*", "", page_data[0]["text"] )
        data["insurers_name"] = insurer_name.replace( "\n", "" )

# %%
def find_policy_duration( page ):
    #date_time dd/mm/yyyy hh:mm:ss
    start_date = page.search( r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?([0-9]{4})(\s*|T)(\[|\()?\s*' + 
                              r'(00|12):(00|01)(\]|\))?\s?(:00|:01)?(\]|\))?\s?(hrs|hours|AM)?',
                             regex=True, case=False 
                            )    
    end_date  =  page.search( r'[0-9]{1,2}[\-\/\]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?([0-9]{4})(\s*|T)(\[|\()?s?' +
                              r'(\(?Mid\s?night\)?|11:59|11:59:59|23:59:59)\s?(\]|\))?\s?(hrs|hours|PM)?(\(?Mid\s?night\))?',
                             regex=True, case=False
                            )
    if len( start_date ) > 0 and "start" not in data :
        data["start"] = start_date[0]['text']
    if len( end_date ) > 0 and "end" not in data :
        data["end"] = end_date[0]['text']
        
    
    #time_data  hh:mm:ss dd/mm/yyyy
    start_date = page.search( r'(\[|\()?\s?(00|12):(00|01)(\]|\))?\s?(:00|:01)?\s?(hrs|hours|AM)?\s?(\]|\))?\s*(T|on|of)\s*' +
                              r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?[0-9]{4}',
                             regex=True, case=False 
                            )
    end_date = page.search( r'(\[|\()?s?(\(?Mid\s?night\)?|11:59|11:59:59|23:59:59)s?(\]|\))?\s?(hrs|hours|PM)?\s*(T|on|of)\s*' +
                            r'[0-9]{1,2}[\-\/\,]?\s?[A-Z0-9]{1,3}[\-\/\,]?\s?[0-9]{4}(\(?Mid\s?night\))?',
                           regex=True, case=False
                          )
    if len( start_date ) > 0 and "start" not in data :
        data["start"] = start_date[0]['text']
    if len( end_date ) > 0 and "end" not in data :
        data["end"] = end_date[0]['text']

# %%
def find_reg_no_using_bbox( page ):
    
    page_data = page.search( r'Registration\s?(No\s?\.?|Number|Mark)?', regex=True, case=False )
    
    if len( page_data ) > 0:
        for i in range( len( page_data ) ):
            for j in range(10):
#                 print( page, page_data[i]['text'] )
                h_offset = ( page_data[i]["x1"] - page_data[i]["x0"] ) / len( page_data[i]["text"] ) * j
                v_offset = ( page_data[i]['bottom'] - page_data[i]['top'] ) * 5
        
                bbox_text = page.crop( [
                     max( page_data[i]["x0"] - h_offset, 0 ),
                     page_data[i]['top'],
                     min( page_data[i]["x1"] + h_offset, page.width ),
                     min( page_data[i]['bottom'] + v_offset, page.height )
                 ], strict=True ).extract_text()
            
#                 print( repr(bbox_text) )
                text = re.findall( r"\n([A-Z]{2}\s?\-?\s?[0-9]{1,2}\s?\-?\s?[A-Z]{1,3}\s?\-?\s?[0-9]{0,5}\n?[0-9]{0,5}|new)", bbox_text, re.IGNORECASE )

                if len( text ):
                    word = text[0].replace("\n\-", "")
                    if word.lower() == "new" or word[-4:].isnumeric():
                        data["reg_no"] = word
#                         print( "\n", page, "\t\t\t\t\t\tfound reg_no ", repr(word), "\n" )
                        return

# %%
def find_chassis_no_bbox( page ):
    
    page_data = page.search( r'Chass?is\s?(No\s?\.?|Number)\s?:?', regex=True, case=False )
    
    if len( page_data ) > 0:
        for i in range( len( page_data ) ):
            for j in range(14):
#                 print( page, page_data[i]['text'] )
                h_offset = ( page_data[i]["x1"] - page_data[i]["x0"] ) / len( page_data[i]["text"] ) * j
                v_offset = ( page_data[i]['bottom'] - page_data[i]['top'] ) * 5
        
                bbox_text = page.crop( [
                     max( page_data[i]["x0"] - h_offset, 0 ),
                     page_data[i]['top'],
                     min( page_data[i]["x1"] + h_offset, page.width ),
                     min( page_data[i]['bottom'] + v_offset, page.height )
                 ], strict=True ).extract_text()
            
#                 print( repr(bbox_text) )
                text = re.findall( r"\n?M[A-EZ][A-HJ-NPR-Z0-9]{14,19}\n?", bbox_text, re.IGNORECASE )

                if len( text ):
                    word = text[0].replace("\n\-", "")
                    if word.lower() == "new" or word[-4:].isnumeric():
                        data["chassis_no"] = word
#                         print( "\n", page, "\t\t\t\t\t\tfound chassis_no ", repr(word), "\n" )
                        return

# %%
df = pd.DataFrame( columns=[ "file", "pages", "insurers name", "type", "reg_no", "insurer", "phone", "email", "policy_type", "chassis_no", "start", "end", "time" ] )
files = os.listdir("./all_policy/Motor/all_policy")

count = 0

for file in files:
# for file in [ "hdfc10.pdf" ]:
    count += 1
    print( count, file )
    
    start_time = time.time()
    
    policy = pdfplumber.open( f'all_policy/Motor/all_policy/{file}' )
    
    insurer_count = {}
    data = {}

    for page in policy.pages:
        
        page_text = page.extract_text()
        
        find_insured_name( page ) if "insurers_name" not in data else None
        find_insurer_by_site( page ) if "insurer" not in data else None
        find_mobile( page ) if "mobile" not in data else None
        find_email( page ) if "email" not in data else None
        find_policy_type( page ) if "policy_type" not in data else None
        find_reg_no( page ) if "reg_no" not in data else None
        find_chassis_no( page ) if "chassis_no" not in data else None
        find_vehicle_type( page ) if "type" not in data else None
        find_policy_duration( page ) if "duration" not in data else None
        
    for page in policy.pages:
        if "insurer" not in data:
            get_insurer_by_name( page )
            
        if "chassis_no" not in data:
            find_chassis_no_with_slash( page )
        
        if "chassis_no" not in data:
            find_chassis_no_bbox( page )
            
        if "reg_no" not in data:
            find_reg_no_using_bbox( page )
            
            
    print( "data", data, "\n" )
    end_time = time.time()

    df.loc[ len( df.index ) ] = [ 
        file,
        len( policy.pages ),
        data["insurers_name"] if "insurers_name" in data else None,
        data["type"] if "type" in data else None,
        data["reg_no"] if "reg_no" in data else None,
        data["insurer"] if "insurer" in data else None,
        data["mobile"] if "mobile" in data else None,        
        data["email"] if "email" in data else None,
        data["policy_type"] if "policy_type" in data else None,
        data["chassis_no"] if "chassis_no" in data else None,
        data["start"] if "start" in data else None,
        data["end"] if "end" in data else None,
        ( end_time - start_time )
    ]
#     break
    
#     https://github.com/jsvine/pdfplumber
# Out:
# 1 hdfc13_4w.pdf
# data {'insurers_name': 'MR MAYUR MADHUKAR PATIL', 'mobile': '9096749797', 'email': 'mayur.m.patil9@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'MH11AW9594', 'chassis_no': 'MCA11835E07029773EMZ', 'start': '03 Nov, 2021 00:01 hrs', 'insurer': 'HDFC'}
#
# 2 reliance11_4w.pdf
# data {'insurers_name': 'MS.PRIYA AWASTHI ', 'mobile': '8433707105', 'email': 'dhirajawasthi@yahoo.com', 'reg_no': 'GJ15CK8239', 'type': '4W', 'start': ' 00:00 Hrs on 21-Jan-2022', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy', 'end': 'Mid Night of 20/01/2023'}
#
# 3 hdf_4w_comp.pdf
# data {'mobile': '8861598378', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA04MS3235', 'start': '13 Oct, 2021 00:01 hrs', 'insurer': 'HDFC'}
#
# 4 iffco1_4w.pdf
# data {'mobile': 'XXXXXXX741', 'start': '07/02/2022 00:00:00\n', 'end': '06/02/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'type': '4W', 'reg_no': 'UP93U5817'}
#
# 5 icici1_2w.pdf
# data {'insurer': 'ICICI', 'mobile': '9356278702', 'reg_no': 'TS09EE9725', 'chassis_no': 'ME4JF502LET601661', 'type': '2W', 'email': '2000@YAHOO.COM', 'policy_type': 'Package Policy', 'start': '02, 2022 12:00:00 '}
#
# 6 bharti_3p_4w.pdf
# data {'mobile': '7299997375', 'email': 'sajuvk@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'TN22CY7234', 'start': '23/04/2021 00:00 hrs', 'end': '22/04/2022 Midnight\n ', 'insurer': 'BHARTI'}
#
# 7 reliance2_2w.pdf
# data {'insurers_name': 'MR.B SENTHIL KUMAR', 'mobile': '8433707105', 'email': 'senthilkumar@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'TN12AH5335', 'start': ' 00:00 Hrs on 10-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MD2A55F5KCJ07279', 'end': 'Mid Night of 09/01/2023'}
#
# 8 newindia-4w-tp.pdf
# data {'insurer': 'NEW INDIA', 'type': '4W', 'policy_type': 'Liability Policy', 'start': '14/04/2022 12:00:01 AM', 'end': '13/04/2023 11:59', 'insurers_name': 'BIKRAM HAZARIKA ', 'mobile': 'XXXXXX0262', 'email': 'akashchetry799@gmail.com', 'reg_no': 'AS12M6347', 'chassis_no': 'MA3ERLF1S00399960/'}
#
# 9 bajaj_4w_od.pdf
# data {'insurer': 'BAJAJ', 'mobile': '9808144591', 'email': 'navinshandilya1@gmail.com', 'type': '4W', 'insurers_name': 'MALATYAGI  ', 'policy_type': 'Package Policy', 'reg_no': 'UP15CY6869'}
#
# 10 national-4w-comp.pdf
# data {'insurers_name': 'Mr. Edward I ', 'insurer': 'NATIONAL', 'mobile': '9916098981', 'email': 'edwardlawson87@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA01MH6947', 'start': '21-Apr-2022(00:00:00) '}
#
# 11 reliance_4w_comp.pdf
# data {'insurers_name': 'MR.ANISH DHIMAN ', 'mobile': '8433707105', 'email': 'anishdhiman99@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'HP64A2836', 'start': ' 00:00 Hrs on 03-Oct-2021', 'insurer': 'RELIANCE', 'chassis_no': 'MAKDG175JG4000911'}
#
# 12 iffco9_2w.pdf
# data {'insurers_name': 'RAMNARESH GODARA ', 'mobile': 'XXXXXXX100', 'reg_no': 'RJ44SB9262', 'type': '2W', 'start': '05/01/2022 00:00:00\n', 'end': '04/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 13 hdfc8_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '9900466863', 'email': 'dhanukumar110@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'KA42EB9744', 'chassis_no': 'ME4JF50AALA134302', 'start': '20 Jan, 2022 00:01 hrs'}
#
# 14 sbi-4w-comp.pdf
# data {'insurers_name': 'Mr. CHINTHALA PREETHI', 'insurer': 'SBI', 'mobile': '+91-9052928520', 'type': '4W', 'start': '15/05/2022T00:00:00\n', 'reg_no': 'TS08GN1666', 'chassis_no': 'MA3NYFB1SKC520556', 'end': '14/05/2023 Midnight\n '}
#
# 15 reliance15_2w.pdf
# data {'insurers_name': 'MR.HIMANSHU KUMAR ', 'mobile': '8433707105', 'email': 'Himanshukum@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'DL13SU5840', 'start': ' 00:00 Hrs on 05-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JF507KH7361902', 'end': 'Mid Night of 04/01/2023'}
#
# 16 magma-4w-comp.pdf
# data {'insurers_name': 'Mrs. Mrsjayshreeben Kamleshkumar Prajapati', 'insurer': 'MAGMA', 'mobile': '9725056102', 'email': 'primekamlesh@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'start': ' 00:00 Hrs of 14/04/2022', 'end': 'Midnight of 13/04/2023', 'reg_no': 'GJ05RA1617'}
#
# 17 reliance8_car.pdf
# data {'insurers_name': 'MR.PRABHAKAR PANDEY ', 'mobile': '8433707105', 'email': 'pankaj.singh.garud@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'UP60AA1991', 'start': ' 00:00 Hrs on 07-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MALBM51BLFM193559M'}
#
# 18 hdfc_4w_hybrid.pdf
# data {'insurers_name': 'MR RAJESH MUROOR PRABHU', 'insurer': 'HDFC', 'mobile': '9448366661', 'email': 'rajeshprabhu14@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'NEW', 'chassis_no': 'MZBEU812TMN218550', 'start': '12 Mar, 2021 00:01 hrs', 'end': '11/03/2022 Midnight '}
#
# 19 bajaj_4w_pack.pdf
# data {'mobile': '9899161954', 'email': 'dssharma761@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'insurer': 'BAJAJ', 'end': 'Midnighton23-NOV-2021', 'insurers_name': 'DEVENDRAKUMARSHARMA  ', 'reg_no': 'UP14AY7728'}
#
# 20 kotak9_2w.pdf
# data {'insurers_name': 'Mr. Vikash Andani', 'insurer': 'KOTAK', 'mobile': '8409305280', 'type': '2W', 'email': 'RAMKUMARITBP1988@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'end': '01/02/2023Midnight\n ', 'chassis_no': '\nMD625SF43E1D76026', 'reg_no': 'UP42AA4005'}
#
# 21 reliance16_4w.pdf
# data {'insurers_name': 'MR.MOHAMMAD RUSTUM BHAT', 'mobile': '8433707105', 'email': 'hilaljmi12@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'JK13C7701', 'start': ' 00:00 Hrs on 29-Oct-2021', 'insurer': 'RELIANCE', 'chassis_no': 'MA3EWDE1S00894649'}
#
# 22 chola-2w-comp.pdf
# data {'insurer': 'CHOLA', 'mobile': '9841198260', 'reg_no': 'TN10BC4732', 'chassis_no': 'MD626AG78J2D14142', 'type': '2W', 'start': '17/04/2022 00:01 hours', 'end': 'midnight on 16/04/2023'}
#
# 23 reliance_hybrid_4w.pdf
# data {'insurers_name': 'Mr. SHIVA KUMARA S', 'mobile': '9426110267', 'email': 'shivakumar267@gmail.com', 'reg_no': 'NEW', 'chassis_no': 'MAT627223MLF40268', 'type': '4W', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy'}
#
# 24 iffco3_2w.pdf
# data {'insurers_name': 'N VARADARAJAN ', 'mobile': 'XXXXXXX101', 'reg_no': 'KC09E86674', 'type': '2W', 'start': '27/02/2022 00:00:00\n', 'end': '26/02/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 25 hdfc_4w_tp.pdf
# data {'insurers_name': 'MRS APARNA ARUN CHORMUNGE', 'mobile': '9870909211', 'email': 'spartans2277@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'MH43L3303', 'start': '10/10/2020 00:01hrs', 'end': '09/10/2021 Midnight ', 'insurer': 'HDFC'}
#
# 26 acko-4w-tp.pdf
# data {'insurers_name': 'TEISOVINUO LOTHA ', 'insurer': 'ACKO', 'mobile': 'XXXXXX8324', 'email': 'sXXXXXXXXXXXXXXXXXXXX6@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'NL07T0267'}
#
# 27 reliance12_2w.pdf
# data {'insurers_name': 'MR.MR RAVEENDRAN ', 'mobile': '8433707105', 'email': 'anugrahameppayur@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'KL77A9698', 'start': ' 00:00 Hrs on 08-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP12DML8474223', 'end': 'Mid Night of 07/01/2023'}
#
# 28 kotak_4w_comp.pdf
# data {'insurers_name': 'Mrs. Shradha Deshpande', 'insurer': 'KOTAK', 'mobile': '9740575400', 'policy_type': 'Comprehensive Policy', 'type': '4W', 'email': 'SANKETH.KANDLIKAR@GMAIL.COM', 'start': '22/09/2020 00:00 ', 'end': '21/09/2021Midnight\n ', 'reg_no': 'KA02MH\n8148'}
#
# 29 kotak2_2w.pdf
# data {'insurers_name': 'Mr. Netaji Shivaji Jadhav', 'insurer': 'KOTAK', 'mobile': '8149445455', 'type': '2W', 'email': 'GANESHDZIRE@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '03/01/2022 00:00 ', 'end': '02/01/2023Midnight\n ', 'chassis_no': '\nMBLHA11ATG9D3730', 'reg_no': 'MH25AF4065'}
#
# 30 navi-4w-tp.pdf
# data {'insurer': 'NAVI', 'type': '4W', 'policy_type': 'Liability Policy', 'insurers_name': 'and Address', 'reg_no': 'KA03ML1507', 'chassis_no': 'MALAM51CR9M333424', 'start': ' 00:00 Hrs on 04-03-2022', 'end': 'Midnight on 03-03-2023'}
#
# 31 national-2w-comp.pdf
# data {'insurers_name': 'Mr. Amit Ratnakar Pagare', 'insurer': 'NATIONAL', 'mobile': '9890085085', 'email': 'contactpagare@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'MH05BW0835', 'start': '13-Apr-2022(00:00:00) '}
#
# 32 reliance4_2w.pdf
# data {'insurers_name': 'MR.SITA RAM BAIRWA', 'mobile': '8433707105', 'email': 'jp9433344@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'RJ14AJ7933', 'start': ' 00:00 Hrs on 04-Feb-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JC67DBK8003293', 'end': 'Mid Night of 03/02/2023'}
#
# 33 acko-4w-comp.pdf
# data {'insurer': 'ACKO', 'email': 'iXXXXXXXXXXXXXXXXXXXa@yahoo.co.in', 'type': '4W', 'policy_type': 'Package Policy', 'insurers_name': 'MANJU ISHWERI NARAYAN', 'reg_no': 'MH03BS0277', 'chassis_no': 'MAT612354EKD08300', 'mobile': 'XXXXXX2426'}
#
# 34 iffco5_2w.pdf
# data {'insurers_name': 'ALAGAPPAN AL ', 'mobile': 'XXXXXXX195', 'reg_no': 'KC20E80135', 'type': '2W', 'start': '02/01/2022 00:00:00\n', 'end': '01/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 35 reliance10_2w.pdf
# data {'insurers_name': 'MR.AKASH KUMAR SINGH', 'mobile': '8433707105', 'email': 'akashikka@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'KA51Y5671', 'start': ' 00:00 Hrs on 21-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME4JC448BB8090424', 'end': 'Mid Night of 20/01/2023'}
#
# 36 newindia-2w-comp.pdf
# data {'insurers_name': 'RUPAM DAS ', 'insurer': 'NEW INDIA', 'mobile': 'XXXXXX6455', 'email': 'noonmati020@gmail.com', 'type': '2W', 'policy_type': 'Package Policy', 'reg_no': 'AS01DB1446', 'start': '15/04/2022 12:00:01 AM', 'end': '14/04/2023 11:59', 'chassis_no': 'MB8NG4BAHG8239880/'}
#
# 37 united-2w-comp.pdf
# data {'insurer': 'UNITED', 'mobile': '9671732414', 'policy_type': 'Package Policy', 'reg_no': 'HR19H1069', 'type': '2W', 'start': ' 00:00 Hrs on 14-Apr-2022', 'end': 'Midnight on 13-Apr-2023', 'email': 'gurmeet3093@gmail.com', 'chassis_no': '\nMBLHA11EUD9E00520'}
#
# 38 reliance3_2w.pdf
# data {'insurers_name': 'MS.SHANTHI S ', 'mobile': '8433707105', 'email': 'rajthanga0123@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'PY01CW1342', 'start': ' 00:00 Hrs on 09-Feb-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP12DAL8138573', 'end': 'Mid Night of 08/02/2023'}
#
# 39 kotak7_2w.pdf
# data {'insurers_name': 'Mr. Prabhuraj K Hosamani', 'insurer': 'KOTAK', 'mobile': '8951618891', 'type': '2W', 'email': 'BAJARANGIPKH@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'end': '10/01/2023Midnight\n ', 'chassis_no': '\nMD2A14AZ4DWD3329', 'reg_no': 'KA41Y8233'}
#
# 40 bharti_4w_comp.pdf
# data {'mobile': '9406826010', 'email': 'anshuljhansiwale@yahoo.co.in', 'type': '4W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'MP09CU3117', 'start': '15/10/2020 00:00 hrs', 'end': '14/10/2021 Midnight\n ', 'insurer': 'BHARTI'}
#
# 41 kotak_hybrid_4w.pdf
# data {'insurers_name': 'Mrs. Suniti Tyagi', 'insurer': 'KOTAK', 'mobile': '7409548465', 'type': '4W', 'email': 'ayushtyagsa@gmail.com', 'start': '27/09/2020 00:00 ', 'end': '26/09/2021 Midnight\n ', 'reg_no': 'NEW'}
#
# 42 kotak10_2w.pdf
# data {'insurers_name': 'Mrs. Reetu Kumari', 'insurer': 'KOTAK', 'mobile': '8533990227', 'type': '2W', 'email': 'REETUREETU141@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '08/01/2022 00:00 ', 'end': '07/01/2023Midnight\n ', 'chassis_no': '\nMBLJFW015HGC12557', 'reg_no': 'DL05SAZ7925'}
#
# 43 iffico_4w_od.pdf
# data {'insurers_name': 'Mr. Anil Singh', 'mobile': '8130533313', 'type': '4W', 'start': '24/08/2020 00:00:00\n', 'end': '23/08/2021 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'reg_no': 'UK07DN9838'}
#
# 44 kotak11_2w.pdf
# data {'insurers_name': 'Mr. Bharat Yashwant Bangar', 'insurer': 'KOTAK', 'mobile': '9594880123', 'type': '2W', 'email': 'DOSTITOUR@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '11/10/2021 00:00 ', 'end': '10/10/2022Midnight\n ', 'chassis_no': '\nMD626BG46H3B2077', 'reg_no': 'MH04JA5479'}
#
# 45 hdfc9_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '7979971843', 'email': 'navneetbhg2020@gmail.com', 'type': '2W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'JH01BC4249', 'chassis_no': 'ME4JC36KKD7311586', 'start': '16 Jan, 2022 00:01 hrs'}
#
# 46 kotak5_2w.pdf
# data {'insurers_name': 'Mr. Sudesh R Morajkar', 'insurer': 'KOTAK', 'mobile': '9822122510', 'type': '2W', 'email': 'SUDESH.ARTIS@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '07/01/2022 00:00 ', 'end': '06/01/2023Midnight\n ', 'chassis_no': '\nME4JF505KGU482180', 'reg_no': 'GA04M4387'}
#
# 47 bharti_od_4w.pdf
# data {'type': '4W', 'insurers_name': 'Mr. Devinder Kumar ', 'mobile': '9729078558', 'email': 'hr2800471@gmail.com', 'reg_no': 'DL2CBA2638', 'start': '25/04/2019 00:00:00\n', 'end': '24/04/2022 23:59:59\n ', 'insurer': 'BHARTI'}
#
# 48 united-4w-tp.pdf
# data {'insurer': 'UNITED', 'mobile': '7904149939', 'reg_no': 'TN24V4844', 'type': '4W', 'start': ' 00:00 Hrs on 03-Mar-2022', 'end': 'Midnight on 02-Mar-2023', 'email': 'veludivxece2018@gmail.com', 'policy_type': 'Liability Policy', 'chassis_no': 'MA3FKE31S00237428'}
#
# 49 bajaj_3p_4w.pdf
# data {'email': None, 'type': '4W', 'insurer': 'BAJAJ', 'insurers_name': 'DEEPAKMISHRA  ', 'reg_no': 'DL02CAK7454'}
#
# 50 newindia-4w-comp.pdf
# data {'insurer': 'NEW INDIA', 'type': '4W', 'policy_type': 'Package Policy', 'start': '20/04/2022 12:00:01 AM', 'end': '19/04/2023 11:59', 'insurers_name': 'GAURAV GOEL ', 'mobile': 'XXXXXX8030', 'email': 'goel209@yahoo.co.in', 'reg_no': 'HR26CD8127'}
#
# 51 reliance1_4w.pdf
# data {'insurers_name': 'MR.RAMAKANTA SAMAL ', 'mobile': '8433707105', 'email': 'niraj.samal@hotmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'OD02AA4963', 'start': ' 00:00 Hrs on 16-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MALA841CLFM151684'}
#
# 52 edel-4w-comp.pdf
# data {'insurers_name': 'Mr. Pronojit Sen ', 'type': '4W', 'policy_type': 'Package Policy', 'start': '[00:00] of 12-Apr-2022', 'insurer': 'EDELWEISS', 'reg_no': 'WB02AP3947'}
#
# 53 iffco6_2w.pdf
# data {'insurers_name': 'BRAJESH KUMAR ', 'mobile': 'XXXXXXX810', 'type': '2W', 'start': '04/01/2022 00:00:00\n', 'end': '03/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'reg_no': 'DL9SBG4545'}
#
# 54 kotak6_2w.pdf
# data {'insurers_name': 'Mr. Suman Bn', 'insurer': 'KOTAK', 'mobile': '9741111668', 'type': '2W', 'email': 'SUMANBN668@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'end': '27/01/2023Midnight\n ', 'chassis_no': '\nME4JF393JF708333', 'reg_no': 'KA05JQ0243'}
#
# 55 kotak_4w_3p.pdf
# data {'insurers_name': 'Mr. Basha S', 'insurer': 'KOTAK', 'mobile': '8178289201', 'type': '4W', 'email': 'harshverdhanpathak115@gmail.com', 'start': '25/08/2021 00:00 ', 'end': '24/08/2022 Midnight\n ', 'chassis_no': '\nMA3JMT81SKE16227', 'reg_no': 'KA51MN8526'}
#
# 56 iffico_3p_4w.pdf
# data {'mobile': 'XXXXXXX569', 'start': '20/10/2021 00:00:00\n', 'end': '19/10/2022 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'type': '4W', 'reg_no': 'MH27AC9244'}
#
# 57 iffco11_2w.pdf
# data {'insurers_name': 'SUDHIR JAIN ', 'mobile': 'XXXXXXX830', 'reg_no': 'DL12SJ2108', 'type': '2W', 'start': '18/11/2021 00:00:00\n', 'end': '17/11/2022 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 58 hdfc2_4w.pdf
# data {'insurers_name': 'M/S RAJ KUMAR KAIN', 'mobile': '7982382088', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL08CNB8249', 'start': '24 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 59 hdfc_4w_od.pdf
# data {'insurers_name': 'MR MANU THOMAS CHIRAYIL', 'insurer': 'HDFC', 'mobile': '7760914134', 'email': 'manuthomaschirayil@outlook.com', 'reg_no': 'KA03ND9582', 'chassis_no': 'MALA851CLJM952554', 'type': '4W', 'start': '28 Dec, 2020 00:01 hrs'}
#
# 60 iffco10_2w.pdf
# data {'insurers_name': 'RAJASEKHAR CH ', 'mobile': 'XXXXXXX689', 'reg_no': 'AP05BK0106', 'type': '2W', 'start': '03/11/2021 00:00:00\n', 'end': '02/11/2022 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 61 iffico_4w_package.pdf
# data {'insurers_name': 'MR KULDEEP  ', 'mobile': '9911093500', 'type': '4W', 'start': '27/09/2020 12:00', 'end': '05/10/2021 23:59:59\n ', 'insurer': 'IFFICO-TOKIO'}
#
# 62 iffco4_2w.pdf
# data {'insurers_name': 'RAKESH KUMAR MAURYA', 'mobile': 'XXXXXXX540', 'reg_no': 'JF50E75411', 'type': '2W', 'start': '10/01/2022 00:00:00\n', 'end': '09/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'policy_type': 'Package Policy'}
#
# 63 bajaj_4w_hybrd.pdf
# data {'insurer': 'BAJAJ', 'insurers_name': 'GIRISHKUMARTHANKAPPANNAIR Zone', 'type': '4W', 'policy_type': 'Package Policy'}
#
# 64 royalsundaram-4w-comp.pdf
# data {'insurers_name': 'Mr. LAVJIBHAI MOHANBHAI HAPALIYA', 'insurer': 'ROYAL', 'mobile': 'xxxxxx5540', 'start': ' 00:00:00 hours on 07/04/2022', 'end': '23:59:59 hours on 06/04/2023', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'GJ5JP5327'}
#
# 65 hdfc12_2w.pdf
# data {'insurer': 'HDFC', 'mobile': '9902059738', 'email': 'jagadeeshae7272@gmail.com', 'type': '2W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'KA53EM8787', 'start': '16 Jan, 2022 00:01 hrs'}
#
# 66 hdfc11_4w.pdf
# data {'insurers_name': 'MR BEERAIAH B ', 'mobile': '9731138386', 'email': 'prakashmbangalore@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA53C7581', 'chassis_no': 'MAT600185GPJ34888', 'start': '03 Feb, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 67 iffco8_2w.pdf
# data {'insurers_name': 'MADHAV RADHEYSHYAM KATIYAR', 'mobile': 'XXXXXXX720', 'reg_no': 'JF50EU80864', 'type': '2W', 'start': '27/01/2022 00:00:00\n', 'end': '26/01/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'policy_type': 'Package Policy'}
#
# 68 hdfc5_4w.pdf
# data {'insurers_name': 'MR KRISHNAMURTHY KIKKISETTI RTO', 'mobile': '9742723000', 'email': 'kkmurty93@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA03MX4830', 'chassis_no': 'MEEBBA002G1325553', 'start': '30 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 69 kotak8_4w.pdf
# data {'insurers_name': 'Mrs. Leelavathi B', 'insurer': 'KOTAK', 'mobile': '9700643243', 'type': '4W', 'email': 'RAMYABHARGAVI.BUJJE@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '19/01/2022 00:00 ', 'end': '18/01/2023Midnight\n ', 'reg_no': 'AP03BP5836'}
#
# 70 iffco7_4w.pdf
# data {'mobile': 'XXXXXXX674', 'start': '03/02/2022 00:00:00\n', 'end': '02/02/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'GA03Y4235'}
#
# 71 reliance9_car.pdf
# data {'insurers_name': 'MR.PRAMOD SINGH RANA', 'mobile': '8433707105', 'email': 'atienter2010@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL02CAZ7876', 'start': ' 00:00 Hrs on 09-Jan-2022', 'insurer': 'RELIANCE'}
#
# 72 acko-2w-comp.pdf
# data {'insurers_name': 'Geetinder Singh ', 'insurer': 'ACKO', 'mobile': 'XXXXXX9111', 'email': 'gXXXXXXXXXXXXi@yahoo.com', 'policy_type': 'Comprehensive Policy', 'reg_no': 'PB10FS2630', 'chassis_no': 'ME3U3K5C0GD042682', 'type': '2W'}
#
# 73 iffico_4w_package2.pdf
# data {'mobile': '8097762008', 'type': '4W', 'start': '03/09/2020 00:00:00 ', 'end': '02/09/2021 23:59:59  ', 'policy_type': 'Package Policy', 'insurer': 'IFFICO-TOKIO', 'reg_no': 'NEW'}
#
# 74 hdfc7_4w.pdf
# data {'insurers_name': 'MR SANDEEP KUMAR ', 'mobile': '9646689689', 'email': 'harpreetsharma097@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'CH01AE2802', 'chassis_no': 'MA3EWDE1S00176139', 'start': '31 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 75 sbi-4w-tp.pdf
# data {'insurers_name': 'Mr. MANISH SHARMA', 'insurer': 'SBI', 'mobile': '+91-9818077949', 'start': '10/03/2022T00:00:00\n', 'reg_no': 'DL2CAN2618', 'chassis_no': 'MA3EDKD1S00290267', 'end': '09/03/2023 Midnight\n ', 'type': '4W'}
#
# 76 kotak3_2w.pdf
# data {'insurers_name': 'Mr. Amol Jugalkishor Heda', 'insurer': 'KOTAK', 'mobile': '9845316882', 'type': '2W', 'email': 'MOHITSR76@GMAIL.COM', 'policy_type': 'Comprehensive Policy', 'start': '09/01/2022 00:00 ', 'end': '08/01/2023Midnight\n ', 'chassis_no': '\nME4JF651JG7037973', 'reg_no': 'MH41AN7522'}
#
# 77 reliance14_2w.pdf
# data {'insurers_name': 'MR.SUNDARABABU R ', 'mobile': '8433707105', 'email': 'rajthanga0123@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'PY05F2934', 'start': ' 00:00 Hrs on 31-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MB8DP11ALJ8A62610', 'end': 'Mid Night of 30/01/2023'}
#
# 78 bharti_hybrid_4w.pdf
# data {'insurers_name': 'Mr. Subasish Mohapatra ', 'mobile': '9008811448', 'email': 'mohapatrasubasish@yahoo.co.in', 'type': '4W', 'start': '30/07/2021 00:00 ', 'end': 'midnight of 29/07/2022', 'insurer': 'BHARTI', 'reg_no': 'NEW'}
#
# 79 iffco2_4w.pdf
# data {'mobile': 'XXXXXXX114', 'start': '09/03/2022 00:00:00\n', 'end': '08/03/2023 23:59:59\n ', 'insurer': 'IFFICO-TOKIO', 'type': '4W', 'reg_no': 'KL27A1810'}
#
# 80 reliance7_4w.pdf
# data {'insurers_name': 'MR.MR SANKHA NARAYAN', 'mobile': '8433707105', 'email': 'surzeett@gmail.com', 'reg_no': 'AS06AA5025', 'type': '4W', 'start': ' 00:00 Hrs on 10-Jan-2022', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy', 'chassis_no': 'MBHEWB22SKM407883', 'end': 'Mid Night of 09/01/2023'}
#
# 81 hdfc1_4w.pdf
# data {'insurers_name': 'MR PARIKSHIT MALHOTRA ', 'insurer': 'HDFC', 'mobile': '9418450772', 'email': 'drpm1972@gmail.com', 'type': '4W', 'policy_type': 'Comprehensive Policy', 'reg_no': 'HP33F5772', 'start': '18 Jan, 2022 00:01 hrs', 'end': '17/01/2023 Midnight '}
#
# 82 reliance_4w_3p.pdf
# data {'insurers_name': 'Mr.SUMIT SUHAG ', 'insurer': 'RELIANCE', 'mobile': '8433707105', 'email': 'davesh.dits@gmail.com', 'reg_no': 'HR26BM5573', 'type': '4W', 'start': ' 00:00 Hrs on 13-Oct-2021', 'end': 'Midnight of 12-Oct-2022', 'policy_type': 'Liability Policy', 'chassis_no': 'MAKGM252HBN211435'}
#
# 83 united-4w-comp.pdf
# data {'insurer': 'UNITED', 'mobile': '9873621425', 'policy_type': 'Package Policy', 'reg_no': 'DL9CAU4736', 'type': '4W', 'start': ' 00:00 Hrs on 09-Apr-2022', 'end': 'Midnight on 08-Apr-2023', 'chassis_no': '\nMBJ53REH2065099410316'}
#
# 84 hdfc6_2W.pdf
# data {'insurer': 'HDFC', 'mobile': '8882746998', 'email': 'pankajali786@gmail.com', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'DL08SCR0181', 'chassis_no': 'MD626AG74K2E23103', 'start': '02 Feb, 2022 00:01 hrs'}
#
# 85 hdfc10_4w.pdf
# data {'insurers_name': 'MR MANJU DEVI ', 'mobile': '9816086889', 'email': 'chandan.ranote@gmail.com', 'type': '4W', 'policy_type': 'Liability Policy', 'reg_no': 'HP12D2172', 'chassis_no': 'MALAA51HR9M486097L', 'start': '16 Jan, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 86 hdfc3_4w.pdf
# data {'insurers_name': 'MR HARI OM ', 'mobile': '7983119833', 'email': 'sksmtr.sk@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'DL03CCN5760', 'chassis_no': 'MA3EWDE1S00D50948', 'start': '01 Feb, 2022 00:01 hrs', 'insurer': 'HDFC'}
#
# 87 reliance13_4w.pdf
# data {'insurers_name': 'MR.ASHWATHANARAYAN M ', 'mobile': '8433707105', 'email': 'bmvishnu.vs@yahoo.co.in', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'KA43M8588', 'start': ' 00:00 Hrs on 06-Jan-2022', 'insurer': 'RELIANCE'}
#
# 88 reliance_4w_od.pdf
# data {'insurers_name': 'Ms. ANJU TIWARI ', 'mobile': '9871421097', 'email': 'shalendra.tripathi@gmail.com', 'reg_no': 'HR26EF2340', 'type': '4W', 'start': ' 00:01 Hrs on 14-Dec-2020', 'insurer': 'RELIANCE', 'policy_type': 'Package Policy', 'chassis_no': 'MAJAXXMRKAKM56507'}
#
# 89 reliance5_2w.pdf
# data {'insurers_name': 'MS.ASTALAKSHMI R ', 'mobile': '8433707105', 'email': 'SKFINANCE01@GMAIL.COM', 'type': '2W', 'policy_type': 'Stand Alone Own Damage', 'reg_no': 'TN11AK9898', 'start': ' 00:00 Hrs on 18-Feb-2022', 'insurer': 'RELIANCE', 'chassis_no': 'ME1SED14AJ0042881', 'end': 'Mid Night of 17/02/2023'}
#
# 90 reliance6_4w.pdf
# data {'insurers_name': 'MR.RAKESH BALDEVBHAI PATEL', 'mobile': '8433707105', 'email': 'rakesh11566@gmail.com', 'type': '4W', 'policy_type': 'Package Policy', 'reg_no': 'GJ06DG2771', 'start': ' 00:00 Hrs on 21-Jan-2022', 'insurer': 'RELIANCE', 'chassis_no': 'MALBB51BR9M122064M'}

# %%
df = df.sort_values("reg_no")
# df.filter( ["file", "start", "end"] )
l = list( set( df[ df["chassis_no"].isnull() == True ]["file"] ) )
print( l )
print( len( l ) )
# Out:
# ['iffco3_2w.pdf', 'iffco10_2w.pdf', 'bajaj_3p_4w.pdf', 'reliance11_4w.pdf', 'bharti_od_4w.pdf', 'iffco5_2w.pdf', 'united-2w-comp.pdf', 'bharti_hybrid_4w.pdf', 'bajaj_4w_pack.pdf', 'kotak_4w_comp.pdf', 'iffco11_2w.pdf', 'kotak_hybrid_4w.pdf', 'iffco6_2w.pdf', 'national-2w-comp.pdf', 'hdfc_4w_tp.pdf', 'iffico_4w_package.pdf', 'united-4w-tp.pdf', 'hdfc2_4w.pdf', 'magma-4w-comp.pdf', 'edel-4w-comp.pdf', 'bharti_4w_comp.pdf', 'united-4w-comp.pdf', 'iffco2_4w.pdf', 'royalsundaram-4w-comp.pdf', 'iffco4_2w.pdf', 'kotak_4w_3p.pdf', 'iffco1_4w.pdf', 'bajaj_4w_od.pdf', 'reliance9_car.pdf', 'newindia-4w-comp.pdf', 'bharti_3p_4w.pdf', 'kotak6_2w.pdf', 'iffico_3p_4w.pdf', 'kotak8_4w.pdf', 'iffico_4w_package2.pdf', 'kotak11_2w.pdf', 'reliance13_4w.pdf', 'iffco9_2w.pdf', 'iffico_4w_od.pdf', 'hdf_4w_comp.pdf', 'kotak5_2w.pdf', 'hdfc12_2w.pdf', 'kotak9_2w.pdf', 'iffco7_4w.pdf', 'kotak2_2w.pdf', 'kotak7_2w.pdf', 'kotak3_2w.pdf', 'national-4w-comp.pdf', 'kotak10_2w.pdf', 'acko-4w-tp.pdf', 'hdfc1_4w.pdf', 'bajaj_4w_hybrd.pdf', 'iffco8_2w.pdf']
# 53

# %%
def test( page ):
    
    page_data = page.search( r'Chass?is\s?(No\s?\.?|Number)\s?:?', regex=True, case=False )
    print( page, len( page_data ) )
    if len( page_data ) > 0:
        for i in range( len( page_data ) ):
            for j in range(14):
#             print( page, page_data[i]['text'] )
                h_offset = ( page_data[i]["x1"] - page_data[i]["x0"] ) / len( page_data[i]["text"] ) * j
                v_offset = ( page_data[i]['bottom'] - page_data[i]['top'] ) * 5
        
                bbox_text = page.crop( [
                     max( page_data[i]["x0"] - h_offset, 0 ),
                     page_data[i]['top'],
                     min( page_data[i]["x1"] + h_offset, page.width ),
                     min( page_data[i]['bottom'] + v_offset, page.height )
                 ], strict=True ).extract_text()
            
                print( repr(bbox_text) )
                text = re.findall( r"M[A-EZ][A-HJ-NPR-Z0-9\n]{14,19}", bbox_text, re.IGNORECASE )

                if len( text ):
                    word = text[0].replace("\n\-", "")
                    if word.lower() == "new" or word[-4:].isnumeric():
                        data["chassis_no"] = word
                        print( "\n", page, "\t\t\t\t\t\tfound chassis_no ", repr(word), "\n" )
                        return

# %%
# files = list( df[ df["chassis_no"].isnull() == True ]["file"] )
i = 0
# for file in files:
for file in ["national-4w-comp.pdf"]:
    i = i + 1
    print( i, file )
    policy = pdfplumber.open( f'all_policy/Motor/all_policy/{file}' )

# repr(policy.pages[0].extract_text() )
# policy.pages[0].search( r'chassis no.\sM[A-EZ][A-HJ-NPR-Z0-9]{9}', regex=True, case=False )[0]['text']
    for page in policy.pages:
        print(page)
        test( page )
# Out:
# 1 national-4w-comp.pdf
# <Page:1>
# <Page:1> 1
# 'Chassis No\nB51BLBM382\nEngine No\n4LABM79389'
# 'Chassis No\nBB51BLBM382\nEngine No\nG4LABM793892'
# 'Chassis No\nBB51BLBM3824\nEngine No\nG4LABM793892'
# 'Chassis No\nLBB51BLBM38243\nEngine No\nG4LABM793892'
# 'Chassis No\nALBB51BLBM382438\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# 'Chassis No\nMALBB51BLBM382438M\nEngine No\nG4LABM793892'
# <Page:2>
# <Page:2> 0

# %%
# df.sort_values("chassis_no")

# %%
# df[ df["chassis_no"].isnull() == True ]['file']

# %%
 'bharti_3p_4w.pdf',   yeah with after/
 'national-4w-comp.pdf', yes 18

# %%
len("MALBB51BLBM382438M")
# Out:
# 18

# %%
# !git add PDF_Reading_Sheet.ipynb
# !git commit -m "added policy_duration extractor"
# !git push
